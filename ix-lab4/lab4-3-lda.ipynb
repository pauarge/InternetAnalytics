# %% [markdown]
# # Text 3: Latent Dirichlet allocation
# **Internet Analytics - Lab 4**
#
# ---
#
# **Group:** *O*
#
# **Names:**
#
# * *Argelaguet Franquelo, Pau*
# * *du Bois de Dunilac, Vivien*
#
# ---
#
# #### Instructions
#
# *This is a template for part 3 of the lab. Clearly write your answers, comments and interpretations in Markodown cells. Don't forget that you can add $\LaTeX$ equations in these cells. Feel free to add or remove any cell.*
#
# *Please properly comment your code. Code readability will be considered for grading. To avoid long cells of codes in the notebook, you can also embed long python functions and classes in a separate module. Don’t forget to hand in your module if that is the case. In multiple exercises, you are required to come up with your own method to solve various problems. Be creative and clearly motivate and explain your methods. Creativity and clarity will be considered for grading.*

# %%
from pyspark.mllib.clustering import LDA, LDAModel
from pyspark.mllib.linalg import Vectors

import pickle
import numpy as np
import string
import collections
import operator
import math

from functools import reduce
from scipy.sparse import csr_matrix
from utils import load_json, load_pkl, save_pkl

# %%
courses = load_json('data/courses.txt')
preprocessed = load_pkl('data/preprocess.pckl')
terms = load_pkl('data/terms.pckl')

# %% [markdown]
# ## Exercise 4.8: Topics extraction

# %%
print(list(list(preprocessed.items())[0][1]['description'].items()))
# Out:
# [('adapt', 2), ('adapt composit', 2), ('applic', 2), ('biocomposit', 2), ('composit', 12), ('composit applic', 2), ('cost', 2), ('develop', 2), ('nanocomposit', 2), ('perform', 2), ('polym', 2), ('product', 3), ('team', 2)]

# %%
def createTermVector(bagOfWord):
    countList = []
    for term in terms:
        countList.append(bagOfWord.get(term, 0))
    return Vectors.dense(countList)

# %%
vectorList = []
counter = 1
for it in list(preprocessed.items()):
    vectorList.append([counter, createTermVector(it[1]['description'])])
    counter += 1
rdd = sc.parallelize(vectorList)

# %%
def pTop(ldaModel, nWords=10):
    for topic in ldaModel.describeTopics():
        termList = []
        for i in range(nWords):
            termList.append(terms[topic[0][i]])
        print(termList)

# %% [markdown]
# ### Variying ALPHA

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=1.01)
pTop(ldaModel)
# Out:
# ['heat', 'communic', 'chemic', 'electron', 'applic', 'reaction', 'algorithm', 'linear', 'comput', 'flow']
# ['energi', 'report', 'skill', 'evalu', 'data', 'plan', 'convers', 'comput', 'week', 'technolog']
# ['physic', 'equat', 'problem', 'mass', 'properti', 'structur', 'group', 'applic', 'solv', 'mechan']
# ['energi', 'paper', 'engin', 'discuss', 'industri', 'busi', 'cell', 'assess', 'team', 'technolog']
# ['problem', 'program', 'comput', 'optim', 'numer', 'research', 'linear', 'algorithm', 'plan', 'signal']
# ['data', 'network', 'robot', 'control', 'algorithm', 'magnet', 'water', 'assess', 'exam', 'architectur']
# ['electron', 'stochast', 'financi', 'control', 'architectur', 'applic', 'function', 'comput', 'linear', 'theori']
# ['simul', 'studi', 'case', 'risk', 'data', 'manag', 'assess', 'case studi', 'mechan', 'activ']
# ['biolog', 'chemic', 'organ', 'structur', 'chemistri', 'develop', 'reaction', 'scientif', 'evalu', 'molecular']
# ['optic', 'microscopi', 'electron', 'mechan', 'quantum', 'spectroscopi', 'laser', 'applic', 'principl', 'imag']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=3.0)
pTop(ldaModel)
# Out:
# ['report', 'flow', 'linear', 'problem', 'skill', 'numer', 'data', 'scientif', 'optim', 'experiment']
# ['electron', 'quantum', 'theori', 'cell', 'microscopi', 'applic', 'magnet', 'structur', 'introduct', 'risk']
# ['circuit', 'architectur', 'devic', 'field', 'sensor', 'activ', 'signal', 'robot', 'integr', 'techniqu']
# ['optic', 'biolog', 'paper', 'laser', 'discuss', 'chemic', 'protein', 'physic', 'chemistri', 'interact']
# ['case', 'studi', 'manag', 'cell', 'power', 'applic', 'case studi', 'engin', 'group', 'wast']
# ['energi', 'engin', 'thermodynam', 'numer', 'physic', 'dure', 'convers', 'environment', 'comput', 'technolog']
# ['control', 'mechan', 'structur', 'properti', 'function', 'fundament', 'fractur', 'measur', 'problem', 'statist']
# ['organ', 'structur', 'engin', 'machin', 'network', 'properti', 'transport', 'physic', 'program', 'metal']
# ['data', 'develop', 'week', 'innov', 'research', 'technolog', 'plan', 'assess', 'evalu', 'differ']
# ['imag', 'stochast', 'theori', 'probabl', 'introduct', 'time', 'optim', 'equat', 'risk', 'differenti']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=5.0)
pTop(ldaModel)
# Out:
# ['statist', 'program', 'data', 'linear', 'optim', 'problem', 'algorithm', 'theori', 'comput', 'function']
# ['control', 'engin', 'circuit', 'robot', 'filter', 'oper', 'week', 'power', 'imag', 'integr']
# ['paper', 'electron', 'control', 'field', 'data', 'water', 'discuss', 'solid', 'energi', 'devic']
# ['report', 'skill', 'laser', 'research', 'quantum', 'evalu', 'laboratori', 'data', 'activ', 'organ']
# ['simul', 'market', 'price', 'flow', 'scientif', 'architectur', 'develop', 'research', 'theori', 'physic']
# ['optic', 'energi', 'fourier', 'risk', 'solv', 'algebra', 'imag', 'physic', 'problem', 'measur']
# ['mechan', 'magnet', 'applic', 'structur', 'properti', 'physic', 'organ', 'metal', 'communic', 'electron']
# ['stochast', 'numer', 'reactor', 'architectur', 'develop', 'visual', 'final', 'imag', 'assess', 'urban']
# ['biolog', 'cell', 'protein', 'signal', 'structur', 'molecular', 'optic', 'dynam', 'applic', 'note']
# ['studi', 'case', 'chemic', 'assess', 'group', 'case studi', 'reaction', 'class', 'product', 'evalu']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=7.5)
pTop(ldaModel)
# Out:
# ['electron', 'sensor', 'techniqu', 'applic', 'product', 'industri', 'communic', 'devic', 'principl', 'technolog']
# ['linear', 'statist', 'probabl', 'introduct', 'stochast', 'price', 'financi', 'imag', 'measur', 'market']
# ['paper', 'teach', 'scienc', 'space', 'theori', 'architectur', 'comput', 'research', 'group', 'scale']
# ['biolog', 'field', 'engin', 'structur', 'problem', 'assess', 'physic', 'research', 'skill', 'energi']
# ['optic', 'structur', 'mechan', 'quantum', 'laser', 'molecular', 'protein', 'function', 'statist', 'applic']
# ['energi', 'control', 'optim', 'program', 'data', 'risk', 'network', 'engin', 'communic', 'power']
# ['case', 'imag', 'studi', 'integr', 'function', 'group', 'activ', 'topic', 'fourier', 'circuit']
# ['chemic', 'flow', 'reaction', 'equat', 'chemistri', 'magnet', 'heat', 'physic', 'thermodynam', 'transfer']
# ['report', 'data', 'experiment', 'week', 'skill', 'scientif', 'laboratori', 'robot', 'written', 'stabil']
# ['develop', 'semest', 'innov', 'architectur', 'numer', 'cell', 'week', 'dure', 'comput', 'evalu']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=10.0)
pTop(ldaModel)
# Out:
# ['optic', 'laser', 'reaction', 'studi', 'theori', 'microscopi', 'problem', 'reactor', 'evalu', 'measur']
# ['data', 'imag', 'program', 'comput', 'statist', 'algorithm', 'signal', 'final', 'practic', 'visual']
# ['electron', 'communic', 'simul', 'robot', 'energi', 'flow', 'equat', 'introduct', 'circuit', 'price']
# ['biolog', 'protein', 'comput', 'molecular', 'interact', 'quantum', 'architectur', 'function', 'dynam', 'theori']
# ['numer', 'engin', 'magnet', 'teach', 'equat', 'mathemat', 'probabl', 'biolog', 'practic', 'properti']
# ['paper', 'semest', 'discuss', 'product', 'assess', 'environment', 'econom', 'research', 'innov', 'studi']
# ['report', 'evalu', 'develop', 'research', 'scientif', 'data', 'problem', 'experiment', 'optim', 'skill']
# ['cell', 'control', 'chemic', 'energi', 'metal', 'thermodynam', 'mechan', 'organ', 'electron', 'convers']
# ['structur', 'energi', 'mechan', 'manag', 'control', 'group', 'risk', 'inform', 'assess', 'dynam']
# ['physic', 'field', 'devic', 'differ', 'industri', 'activ', 'group', 'plan', 'sensor', 'provid']

# %% [markdown]
# ### Variying BETA

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['structur', 'mechan', 'comput', 'quantum', 'numer', 'cell', 'dynam', 'simul', 'applic', 'solv']
# ['control', 'protein', 'biolog', 'imag', 'research', 'network', 'develop', 'activ', 'chemic', 'studi']
# ['report', 'problem', 'evalu', 'plan', 'data', 'skill', 'optim', 'scientif', 'assess', 'studi']
# ['flow', 'physic', 'practic', 'teach', 'skill', 'theori', 'test', 'equat', 'product', 'technolog']
# ['electron', 'devic', 'imag', 'microscopi', 'structur', 'techniqu', 'properti', 'chemistri', 'integr', 'organ']
# ['risk', 'manag', 'magnet', 'market', 'differ', 'financi', 'case', 'price', 'assess', 'introduct']
# ['engin', 'paper', 'field', 'biolog', 'discuss', 'reaction', 'communic', 'chemic', 'activ', 'circuit']
# ['energi', 'mass', 'industri', 'thermodynam', 'heat', 'environment', 'evalu', 'water', 'chemic', 'convers']
# ['statist', 'signal', 'linear', 'probabl', 'stochast', 'theori', 'data', 'robot', 'time', 'control']
# ['optic', 'data', 'cell', 'algorithm', 'laser', 'note', 'function', 'program', 'applic', 'structur']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=3.0, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['cell', 'biolog', 'applic', 'organ', 'chemic', 'physic', 'signal', 'function', 'reaction', 'activ']
# ['problem', 'numer', 'comput', 'linear', 'theori', 'optim', 'algorithm', 'program', 'statist', 'equat']
# ['optic', 'microscopi', 'electron', 'applic', 'imag', 'physic', 'principl', 'equat', 'control', 'theori']
# ['energi', 'heat', 'convers', 'thermodynam', 'architectur', 'magnet', 'transfer', 'physic', 'case', 'technolog']
# ['network', 'technolog', 'applic', 'theori', 'control', 'activ', 'communic', 'techniqu', 'imag', 'develop']
# ['data', 'report', 'research', 'evalu', 'scientif', 'skill', 'plan', 'assess', 'experiment', 'problem']
# ['structur', 'week', 'class', 'engin', 'control', 'assess', 'group', 'activ', 'develop', 'evalu']
# ['laser', 'quantum', 'physic', 'mechan', 'biolog', 'architectur', 'chemic', 'electron', 'engin', 'principl']
# ['electron', 'applic', 'theori', 'mechan', 'signal', 'structur', 'techniqu', 'introduct', 'devic', 'properti']
# ['imag', 'applic', 'physic', 'mechan', 'engin', 'properti', 'theori', 'techniqu', 'activ', 'biolog']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=5.0, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['data', 'problem', 'assess', 'activ', 'control', 'optic', 'evalu', 'comput', 'energi', 'applic']
# ['electron', 'energi', 'imag', 'applic', 'structur', 'physic', 'biolog', 'control', 'activ', 'mechan']
# ['problem', 'comput', 'data', 'assess', 'applic', 'evalu', 'activ', 'theori', 'structur', 'optim']
# ['biolog', 'structur', 'physic', 'mechan', 'applic', 'chemic', 'energi', 'assess', 'cell', 'engin']
# ['energi', 'applic', 'structur', 'data', 'optic', 'electron', 'theori', 'assess', 'problem', 'physic']
# ['structur', 'optic', 'problem', 'applic', 'electron', 'data', 'biolog', 'physic', 'theori', 'activ']
# ['data', 'engin', 'problem', 'structur', 'activ', 'theori', 'assess', 'applic', 'evalu', 'comput']
# ['electron', 'optic', 'energi', 'applic', 'structur', 'physic', 'mechan', 'control', 'theori', 'properti']
# ['structur', 'optic', 'problem', 'applic', 'comput', 'theori', 'biolog', 'physic', 'mechan', 'activ']
# ['report', 'data', 'evalu', 'research', 'assess', 'problem', 'technolog', 'skill', 'activ', 'engin']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=7.0, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['structur', 'electron', 'applic', 'data', 'problem', 'physic', 'mechan', 'energi', 'assess', 'activ']
# ['energi', 'data', 'problem', 'assess', 'structur', 'applic', 'evalu', 'activ', 'comput', 'theori']
# ['data', 'energi', 'evalu', 'assess', 'problem', 'activ', 'report', 'applic', 'structur', 'comput']
# ['optic', 'applic', 'problem', 'energi', 'activ', 'electron', 'assess', 'theori', 'structur', 'comput']
# ['data', 'optic', 'structur', 'applic', 'problem', 'theori', 'assess', 'activ', 'comput', 'evalu']
# ['structur', 'applic', 'problem', 'theori', 'assess', 'data', 'activ', 'comput', 'evalu', 'physic']
# ['problem', 'structur', 'applic', 'comput', 'theori', 'data', 'assess', 'activ', 'physic', 'mechan']
# ['structur', 'data', 'problem', 'assess', 'applic', 'engin', 'activ', 'evalu', 'theori', 'comput']
# ['data', 'applic', 'structur', 'problem', 'assess', 'engin', 'energi', 'activ', 'evalu', 'comput']
# ['assess', 'structur', 'evalu', 'problem', 'applic', 'data', 'activ', 'engin', 'theori', 'research']

# %% [markdown]
# ### Optimized parameters

# %%
# k = number of topics, alpha(doc) higher alpha means more different topics per document
# beta(topic) higher beta means more words per topic
ldaModel = LDA.train(rdd, k=40, docConcentration=1.51, topicConcentration=1.01, seed=10)

# print the top x terms for each topic
pTop(ldaModel, 10)
# Out:
# ['measur', 'field', 'wast', 'snow', 'solid', 'physic', 'properti', 'solid wast', 'manag', 'engin']
# ['laser', 'network', 'digit', 'architectur', 'generat', 'studio', 'form', 'communic', 'urban', 'applic']
# ['imag', 'diffract', 'structur', 'mass', 'scienc', 'electron', 'xray', 'organ', 'spectrometri', 'mass spectrometri']
# ['case', 'assess', 'communic', 'class', 'surfac', 'chain', 'suppli', 'reactor', 'studi', 'oper']
# ['polici', 'time', 'environment', 'evalu', 'power', 'communic', 'modul', 'regul', 'solut', 'recycl']
# ['space', 'product', 'inform', 'neuron', 'function', 'modul', 'communic', 'biominer', 'algebra', 'applic']
# ['structur', 'mechan', 'protein', 'properti', 'studi', 'applic', 'local', 'biolog', 'optim', 'chemic']
# ['solv', 'numer', 'robot', 'problem', 'equat', 'practic', 'comput', 'program', 'distribut', 'linear']
# ['cell', 'stabil', 'algorithm', 'structur', 'function', 'data', 'week', 'dynam', 'cancer', 'lim']
# ['paper', 'quantum', 'discuss', 'topic', 'oral', 'assess', 'molecular', 'critic', 'evalu', 'oral present']
# ['membran', 'function', 'verif', 'cognit', 'privaci', 'effect', 'secur', 'articl', 'qualiti', 'protein']
# ['theori', 'print', 'metabol', 'electron', 'semest', 'studi', 'research', 'function', 'pathway', 'differ']
# ['engin', 'note', 'doctor', 'system engin', 'doctor student', 'probabl', 'edm', 'analog', 'corpor', 'oper']
# ['risk', 'manag', 'plan', 'convex', 'industri', 'develop', 'energi', 'assess', 'problem', 'decis']
# ['report', 'data', 'skill', 'scientif', 'research', 'evalu', 'supervis', 'experiment', 'result', 'written']
# ['busi', 'technolog', 'class', 'assess', 'group', 'activ', 'plan', 'mem', 'team', 'differ']
# ['secur', 'philosoph', 'microbi', 'machin', 'evalu', 'plan', 'machin learn', 'term', 'problem', 'scienc']
# ['cell', 'fractur', 'film', 'mechan', 'thin', 'stem', 'thin film', 'stem cell', 'growth', 'wearabl']
# ['microscopi', 'electron', 'teach', 'energi', 'electron microscopi', 'urban', 'spatial', 'techniqu', 'sustain', 'skill']
# ['structur', 'steel', 'week', 'seismic', 'optic', 'signal', 'tumor', 'light', 'biomed', 'interact']
# ['signal', 'fourier', 'filter', 'transform', 'signal process', '2d', 'fourier transform', 'applic', 'integr', 'data']
# ['chemistri', 'organ', 'parallel', 'energi', 'water', 'environment', 'reaction', 'program', 'catalysi', 'comput']
# ['data', 'algorithm', 'speech', 'code', 'power', 'control', 'graph', 'hour', 'algebra', 'grid']
# ['optic', 'imag', 'organ', 'electron', 'microscopi', 'treatment', 'techniqu', 'wastewat', 'solar', 'devic']
# ['metal', 'properti', 'phase', 'engin', 'physic', 'alloy', 'comput', 'technolog', 'thermodynam', 'mathemat']
# ['statist', 'linear', 'probabl', 'regress', 'applic', 'tool', 'imag', 'markov', 'theori', 'nuclear']
# ['biolog', 'chemic', 'scientif', 'discuss', 'research', 'reaction', 'chemistri', 'protein', 'evalu', 'experiment']
# ['imag', 'physic', 'turbul', 'engin', 'skill', 'electron', 'transport', 'digit', 'strategi', 'flow']
# ['optic', 'applic', 'laser', 'fiber', 'test', 'waveguid', 'photon', 'engin', 'tissu', 'light']
# ['price', 'financi', 'market', 'stochast', 'financ', 'option', 'asset', 'portfolio', 'deriv', 'risk']
# ['simul', 'comput', 'numer', 'mechan', 'differ', 'theori', 'dynam', 'part', 'scale', 'molecular']
# ['optim', 'program', 'languag', 'comput', 'algorithm', 'problem', 'electron', 'atom', 'mathemat', 'theori']
# ['chemic', 'thermodynam', 'reaction', 'develop', 'state', 'law', 'laser', 'technolog', 'principl', 'equat']
# ['control', 'magnet', 'network', 'dynam', 'perform', 'devic', 'social', 'comput', 'media', 'effect']
# ['acoust', 'structur', 'nonlinear', 'theori', 'base', 'econom', 'exam', 'techniqu', 'room', 'ceram']
# ['food', 'interfac', 'dure', 'effect', 'product', 'statist', 'data', 'test', 'electron', 'chemistri']
# ['activ', 'posit', 'properti', 'calculus', 'sensor', 'nonlinear', 'filter', 'propag', 'map', 'stochast']
# ['softwar', 'physic', 'role', 'mechan', 'solut', 'program', 'numer', 'element', 'problem', 'miniproject']
# ['energi', 'flow', 'heat', 'innov', 'transfer', 'convers', 'fluid', 'mass', 'energi convers', 'equat']
# ['architectur', 'plasma', 'common', 'applic', 'drug', 'physic', 'devic', 'circuit', 'interact', 'citi']

# %%
def extractTopics(ldaModel, nWords=10):
    topicList = []
    for topic in ldaModel.describeTopics():
        termList = []
        for i in range(nWords):
            termList.append(terms[topic[0][i]])
        topicList.append(termList)
    return topicList

# %%
courseTopics = extractTopics(ldaModel, 25)
topicLabels = range(len(courseTopics))
#topicLabels = ['Imagery', 'Scientific methodology', 'Statistics', 'Biology/Chemistry', 'Signal/Image processing', 'Energy', 'Lab environment', 'Maths', 'Stochastic models', 'Programming', 'Business', 'Organization']

# %%
for course in preprocessed.items():
    topics = []
    for i in range(len(courseTopics)):
        count = 0
        t = courseTopics[i]
        for word in course[1]['description']:
            if word in t:
                count += 1
        if count > 4:
            topics.append(topicLabels[i])
    print(course[1]['name'], topics)
# Out:
# Composites technology []
# Image Processing for Life Science []
# Global business environment [2, 5, 7, 13, 16, 27, 33]
# Electrochemical nano-bio-sensing and bio/CMOS interfaces []
# Structural mechanics (for MT) []
# Théorie et critique du projet MA2 (Boltshauser) [0, 1, 12, 16, 31, 32]
# Advanced principles and applications of systems biology [4]
# Mass spectrometry [30]
# Principles of digital communications []
# Hardware systems modeling I [13]
# Quantitative systems modeling techniques [21]
# Medical radiation physics []
# Bio-nano-chip design []
# Principles of powder and densification processing []
# Fundamentals of solid-state materials [29]
# Microeconomics []
# Polymer chemistry and macromolecular engineering []
# Physical chemistry of polymeric materials [30]
# Fundamentals of neuroengineering []
# In Silico neuroscience []
# Materials selection [2, 5, 31]
# Optics laboratories I [3, 4, 7, 9, 13, 25, 31, 33]
# Fracture mechanics [12, 23, 27]
# Air pollution and climate change
#  [8]
# Philosophy of life sciences I [5, 7, 13, 20, 21, 22, 24, 27, 28, 33]
# Lab methods : proteomics [5, 6, 30, 32, 34]
# Cementitious materials (advanced) [28, 31, 32]
# Material and energy flow analysis [7, 22, 31]
# Linear algebra (english) []
# Transport phenomena II []
# Printed systems and large area manufacturing [2, 9, 12, 16, 18, 24, 26, 29, 34]
# Theoretical computer science [3, 21, 34]
# Philosophy, epistemology and history of science I []
# Reservoir mechanics for geo-energy and the environment [0, 9, 12, 23, 31]
# Non linear analysis of structures [15, 31]
# Investments [17, 27]
# Engines and fuel cells [0, 3, 23, 30]
# Recycling of materials [24]
# Statistical signal and data processing through applications [19, 21, 34]
# Analysis II (English) [17]
# Technology & innovation strategy [2, 5, 7, 12, 16, 24, 27, 31, 32]
# Lab immersion I [7, 20, 21, 22, 24, 28, 31, 33]
# Internet analytics [21, 34]
# Supply chain management [2, 5, 7, 13, 16]
# Particle-based methods [0, 6, 12, 17]
# Statistical Sequence Processing [21]
# Solid state image sensing [9, 13, 18, 25, 26]
# Soft matter []
# Advanced regression [21, 34]
# Introduction to database systems [8, 12, 15, 16, 20, 21, 22, 31, 32]
# Hydraulic turbomachines []
# Design and analysis of experiments in materials science and engineering []
# Business design for IT services [5]
# Some problems in the theory of simple groups []
# Simulation and optimisation of industrial applications [5, 7, 12, 13, 31]
# Biomicroscopy II [4, 9, 10, 12, 18, 21, 25]
# Modelling problem solving, computing and visualisation II [31]
# Frontiers in Organic Synthesis. Part III Stereochemistry [1, 18, 30]
# Photonic micro- and nanosystems [9, 25, 29]
# Safety of chemical processes []
# Probabilities and statistics []
# Practical - Fellay Lab []
# CCMX Winter School - Metal Science []
# Mobile robots [12]
# Leading research in Chemical Engineering (a) [2, 30]
# Fluvial biogeosciences [5, 7, 8, 20, 24, 28]
# Biochemistry II []
# Micro-magnetic field sensors and actuators [9, 29]
# Diffraction methods in structural biology [24, 29]
# Practical - Gönczy Lab []
# Principles and Practicals in X-Ray Scattering []
# Frederic Joliot/Otto Hahn Summer School on nuclear reactors Physics, fuels and systems []
# Computational finance [17, 19]
# Applied stochastic processes []
# Structure and evolution of galaxies (UNIGe) []
# Numerical integration  of stochastic differential equations [17]
# Immunology [7, 13, 20, 24, 25, 28, 31]
# Thin film fabrication processes [14]
# Studio MA1 (Lütjens et Padmanabhan) [32]
# Théorie et critique du projet MA1 (Huang) [6, 16, 31, 32]
# Biomedical signal processing [19]
# Current Topics in Chemical Biology 2 []
# Physics and hydrology of snow []
# Nuclear magnetic resonance [29]
# Limestone-Calcined Clay - Cement : Characterisation methods []
# Advanced materials for photovoltaics and lighting [6, 12, 13, 21, 26]
# Nanoelectronics [26]
# PhD Masterclass - The horizontal metropolis and other research questions []
# Mapping urban history [5, 13, 32]
# Topics in Autonomous Robotics []
# Speech processing [2]
# Mathematical models in supply chain management [2, 7, 16]
# Practical - Simanis Lab []
# Image communication []
# Plasma Diagnostics in Basic Plasma Physics Devices and Tokamaks: from Principles to Practice []
# Nanophotonics and plasmonics []
# Computational photography [4, 9, 15, 21, 22, 25, 33, 34]
# Information literacy for chemists []
# Distributed algorithms []
# Entrepreneurship laboratory (e-lab) []
# Introduction to planetary sciences []
# Biomedical optics [25]
# Quality assurance and quality management systems [8]
# Non-destructive evaluation methods []
# Concepts in ecological engineering []
# Molecular endocrinology [24]
# Privacy Protection [21, 22]
# Synthesis, analysis and verification [0, 12, 16, 21]
# Chemical engineering lab & project [1, 14, 20]
# Mathematical modelling of DNA []
# Industry dynamics, models & trends [7]
# Optics II []
# Multivariable control and coordination systems [19]
# Science and technology of UV-induced polymerization []
# Lab methods : animal experimentation []
# Structure and reactivity []
# Macrofinance [2, 15, 17, 21, 27, 28]
# Operations: economics & strategy [7]
# Inorganic chemistry "Applications and spin-offs" []
# Analytic algorithms [21, 34]
# Geomechanics []
# Database systems []
# How people learn II [0, 7, 20, 31]
# Biomolecular structure and mechanics [4, 6, 12, 20, 29, 30, 31]
# Practical - De Palma Lab []
# Distributed intelligent systems [13, 21, 33]
# Research project in materials I [20]
# Nutrition: from molecules to health []
# Wood structures, properties and uses [0, 6, 12, 31, 32]
# Corporate governance []
# Scientific literature analysis in Computational molecular biology [16, 22, 24, 28, 33]
# Mechanisms of cell motility []
# Specialisation project in materials [20]
# Making structural logic [0, 15, 16, 32]
# Biotechnology lab (for CGC) []
# Bioprocesses and downstream processing [2, 3, 4, 5, 7, 9, 14, 16, 23, 30, 31, 33]
# Algebraic curves and cryptography [21]
# Image and video processing [19, 25]
# Biochemical engineering [3, 14, 30, 31]
# Analog circuits for biochip []
# Advanced wireless communications: algorithms and architectures []
# Numerical methods in biomechanics [3, 14, 31]
# Practical - Cole Lab []
# Functional Data Analysis []
# TCP/IP networking [6, 10, 21, 22, 34]
# Introduction to particle accelerators []
# Technology and Public Policy - (d) Technology policies for grand and global challenges []
# Technology and Public Policy - (b) Technology, policy and regulation [28]
# Principles of computer systems [4, 21, 26, 34]
# Physics and chemistry of the atmosphere [14, 30]
# Biomechanics of the musculoskeletal system []
# Studio BA4 (De Vylder & Taillieu) []
# Practical - Trono Lab []
# Highlights in microtechnology []
# Transport phenomena I [3, 23]
# International Finance []
# Chemical biology - tools and methods [20, 28, 30]
# Experimental cognitive psychology I [7, 13, 20, 22, 28, 31, 33, 34]
# Topics on Datacenter Design []
# Mechanical design principles [31]
# Scanning and Analytical Transmission Electron Microscopy [10, 18]
# Computational perception using multimodal sensors []
# Supramolecular chemistry []
# Biological modeling of neural networks [4]
# Automatic speech processing [2, 21, 34]
# Dielectric properties of materials [6, 10, 12, 29]
# Using Mathematica to analyse and model experimental data []
# Process development II []
# Large-area electronics: devices and materials [6, 9, 18, 26, 29]
# Chemosensory receptors: Applications for biosensors and medical therapies []
# Risk management [7, 8, 14]
# Distributed information systems []
# Mathematical modelling of behavior []
# Empirical Asset Pricing []
# Risk and energy [2, 5, 7, 8, 13, 16, 20, 25, 27, 31, 33]
# Coordination chemistry and reactivity of f elements []
# UE U : Cartography [32, 34]
# Optional project in Systems engineering []
# Energy Regulation (2016) []
# Computational motor control [0, 19]
# Data converter circuits and systems [32]
# Molecular and cellular biophysic I [30]
# Systems and architectures for signal processing [2, 6, 7, 13, 16, 21, 22, 31, 32]
# Tokamak Plasma Control []
# Training Rotation (EDMS) []
# Nanotechnology [6, 12]
# Metrology I []
# Advanced algorithms [21, 34]
# Project in neuroprosthetics [20]
# Electrochemistry for materials technology [2]
# Quantum electrodynamics and quantum optics []
# Scientific literature analysis in molecular and cancer biology [5, 16, 22, 24, 28, 33]
# Rings and modules []
# Practical - Suter Lab [5, 6]
# Unsupervised and reinforcement learning in neural networks [21, 34]
# Optics and technology of liquid crystal displays []
# Hot Topics in Cancer Research [2]
# Lab in microelectronics []
# Linear models []
# Principles and applications of systems biology [4, 13, 22, 30, 31]
# Statistical Physics for Communication and Computer Science []
# Economics of innovation in the biomedical industry [21, 27]
# Introduction to transport phenomena [3]
# Magnetic and semiconducting nanostructures []
# Experimental Geomechanics []
# Experimental cognitive psychology II [20]
# Photochemistry I [6, 29]
# Stem cell biology and technology [4, 5]
# Powder technology []
# Credit risk [17]
# Parabolic and hyperbolic PDE's []
# Powder Characterisation and Dispersion []
# IEEE Sensors Council Summer School on Nano-Bio-Sensing [18, 24, 29, 33]
# Leading research in Chemical Engineering (b) [2, 30]
# Numerical methods in heat transfer [0, 3, 4, 6, 7, 12, 13, 14, 17, 20, 21, 22, 23, 31]
# Théorie et critique du projet MA1 (Gugger) [32]
# Test of VLSI systems []
# Laser microprocessing [25]
# UE N : Art et architecture: constructing the view II [32, 34]
# Empirical Corporate Finance []
# IC design for robustness []
# Introduction to econometrics []
# Radiation protection & radiation applications []
# Semiconductor physics and fundamentals of electronic devices [18, 26]
# Chemical engineering product design [1, 14, 30, 31]
# Computer simulation of physical systems I [19]
# Chemical biology [2, 30]
# Experimental design and data analysis with R [4, 15, 22, 34]
# Introduction to natural language processing [34]
# Mobile networks []
# Philosophy, epistemology and history of science II []
# Optical communications []
# Low-voltage analog CMOS IC design []
# Nano CMOS Devices & Technologies for Tera-Bit Circuits and Systems []
# Quantitative methods II []
# Trends in Metabolism & Physiology []
# Media security [25]
# Markov chains and algorithmic applications [21, 34]
# Energy systems engineering [3]
# Surfaces and interfaces []
# Lasers and applications in chemistry [3, 6, 7, 9, 12, 14, 25, 31]
# Working Group in Algebraic Groups, II []
# Chemistry of food processes [1, 8]
# Selected topics in advanced optics [25, 27]
# Product lifecycle management - concepts methods and tools [2, 5, 13, 31]
# Project in bioengineering and biosciences [7, 13, 16, 20, 21, 22, 24, 28, 31, 33]
# Introduction to Algebraic geometry []
# Lab immersion academic (outside EPFL) A [7, 16, 20, 21, 22, 24, 31, 33]
# Biomaterials (pour MX) []
# D. Thinking: real problems, human-focused solutions [32]
# Financial big data [2, 13, 17, 20, 21, 22, 27, 31, 33]
# Human language technology: applications to information access []
# Modeling and simulation of microsystems [4]
# Synergism between Art of Total Synthesis and High Level Strategic Design (MOM) []
# Topics in geometric analysis I []
# Scanning electron microscopy techniques (b) []
# Lab in acoustics [31]
# Bioelectronics and implantable biomedical microelectronics [12, 24, 33]
# Introduction to operating systems []
# Solar photovoltaics and energy systems [3, 26, 29]
# Nonlinear signal modeling and prediction []
# Theoretical corporate finance []
# Neurosciences II : cellular mechanisms of brain function [4, 12, 13, 16, 23, 31]
# Digital education & learning analytics []
# Frontiers in Organic Synthesis. Part II Synthesis of carbo- and hetero-cycles [1]
# Hardware systems modeling [26]
# Statistical thermodynamics [3, 23]
# Applied data analysis [16, 20, 21, 22, 24, 27, 31, 32, 33, 34]
# Electron microscopy: advanced methods []
# Modeling of emerging electron devices []
# Scientific literature analysis in cell and developmental biology [1, 16, 18, 20, 22, 28]
# Numerical approximation of PDE's II [17]
# Control systems   TP [19]
# Project in biomedical technologies [20]
# Practical - Hantschel Lab [6]
# Classical electrodynamics [11, 17, 31]
# Pattern classification and machine learning [21, 22, 27, 34]
# Industrial electronics I []
# CCMX Advanced Course 'Advanced X-ray Diffraction Methods for Coatings: strain, defects and deformation analysis of thin films []
# Molecular and cellular biophysic II [4, 28, 30]
# CCMX Advanced Course - Instrumented Nanoindentation [6, 10, 12, 21, 22]
# Electronic properties of solids and superconductivity []
# Practical - Brisken Lab [6]
# Hydrogeophysics []
# Sensorimotor neuroprosthetics [31, 33]
# Advanced analysis I []
# Nanofabrication with focused electron and ion beams []
# Computer simulation of physical systems II [3, 6, 21]
# Fundamentals in Systems Engineering [1, 3, 9, 16, 21, 22, 28, 32, 33]
# Programming concepts in scientific computing [16, 21, 22]
# Intelligent agents [26]
# Lifecycle performance of product systems [2, 14, 31]
# Fluid mechanics for SV []
# Engineering internship credited with master project (master in Management of Technology and Entrepreneurship) []
# Active noise control []
# Reactive programming []
# Principles of intellectual property management [7, 12]
# Optics laboratories II [25, 31]
# UE L : Art and architecture: constructing the view I [34]
# Computer language processing [26]
# Photomedicine [9, 18, 24, 25, 28]
# Modelling and optimization of energy systems [0, 2, 3, 12, 13, 21, 23, 30, 31, 33]
# 1st Workshop on Advances in CFD and MD modelling of Interface Dynamics in Capillary Two-Phase Flows []
# Early detection of innovation potential [1, 2, 7, 13, 16, 20, 22, 24, 27, 31]
# Sanitary engineering in developing countries [8]
# Experimental biochemistry and biophysics [4, 7, 20, 24, 28, 30, 31]
# Virtual reality [22, 34]
# Recent Events in Energy-1 []
# History of globalization II []
# Biomechanics of the cardiovascular system []
# Project in Electrical Energy Systems []
# Turbulence [31]
# Chemical thermodynamics [3, 14, 30]
# Topics in geometric analysis II []
# Methods of Modelling and Simulation of Materials Science []
# Nanobiotechnology and biophysics [4, 18, 22, 28]
# Thermal power cycles and heat pump systems [3]
# Advanced information, computation, communication II []
# Methods for rapid production and development []
# Software engineering [0, 7, 21]
# How people learn I [7, 16]
# Thermodynamics for materials science [14]
# Thermodynamics and energetics I [3, 23]
# Applied corporate & industry analysis (MTE master only) [7]
# Nanoscale MOSFETs and beyond CMOS devices [26]
# Electrochemical Thermodynamics and Kinetics of Metals and Semiconductors for Energy Conversion [3]
# Fundamentals of superresolution optical microscopy and Scanning Probe Microscopy []
# Understanding Statistics and Experimental Design []
# Scientific project design in translational neurosciences [5, 6, 18, 33]
# Seminar series on advances in materials (spring) []
# Audio signal processing and virtual acoustics [15, 19]
# Slope stability []
# Economics of Innovation and Technological Change []
# Elliptic PDE's [17]
# Computer-aided engineering [31]
# Nuclear fusion and plasma physics []
# Project in micro and nanoelectronics []
# Environmental chemistry [1, 14]
# Power systems dynamics [13, 19]
# Tribology [12]
# Gödel and recursivity []
# Technology policy and the energy transition [7, 28]
# X-Ray Analysis for thin films []
# Fourier analysis and boundary value problems []
# Organic chemistry [1, 8, 14, 30]
# Density functional theory for chemistry students []
# Advanced microwaves for wireless communications []
# Optimal decision making [21]
# Hardware systems modeling II []
# Introduction to Frustrated Magnetism []
# Quantum Information Theory and Computation [6, 21]
# Investing: a Guide to Doing the Right Thing [2, 5, 13, 17]
# Biological chemistry II (for SV) []
# Théorie et critique du projet MA2 (Geers) [20, 30, 32]
# Renewable energy and solar architecture in Davos []
# Lab immersion in industry B [7, 16, 20, 21, 22, 24, 31, 33]
# Seminars in Physical Chemistry (2) []
# Multivariate statistics []
# Financial econometrics [17, 19, 21, 22, 27, 34]
# Equilibrium-stage separation processes [0]
# Electron Microscopy for Life Science [4, 9, 10, 18]
# Water resources engineering []
# IC design II []
# Space mission design and operations [28]
# Model predictive control [21]
# Computer vision []
# Photochemistry II [3, 29]
# Instability [6, 7, 12, 31]
# Transmission electron microscopy and diffraction (a) [10, 18]
# Modern photovoltaic technologies [26]
# Sparse stochastic processes [17, 21, 31]
# Cristallography and diffraction methods [29]
# Econometrics []
# Lab methods : histology []
# Studio MA1 (Escher et GuneWardena) [16, 32]
# Introduction to chemical engineering [3, 14, 17, 21, 31, 33]
# Information technology and digital strategy [5, 6, 7]
# Practical - Bucher Lab []
# Advanced quantum field theory []
# Working group in Topology I []
# Functional programming []
# Neurotechnologies to treat neurodisorders: neuroprosthetics (EDNE) []
# Lab methods : bioactive compounds screening [1, 4, 5, 14, 18, 20, 22, 24, 31]
# Advanced MEMS [26, 29]
# Théorie et critique du projet MA1 (Geers) [20, 30, 32]
# PLLs and clock & data recovery []
# Active Remote Sensing of the Atmosphere []
# Practical - Lemaitre Lab []
# Integrated circuits technology []
# Applied probability & stochastic processes [21, 27]
# Negotiation techniques [5, 27, 31, 33]
# Satellite communications  systems and networks []
# Parallel and high-performance computing []
# Plasma physics III []
# Energy conversion and renewable energy [3]
# Image optics [9, 10, 18, 24, 25]
# Financial Econometrics (EDFI) []
# Interdisciplinary / disciplinary project for chemical master []
# Social media [0]
# Fixed income analysis [17]
# Parallelism and concurrency []
# Optical fibers and fiber devices []
# Surface and thin films processes []
# Optimization and simulation [21]
# Financial & managerial accounting []
# Innovation management [5, 7, 13, 16, 22, 27]
# Image analysis and pattern recognition []
# Stochastic calculus I [11, 17]
# Piezoelectric materials, properties and devices []
# Limnology []
# Fundamentals of biosensors and electronic biochips [33]
# Signal processing for communications [10, 19, 21, 27, 33]
# Soft Microsystems Processing and Devices [10, 12, 24, 26, 29]
# A Network Tour of Data Science [15, 21, 31, 34]
# Mass spectrometry, principles and applications []
# Development engineering [0, 6, 7, 16, 31, 33]
# Assembly techniques [5, 6, 10, 12, 27, 31]
# Nonlinear Optics []
# Nonlinear Spectroscopy []
# Advanced analog and RF integrated circuits design II []
# RF MEMS for communications applications []
# Fundamentals of traffic operations and control [21, 22, 27, 31, 33]
# Biophysics II []
# Quantum Field Theory Methods in Gravity and Cosmology []
# Lasers: theory and modern applications [9, 25]
# Machine Learning for Engineers []
# Energy storage in power systems: technologies, applications and future needs []
# Properties of semiconductors and related nanostructures []
# Seismic engineering []
# Théorie et critique du projet MA2 (Gugger) [32]
# Advanced lab in electrical engineering []
# Concurrent algorithms []
# Water quality modeling [8, 14, 30]
# Scientific literature analysis in Neuroscience [16, 22, 24]
# Information security and privacy []
# Chemical engineering of heterogenous reactions [1, 12, 30, 31]
# Flexible bioelectronics [18, 24, 29]
# Eco-friendly production and process intensification [1, 8, 14, 23, 30, 31]
# Dynamical system theory for engineers [21]
# Introduction to magnetic materials in modern technologies [0, 3, 6, 9, 12, 24, 26, 29, 31]
# Empirical Methods in Corporate Finance []
# Cosmology: Dark and Luminous Matters  []
# Pharmacology and pharmacokinetics []
# Algorithms [21, 31, 34]
# Probability theory []
# Theoretical Microfluidics []
# Economics of innovation [5, 7, 15, 22, 24, 27, 31, 34]
# Pharmacological chemistry [18]
# High energy and space astrophysics (UNIGe) []
# Fundamentals in statistical pattern recognition [21, 22]
# Advanced Topics in Cryptology [16, 22]
# Advanced cryptography [27, 34]
# Biostatistics [34]
# Digital 3D Geometry Processing [25]
# Introduction to digital signal processing using Matlab, applied to environmental sciences and civil engineering []
# Advanced diffusional separation processes []
# Lab immersion academic (outside EPFL) B [7, 13, 16, 20, 21, 22, 24, 31]
# Inorganic reactivity [14]
# Advanced satellite positioning []
# Lab in electrical energy systems [4, 33]
# Optical waves propagation [9]
# Energy Autonomous Wireless Smart Systems [2, 12, 16, 18, 24, 29, 34]
# Numerical methods for visual computing [12, 16, 17, 21, 22, 27, 34]
# Power management []
# Environmental policy [2, 5, 7, 13, 31]
# Fate and behaviour of organic pollutants [1, 14, 30]
# Landmark Papers in Cancer and Infection []
# Advanced analog and RF integrated circuits design I [33]
# Advanced control systems []
# 2D Layered Materials: Synthesis, Properties and Applications [1, 3, 6, 10, 12, 15, 18, 24, 26, 29, 31]
# Game Theory []
# Linear system theory []
# Discrete mathematics [21]
# Emerging Nanopatterning Methods []
# Project in information technologies []
# Graph theory []
# Ceramics, structures and properties   TP []
# Strategic marketing & technology commercialization [2, 5, 7, 13, 16, 22, 27]
# Lab immersion in industry A [7, 16, 20, 21, 22, 24, 31, 33]
# Topics in theoretical computer science [21, 22, 24, 34]
# Advanced Earthquake Engineering []
# Scaling laws in micro- and nanosystems [29]
# Materials and technology of microfabrication []
# Business information systems [5, 7]
# History of globalization I [5, 13, 16, 20, 22, 24, 31, 32]
# Operating systems implementation []
# Entrepreneurship [7, 13, 24]
# Computational methods in molecular quantum mechanics [3, 6, 21]
# High pressure in chemical kinetics and equilibria []
# Materials Science [27]
# CCMX Winter School - Additive Manufacturing of Metals and the Material Science Behind It' []
# Introduction to crystal growth by epitaxy []
# Microstructuring of glass []
# Advanced composites in engineering structures [27]
# Ecotoxicology [1, 8, 14]
# New tools and research strategies in personalized medicine [7, 20, 24, 28]
# Numerical methods for electromagnetics [17]
# Photomechanics for Engineers []
# Introduction to scanning electron microscopy microanalysis techniques [18]
# Fundamentals of VLSI design []
# Electric filters [33]
# Introduction to multiprocessor architecture []
# Wireless Transceivers: Radio Architectures, System and Circuit Design []
# Information theory and coding [34]
# Cellular Signalling [4]
# Fracture of materials [12, 31]
# Advances in Additive Manufacturing for Polymers in Bioengineering, Electronics and Material Science [2]
# Chemistry of small biological molecules [4, 18]
# Théorie et critique du projet MA2 (Huang) [6, 16, 31, 32]
# Human computer interaction []
# Scientific project design in integrative neurosciences []
# Organic electronic materials - synthesis, applications, properties [1, 14, 18, 26, 30]
# Sensor orientation [34]
# Imagery of territory []
# Scientific project design in drug discovery [1, 5, 6, 12, 18, 22, 24, 25, 28, 31, 33]
# Brain Bioenergetics: from behavior to pathology []
# Advanced information, computation, communication I [11, 16, 21, 27]
# Wireless receivers: algorithms and architectures []
# Biomimetic membrane systems and their applications []
# Data Analysis for Science and Engineering [20, 22, 34]
# Infection biology []
# Advanced digital communications [2, 15, 16, 21, 24, 33, 34]
# Difficult Double Double Histories []
# Lab immersion III [7, 20, 21, 22, 24, 28, 31, 33]
# Practical - Lingner Lab [6]
# Reactor Technology []
# Advanced derivatives [17, 27]
# Geocomputation [6, 20, 22, 31, 32]
# Summer School on Neurophysiology for Neural and Biomedical Engineering (2016) [20]
# Multivariate Extreme Value and Max-Stable Processes []
# Monthly IBI-EDBB Mini-symposia []
# Numerical Methods for Physical Properties Evaluation []
# High Dimensional Approximation for PDEs with random parameters [11]
# Energy geostructures [12, 22, 31]
# Data analysis and model classification []
# Mechanical product design and development [0, 29, 31]
# Energy planning: modeling and decision support systems [8]
# Waterborne Pathogens []
# Mathematics for Financial Economics []
# Cellular biology and biochemistry for engineers [2, 4, 5, 9, 14, 16, 18, 20, 27, 28, 31, 33]
# Smart grids technologies [34]
# Transportation systems engineering []
# Working group in Topology II []
# Networks out of control [34]
# Surface analysis []
# Multi-body simulation [0, 3, 31]
# Accounting for finance []
# Computer architecture []
# Laser Processing of Materials: From Optical Properties of Materials and Light-Matter Interaction to Applications [25]
# Real-time embedded systems [1, 21, 24, 31, 32]
# Robotics practicals [12, 20, 31]
# Practical - Naef Lab [6]
# Optional project in computer science []
# UE W: Reading construction []
# Advanced lab in electrical energy systems [33, 34]
# HF and VHF circuits and techniques II [33]
# Interfaces in biology and nanoscience []
# Practical - Constam Lab [18]
# Dynamic Asset Pricing []
# Microelectronics [26, 29, 33]
# Hydrodynamics []
# Readings in Organization Economics []
# Optics III []
# Gene transfer and recombinant protein expression in animal cells []
# CCMX Advanced Course - Atomic Force Microscopy (AFM): Theory and Practice [10]
# Wave propagation along transmission lines [9]
# CCMX Advanced Course - Combining Structural & Analytical Investigations of Matter at the Micro-, Nano and Atomic Scale- (2016) [18, 29]
# Propagation of acoustic waves [27, 31]
# Food biotechnology [1]
# Derivatives [11, 17, 21, 27]
# Leading and managing in a global context [7, 16, 20, 27, 28, 31]
# Technology ventures in IC []
# Advanced NMR and imaging [25]
# Seminars in Physical Chemistry (1) []
# Optional project in communication systems []
# Effects of radiation on materials [10]
# Advanced compiler construction [26]
# Circuits and systems II [12, 19, 21, 26, 27, 33]
# Cancer Biology I []
# Magnetic confinement []
# Cancer Biology II [20]
# Creative Problem Solving in Science and Engineering []
# Design of Ultra-low Power Wearable Wireless Systems [0, 1, 7, 8, 9, 13, 16, 18, 20, 21, 22, 24, 25, 28, 29, 32, 33, 34]
# Metrology II []
# Summer school on healthcare diagnostics [2]
# Introduction to practical aspects of animal experimentation and animal facilities (Winter) (EDNE) []
# Quantitative methods in finance [3, 9, 11, 17, 19, 21, 27, 33]
# Numerical methods in chemistry [14, 17, 19, 21]
# General physics II []
# Enterprise and service-oriented architecture [33]
# Magnetic materials in modern technologies - from concepts to real devices [6, 12, 26, 29]
# Electromagnetic compatibility []
# Scaling in MEMS []
# Part 4 : Research project in Area and Cultural Studies []
# Biomass conversion []
# Solid waste engineering [0, 1, 2, 3, 5, 6, 7, 8, 9, 10, 12, 13, 14, 16, 18, 20, 22, 23, 24, 25, 27, 31, 32, 33]
# Haptic human robot interfaces []
# Statistical neurosciences [21]
# Student seminar: security protocols and applications []
# Fundamentals of biomedical imaging []
# Information : strategy & economics [27]
# Personal interaction studio [31, 32, 34]
# Total synthesis of natural products []
# Incompressible fluid mechanics []
# Solid state physics II [3, 6, 12]
# Fracture Mechanics and Fatigue of Structures [12]
# HydroPower and Dams: Benefits and Concerns []
# Cryptography and security [21, 27, 34]
# Neurosciences I : molecular neuroscience and neurodegeneration [5]
# Microbial diversity []
# Neurosciences III : behavioral and cognitive neuroscience []
# Seminar series on advances in materials (autumn) []
# Characterization Methods in Materials Science []
# Biomicroscopy I [9, 10, 18, 25]
# Computational physics III [17, 19, 21, 34]
# Lab in microwaves []
# Engineering geology for geo-energy [23]
# Process development I []
# New Concretes for Structures []
# Signals, instruments, and systems [19, 21]
# Introduction to computer graphics [16, 25]
# Probabilistic Coupling []
# Statistical theory [27]
# Time series [21]
# Photonic systems and technology [9, 12, 24, 25, 31]
# Advanced analysis II [19]
# Plasma instabilities []
# Audio engineering []
# Studio BA5 (Fröhlich M. & A.) [32]
# Environmental transport phenomena []
# Advanced machine learning [21, 22, 27]
# Ultrafast phenomena [25]
# Transmission electron microscopy and diffraction (b) [10, 18]
# Water and wastewater treatment [1, 8]
# Bioreactor modeling and simulation [13, 21, 33]
# Physical models for micro and nanosystems []
# Reliability of MEMS (EDOC) []
# Grid and Converter Controls [34]
# Light sources: optical fiber and waveguide lasers [25]
# Integrated optics [9, 25]
# Snow Science Winter School [22, 24]
# Micro and nanostructuration of materials []
# Heat and mass transfer [23]
# Theory of computation []
# General physics III []
# Methods of asymptotic analysis in mechanics []
# Environment chemical and biological technology [8]
# Evolutionary robotics []
# Analysis and modelling of locomotion [1]
# Advanced topics in electromagnetic compatibility []
# Fundamentals of Biometrics []
# Advanced computer architecture []
# Laboratory information management systems (LIMS) []
# Advanced topics in financial econometrics [17]
# Harmonic analysis []
# Fundamentals of biophotonics [3, 9, 12, 18, 21, 25, 31, 33]
# Engineering of musculoskeletal system and rehabilitation []
# Corporate strategy [2, 5, 7, 13, 16, 22, 31]
# Introduction to the finite elements method [17, 21]
# Transient and dynamic analysis of electric power systems []
# Information and Asset Pricing []
# Embedded systems [21, 31]
# Organic semiconductors [6, 18]
# Combinatorial optimization [21]
# Genomics and bioinformatics []
# Advances in Contact Mechanics []
# Crystallography of structural phase transformations [5, 12, 27, 31, 33]
# Advanced analog IC design []
# Computer networks [21, 34]
# Statistical mechanics [13, 27, 31, 34]
# Principles of finance [8, 17, 19, 27]
# Understanding modern Switzerland II []
# Introduction to nuclear engineering [10]
# Information Science in Engineering []
# Applied molecular quantum chemistry [3, 6, 23, 29, 30]
# Symmetry and Conservation in the Cell [0, 3, 4, 14]
# Advanced metallurgy [6, 27]
# Environmental Economics for Engineers []
# Economics of innovation & management in energy []
# Understanding modern Switzerland I [20]
# Communication for Research Engineers []
# Power electronics []
# Current Topics in Chemical Biology 1 [20]
# Applied mechanical design [13, 31, 33]
# Optical Materials: Fundamental concepts and recent developments []
# Presentation skills []
# 3D Electron Microscopy and FIB-Nanotomography []
# Scanning electron microscopy techniques (a) []
# BioMEMS []
# Plasma physics II []
# Lab methods : biosafety []
# Advanced probability and applications [11]
# Sensors in medical instrumentation [29]
# Thermodynamics of energy conversion and storage [3]
# Spacecraft avionics systems, architectures and processors [13, 16, 28, 31]
# General chemistry (English) [1, 3, 4, 6, 8, 14, 26, 27, 29, 30]
# Games for Crowds and Networks []
# Numerical Analysis and Computational Mathematics [17, 21, 27, 31]
# Advanced Microscopy for Life Science []
# Théorie et critique du projet BA3 (De Vylder & Taillieu) []
# Quantum chemistry [3, 29]
# Machine learning programming [22]
# Practical - Meylan Lab [6, 16, 18, 22]
# Brain-computer interaction []
# Academic Writing for Doctoral Students []
# Studio MA2 (Lütjens et Padmanabhan) [32]
# Measuring systems laboratory work []
# Industrial electronics II []
# Efficient Synthetic Routes Towards Bioactive Molecules []
# Atomistic and quantum simulations of materials [3, 6, 29]
# Electronic spectroscopy [6, 29, 31]
# Analysis III []
# Practical - Radtke Lab [6]
# Neuroscience for engineers []
# Mathematics of data: from theory to computation [21, 22, 31, 34]
# Inorganic chemistry "Techniques and methods" []
# Fluid mechanics (for SIE) [23]
# Bioinorganic chemistry []
# Bioanalytics and analytical sensors []
# Physics of photonic semiconductor devices [25]
# Project in Biotechnology []
# Digital Speech and Audio Coding []
# Foundations of software []
# Current Topics in Distributed Systems []
# Industrial automation [24]
# Lab immersion II [7, 20, 21, 22, 24, 33]
# Project in molecular sciences [20]
# Stellar evolution and nucleosynthesis (UNIGe) []
# Data science for business [7, 8, 13, 20, 21, 22, 24, 27, 33, 34]
# Asset Pricing []
# Quantum optics and quantum information [3]
# Analysis of ancient materials and their degradation []
# Advanced steel design [15]
# Recent Events in Energy-2 []
# Spatial statistics and analysis []
# Process development project []
# Semester project in Bioengineering [20, 21, 22, 24, 31, 33]
# Applied wastewater engineering [8, 33]
# Life cycle engineering of polymers [5, 7, 13, 24, 31]
# Introduction to electronic structure methods [3, 6, 21, 26, 31, 34]
# CCMX Summer School - Multiscale Modelling of Materials (2016) [12, 31]
# Introduction to nanomaterials [24]
# CCMX Winter School Surface Science and Coatings []
# Advanced electroanalytical chemistry I []
# Basic principles of drug action at the nervous system []
# Quantitative risk management []
# Statistics for genomic data analysis [24]
# Advanced bioengineering methods laboratory [20, 22]
# Scientific project design in translational oncology [16]
# Optics I []
# Analysis I (English) []
# Convex optimization and applications [21]
# Venture capital [17]
# Advanced energetics [3, 12, 13, 23]
# General physics I (English) [3]
# Scientific literature analysis in Bioengineering [7, 16, 20, 22, 24, 28, 31, 32, 33]
# Biological chemistry III []
# Tissue engineering [5, 18]
# Localization and Navigation Methods [9, 34]
# Advanced biomedical imaging methods and instrumentation []
# Scientific project design in synthetic biology (iGEM) []
# Modelling, optimisation, design and analysis of integrated energy systems []
# Discrete optimization [21]
# HF and VHF circuits and techniques I [33]
# Scientific project design in regenerative medicine and diagnostics []
# Neutronics [10]
# Qualitative Research Methods []
# Numerical flow simulation [0, 6, 7, 12]
# Reactor Experiments []
# Practical - Van der Goot Lab []
# Biomaterials [2, 4, 5, 12, 13, 16, 18, 25, 31]
# Optical detectors [9, 18, 25, 26, 29]
# Introduction to cellular and molecular biotechnology []
# Optimal control [21]
# Project in computer science II []
# Image processing I [19]
# Biomineralization: from nature to application [12, 14, 20, 24, 28]
# Philosophy of life sciences II [13, 20, 33]
# Spacecraft design and system engineering []
# CCMX Advanced Course - Inorganic Particle Synthesis by Precipitation: From Nanoparticles to Self-organised  Mesocrystals and from Theory to Practice []
# Lectures in Life Sciences []
# Introductory course about Spatial Statistics []
# Mathematical methods for physicists [17, 21]
# Selected topics in mechanics of solids and structures [2]
# Martingales in financial mathematics [17, 27]
# Computational Social Media [0, 22]
# Analog circuits design I []
# Advanced numerical analysis [17, 21]
# Aerodynamics []
# Catalyst design for synthesis [1, 14]
# General physics (English) II [3]
# Frontiers in Chemical Synthesis. Towards Sustainable Chemistry [1]
# Science and Engineering Teaching and Learning [5, 7, 15, 20, 22, 31, 32, 33]
# B2B - high-tech marketing [2, 5, 7, 16, 27]
# Measuring systems [20]
# Working Group in Algebraic Groups, I []
# Principles of microeconomics [16, 27, 28]
# Software-defined radio: A hands-on course []
# Cognitive psychology B [7, 20, 22, 24, 28]
# Modelling problem solving, computing and visualisation I []
# Optimization Methods and Models [21]
# Nanocomputing: Devices, Circuits and Architectures [26]
# Two-phase flows and heat transfer [23]
# Theory of materials : from structures to properties []
# Technology and Public Policy - (a) Science, technology and society []
# Computation of molecular properties []
# Microbiology [31]
# Analog circuits design II []
# MINTT: Management of Innovation and technology transfer (EDOC) [2, 5, 7, 12, 13, 16, 20, 24, 28, 31]
# Advanced multiprocessor architecture [22]
# Single cell genomics []
# Advanced electroanalytical chemistry (II session) []
# Computational linear algebra [21]
# Additive Combinatorics []
# Production management [7, 13, 16, 31, 32]
# Packing and covering [21]
# Research project in materials II [20]
# Molecular quantum dynamics [3, 6]
# System Identification [20]
# Stochastic calculus II [17, 19]
# Biophysics I [4]
# CCMX Winter School - Nanoparticles: From Fundamentals to Applications in Life Sciences []
# Basic principles of drug action at the cardiovascular system []
# Commutative algebra []
# Sustainability assessment [5, 7, 13, 16, 20, 31, 32, 33]
# Chemical kinetics [6, 30]
# Decision-aid methodologies in transportation [21, 22, 31]
# Introduction to environmental engineering [8, 14]
# Entrepreneurship & new venture strategy (a) [7]
# Renewable energy (for ME) [3, 29]
# Physical and computational organic chemistry [1, 14, 30]
# Signal processing for functional brain imaging [21]
# Design technologies for integrated systems [13, 21, 26]
# Structural stability [15, 21, 27]
# Translational Robotics for Clinical Rehabilitation [31]
# Microwaves []
# Convexity [21]
# Introduction to finance (IF master and minor only) [2, 5, 7, 8, 13, 17, 27]
# Practical - Blokesch Lab [6]
# Scientific programming for Engineers []

# %% [markdown]
# ## Exercise 4.9: Dirichlet hyperparameters

# %% [markdown]
# ## Exercise 4.10: EPFL's taught subjects

# %% [markdown]
# ## Exercise 4.11: Wikipedia structure
