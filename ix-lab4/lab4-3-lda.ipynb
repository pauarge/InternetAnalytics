# %% [markdown]
# # Text 3: Latent Dirichlet allocation
# **Internet Analytics - Lab 4**
#
# ---
#
# **Group:** *O*
#
# **Names:**
#
# * *Argelaguet Franquelo, Pau*
# * *du Bois de Dunilac, Vivien*
#
# ---
#
# #### Instructions
#
# *This is a template for part 3 of the lab. Clearly write your answers, comments and interpretations in Markodown cells. Don't forget that you can add $\LaTeX$ equations in these cells. Feel free to add or remove any cell.*
#
# *Please properly comment your code. Code readability will be considered for grading. To avoid long cells of codes in the notebook, you can also embed long python functions and classes in a separate module. Don’t forget to hand in your module if that is the case. In multiple exercises, you are required to come up with your own method to solve various problems. Be creative and clearly motivate and explain your methods. Creativity and clarity will be considered for grading.*

# %%
from pyspark.mllib.clustering import LDA, LDAModel
from pyspark.mllib.linalg import Vectors

import json
import pickle
import numpy as np
import string
import collections
import operator
import math

from functools import reduce
from scipy.sparse import csr_matrix
from utils import load_json, load_pkl, save_pkl

# %%
courses = load_json('data/courses.txt')
preprocessed = load_pkl('data/preprocess.pckl')
terms = load_pkl('data/terms.pckl')

# %%
mat = load_pkl('data/mat.pckl')
doc = load_pkl('data/documents.pckl')
stopwords = load_pkl('data/stopwords.pkl')

# %% [markdown]
# ## Exercise 4.8: Topics extraction

# %%
# Creates a dense vector containing (wordIndex, wordCount) pairs from a dict of (word, wordCount) k,v pairs
# The index of the word is its index in the alphabet
def createTermVector(bagOfWord):
    countList = []
    for term in terms:
        countList.append(bagOfWord.get(term, 0))
    return Vectors.dense(countList)

# %%
# For each topic of the model print the nWords top words
def pTop(ldaModel, nWords=10):
    for topic in ldaModel.describeTopics():
        termList = []
        for i in range(nWords):
            termList.append(terms[topic[0][i]])
        print(termList)

# %%
# Create an rdd of term vectors for the documents
vectorList = []
counter = 1
for it in list(preprocessed.items()):
    vectorList.append([counter, createTermVector(it[1]['description'])])
    counter += 1
rdd = sc.parallelize(vectorList)

# %%
# Extract 10 topics with default parameters
ldaModel = LDA.train(rdd, k=10)
pTop(ldaModel)
# Out:
# ['case', 'risk', 'manag', 'innov', 'studi', 'exam', 'assess', 'class', 'market', 'evalu']
# ['structur', 'program', 'algorithm', 'comput', 'solut', 'properti', 'languag', 'cell', 'machin', 'techniqu']
# ['statist', 'cell', 'linear', 'probabl', 'biolog', 'mass', 'engin', 'time', 'data', 'physic']
# ['report', 'data', 'skill', 'energi', 'evalu', 'numer', 'problem', 'laboratori', 'heat', 'optim']
# ['chemic', 'chemistri', 'electron', 'reaction', 'organ', 'product', 'thermodynam', 'kinet', 'engin', 'theori']
# ['engin', 'space', 'introduct', 'integr', 'dure', 'theori', 'stochast', 'differenti', 'equat', 'differ']
# ['structur', 'research', 'circuit', 'test', 'mechan', 'energi', 'architectur', 'session', 'develop', 'speech']
# ['paper', 'control', 'dynam', 'protein', 'molecular', 'quantum', 'robot', 'discuss', 'oral', 'biolog']
# ['optic', 'laser', 'applic', 'control', 'communic', 'power', 'physic', 'network', 'digit', 'signal']
# ['imag', 'magnet', 'physic', 'develop', 'applic', 'technolog', 'teach', 'techniqu', 'sensor', 'comput']

# %% [markdown]
# With the default parameters we get topics that are not very precise. Some of them cumulate several subjects while others contain words that have little significance like 'semest', 'includ' and 'scientif'. Overall LSI seems to perform better than LDA with its default parameters, the topics obtained by LSI are more precise and do not group completely unrelated words together.
#
# Labels for the LDA topics could be:
# 1. Physics
# 2. General Engineering
# 3. Data and statistics
# 4. Biology and chemistry
# 5. Risks, management
# 6. Electronics and robotics
# 7. Imagery
# 8. Biology
# 9. Optics
# 10. Computing and signal processing

# %% [markdown]
# ## Exercise 4.9: Dirichlet hyperparameters

# %% [markdown]
# ### Variying ALPHA
#
# The alpha parameter is the parameter of the prior distribution of topics per document. Increasing alpha means searching for topics more uniformly accross the documents (more topics per document).

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=1.01, seed=10)
pTop(ldaModel)
# Out:
# ['architectur', 'reaction', 'develop', 'organ', 'chemistri', 'differ', 'studi', 'assess', 'semest', 'comput']
# ['biolog', 'cell', 'chemic', 'protein', 'engin', 'structur', 'molecular', 'develop', 'research', 'cancer']
# ['optic', 'laser', 'technolog', 'architectur', 'applic', 'wast', 'electron', 'principl', 'theori', 'physic']
# ['physic', 'paper', 'electron', 'chemic', 'organ', 'properti', 'techniqu', 'week', 'applic', 'transport']
# ['signal', 'imag', 'equat', 'filter', 'engin', 'theori', 'problem', 'chemistri', 'applic', 'data']
# ['energi', 'heat', 'circuit', 'transfer', 'risk', 'convers', 'principl', 'molecular', 'assess', 'metal']
# ['report', 'scientif', 'mechan', 'skill', 'experiment', 'structur', 'laboratori', 'electron', 'problem', 'evalu']
# ['algorithm', 'comput', 'problem', 'linear', 'numer', 'optim', 'simul', 'case', 'theori', 'studi']
# ['microscopi', 'imag', 'optic', 'theori', 'electron', 'introduct', 'structur', 'fourier', 'stochast', 'applic']
# ['data', 'control', 'program', 'magnet', 'activ', 'assess', 'problem', 'group', 'class', 'evalu']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=3.0, seed=10)
pTop(ldaModel)
# Out:
# ['reaction', 'develop', 'architectur', 'differ', 'data', 'assess', 'communic', 'semest', 'studi', 'chemistri']
# ['biolog', 'cell', 'protein', 'chemic', 'engin', 'develop', 'research', 'molecular', 'robot', 'practic']
# ['optic', 'laser', 'architectur', 'technolog', 'reactor', 'principl', 'applic', 'theori', 'solid', 'wast']
# ['paper', 'chemic', 'organ', 'physic', 'network', 'techniqu', 'week', 'electron', 'busi', 'industri']
# ['equat', 'signal', 'engin', 'imag', 'theori', 'filter', 'space', 'problem', 'differenti', 'chemistri']
# ['energi', 'heat', 'report', 'technolog', 'circuit', 'transfer', 'molecular', 'thermodynam', 'assess', 'risk']
# ['mechan', 'electron', 'report', 'structur', 'skill', 'experiment', 'scientif', 'flow', 'properti', 'measur']
# ['algorithm', 'comput', 'linear', 'numer', 'problem', 'optim', 'simul', 'program', 'case', 'studi']
# ['optic', 'microscopi', 'stochast', 'imag', 'theori', 'introduct', 'applic', 'fourier', 'electron', 'financi']
# ['data', 'control', 'magnet', 'program', 'plan', 'group', 'dure', 'problem', 'session', 'activ']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=5.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'reaction', 'develop', 'communic', 'differ', 'architectur', 'assess', 'semest', 'research', 'studi']
# ['biolog', 'cell', 'protein', 'chemic', 'engin', 'develop', 'teach', 'research', 'practic', 'robot']
# ['optic', 'laser', 'architectur', 'technolog', 'reactor', 'principl', 'manag', 'solid', 'theori', 'state']
# ['paper', 'chemic', 'organ', 'physic', 'week', 'techniqu', 'industri', 'network', 'busi', 'electron']
# ['equat', 'engin', 'imag', 'signal', 'theori', 'space', 'problem', 'filter', 'chemistri', 'differenti']
# ['energi', 'report', 'heat', 'molecular', 'technolog', 'thermodynam', 'transfer', 'circuit', 'evalu', 'assess']
# ['mechan', 'electron', 'structur', 'skill', 'flow', 'report', 'measur', 'properti', 'experiment', 'scientif']
# ['algorithm', 'comput', 'linear', 'numer', 'problem', 'optim', 'program', 'simul', 'case', 'studi']
# ['optic', 'stochast', 'microscopi', 'introduct', 'theori', 'applic', 'imag', 'fourier', 'financi', 'price']
# ['data', 'control', 'magnet', 'plan', 'group', 'dure', 'problem', 'session', 'activ', 'studi']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=7.5, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'communic', 'reaction', 'develop', 'differ', 'assess', 'architectur', 'signal', 'research', 'semest']
# ['biolog', 'cell', 'chemic', 'engin', 'protein', 'develop', 'teach', 'practic', 'scienc', 'robot']
# ['optic', 'laser', 'architectur', 'technolog', 'manag', 'reactor', 'integr', 'polici', 'solid', 'principl']
# ['paper', 'organ', 'chemic', 'techniqu', 'week', 'structur', 'electron', 'physic', 'industri', 'busi']
# ['equat', 'engin', 'theori', 'imag', 'risk', 'space', 'problem', 'chemistri', 'signal', 'probabl']
# ['energi', 'report', 'molecular', 'heat', 'transfer', 'evalu', 'thermodynam', 'technolog', 'research', 'assess']
# ['mechan', 'electron', 'structur', 'flow', 'report', 'experiment', 'measur', 'skill', 'properti', 'scientif']
# ['algorithm', 'comput', 'linear', 'numer', 'problem', 'simul', 'program', 'control', 'studi', 'case']
# ['optic', 'stochast', 'microscopi', 'introduct', 'applic', 'fourier', 'structur', 'theori', 'financi', 'physic']
# ['data', 'magnet', 'group', 'plan', 'dure', 'control', 'innov', 'session', 'problem', 'studi']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=10.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'communic', 'reaction', 'differ', 'develop', 'assess', 'signal', 'architectur', 'research', 'semest']
# ['biolog', 'cell', 'chemic', 'engin', 'protein', 'develop', 'teach', 'practic', 'scienc', 'robot']
# ['laser', 'optic', 'architectur', 'technolog', 'manag', 'reactor', 'polici', 'solid', 'integr', 'generat']
# ['organ', 'paper', 'structur', 'chemic', 'techniqu', 'electron', 'week', 'applic', 'busi', 'optim']
# ['engin', 'equat', 'theori', 'risk', 'imag', 'probabl', 'space', 'chemistri', 'problem', 'differenti']
# ['energi', 'report', 'molecular', 'heat', 'transfer', 'evalu', 'thermodynam', 'research', 'technolog', 'comput']
# ['electron', 'mechan', 'structur', 'report', 'flow', 'experiment', 'scientif', 'skill', 'measur', 'properti']
# ['algorithm', 'comput', 'linear', 'numer', 'problem', 'simul', 'control', 'program', 'case', 'studi']
# ['optic', 'stochast', 'microscopi', 'applic', 'introduct', 'properti', 'mechan', 'physic', 'fourier', 'electron']
# ['data', 'magnet', 'group', 'plan', 'dure', 'innov', 'session', 'control', 'problem', 'studi']

# %% [markdown]
# We can observe that a low value of alpha results in topics that are very different from each other but they do not always make intuitive sense. Several subjects end up in the same topic because the algorithm thinks that the probability of there being more than one topic in a document is very low.
#
# A high value of alpha gives more mixed topics. The algorithm creates topics for words of little meaning because it tries to find too many topics in some documents. A balance needs to be found between identifying too few or too many topics in the documents to produce meaningful topics.

# %% [markdown]
# ### Variying BETA
#
# The beta parameter is the parameter of the prior distribution of words per topics. Increasing beta means considering that more words of a document belong to its topics.

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=6.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'communic', 'reaction', 'develop', 'differ', 'assess', 'architectur', 'research', 'semest', 'signal']
# ['biolog', 'cell', 'protein', 'chemic', 'engin', 'develop', 'practic', 'teach', 'research', 'scienc']
# ['optic', 'laser', 'architectur', 'technolog', 'reactor', 'manag', 'principl', 'solid', 'integr', 'state']
# ['paper', 'chemic', 'organ', 'physic', 'week', 'techniqu', 'industri', 'electron', 'busi', 'structur']
# ['equat', 'engin', 'theori', 'imag', 'signal', 'space', 'problem', 'chemistri', 'differenti', 'filter']
# ['energi', 'report', 'heat', 'molecular', 'technolog', 'thermodynam', 'transfer', 'evalu', 'circuit', 'assess']
# ['mechan', 'electron', 'structur', 'flow', 'skill', 'report', 'measur', 'properti', 'experiment', 'scientif']
# ['algorithm', 'comput', 'linear', 'numer', 'problem', 'simul', 'program', 'optim', 'case', 'studi']
# ['optic', 'stochast', 'microscopi', 'introduct', 'applic', 'fourier', 'theori', 'financi', 'structur', 'imag']
# ['data', 'magnet', 'control', 'group', 'plan', 'dure', 'problem', 'innov', 'session', 'activ']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=3.0, docConcentration=6.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'architectur', 'electron', 'circuit', 'techniqu', 'comput', 'structur', 'problem', 'research', 'applic']
# ['biolog', 'protein', 'chemic', 'cell', 'molecular', 'structur', 'mechan', 'physic', 'function', 'applic']
# ['optic', 'laser', 'principl', 'physic', 'applic', 'technolog', 'activ', 'architectur', 'theori', 'wast']
# ['structur', 'week', 'mechan', 'equat', 'electron', 'numer', 'applic', 'stabil', 'paper', 'theori']
# ['imag', 'signal', 'applic', 'theori', 'structur', 'physic', 'comput', 'problem', 'techniqu', 'algorithm']
# ['report', 'engin', 'evalu', 'data', 'assess', 'plan', 'research', 'technolog', 'problem', 'skill']
# ['mechan', 'structur', 'problem', 'comput', 'electron', 'chemic', 'reaction', 'theori', 'organ', 'molecular']
# ['energi', 'risk', 'problem', 'linear', 'applic', 'comput', 'studi', 'control', 'theori', 'techniqu']
# ['cell', 'structur', 'biolog', 'theori', 'electron', 'applic', 'mechan', 'physic', 'properti', 'stochast']
# ['data', 'assess', 'develop', 'control', 'program', 'evalu', 'architectur', 'algorithm', 'group', 'problem']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=5.0, docConcentration=6.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'structur', 'problem', 'applic', 'comput', 'assess', 'electron', 'theori', 'activ', 'techniqu']
# ['structur', 'biolog', 'applic', 'cell', 'physic', 'mechan', 'data', 'chemic', 'theori', 'activ']
# ['optic', 'applic', 'physic', 'laser', 'activ', 'theori', 'energi', 'assess', 'evalu', 'problem']
# ['structur', 'data', 'applic', 'problem', 'electron', 'energi', 'mechan', 'comput', 'assess', 'theori']
# ['structur', 'applic', 'problem', 'theori', 'physic', 'imag', 'comput', 'data', 'mechan', 'assess']
# ['data', 'report', 'engin', 'evalu', 'assess', 'problem', 'energi', 'activ', 'technolog', 'applic']
# ['structur', 'problem', 'theori', 'mechan', 'comput', 'applic', 'data', 'assess', 'activ', 'evalu']
# ['energi', 'problem', 'applic', 'comput', 'assess', 'structur', 'activ', 'evalu', 'theori', 'control']
# ['structur', 'cell', 'applic', 'electron', 'theori', 'mechan', 'physic', 'biolog', 'activ', 'chemic']
# ['data', 'assess', 'problem', 'evalu', 'energi', 'activ', 'applic', 'comput', 'structur', 'theori']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=7.0, docConcentration=6.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'structur', 'problem', 'applic', 'assess', 'activ', 'comput', 'evalu', 'theori', 'electron']
# ['structur', 'applic', 'data', 'problem', 'physic', 'assess', 'activ', 'biolog', 'energi', 'mechan']
# ['optic', 'applic', 'energi', 'activ', 'assess', 'problem', 'structur', 'evalu', 'theori', 'data']
# ['data', 'structur', 'problem', 'applic', 'energi', 'assess', 'comput', 'evalu', 'activ', 'electron']
# ['structur', 'applic', 'problem', 'data', 'theori', 'comput', 'assess', 'physic', 'activ', 'mechan']
# ['data', 'problem', 'evalu', 'energi', 'assess', 'engin', 'report', 'activ', 'applic', 'comput']
# ['structur', 'problem', 'data', 'applic', 'assess', 'evalu', 'activ', 'comput', 'theori', 'mechan']
# ['energi', 'problem', 'applic', 'structur', 'assess', 'activ', 'evalu', 'comput', 'data', 'theori']
# ['structur', 'applic', 'theori', 'physic', 'electron', 'mechan', 'problem', 'optic', 'activ', 'assess']
# ['data', 'problem', 'assess', 'applic', 'energi', 'structur', 'evalu', 'activ', 'comput', 'theori']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=10.0, docConcentration=6.0, seed=10)
pTop(ldaModel)
# Out:
# ['data', 'structur', 'problem', 'applic', 'assess', 'activ', 'evalu', 'energi', 'comput', 'theori']
# ['structur', 'data', 'applic', 'problem', 'assess', 'energi', 'activ', 'evalu', 'theori', 'comput']
# ['optic', 'applic', 'data', 'problem', 'structur', 'assess', 'energi', 'activ', 'evalu', 'theori']
# ['data', 'structur', 'problem', 'applic', 'assess', 'energi', 'activ', 'evalu', 'comput', 'theori']
# ['data', 'structur', 'applic', 'problem', 'assess', 'activ', 'theori', 'comput', 'evalu', 'physic']
# ['data', 'problem', 'applic', 'assess', 'energi', 'evalu', 'structur', 'activ', 'engin', 'comput']
# ['data', 'structur', 'problem', 'applic', 'assess', 'evalu', 'activ', 'comput', 'theori', 'optic']
# ['energi', 'problem', 'applic', 'structur', 'data', 'assess', 'activ', 'evalu', 'comput', 'theori']
# ['structur', 'applic', 'problem', 'assess', 'theori', 'activ', 'data', 'energi', 'evalu', 'physic']
# ['data', 'problem', 'structur', 'applic', 'assess', 'energi', 'evalu', 'activ', 'comput', 'theori']

# %% [markdown]
# With a low value of beta we can see that the topics are very different from one another for the five most significant words. For less significant words they make less sense and share many words. This makes sense because a low value of beta means that only the most frequent words in each document are considered meaningful.
#
# With a high value of beta the topics become more similar. This makes sense as well because considering too many words as being important will add meaningless words to the topics. A balance needs to be found between making sure that all of the important words are considered as such and making sure that no meaningless words are considered important.

# %% [markdown]
# ## Exercise 4.10: EPFL's taught subjects

# %% [markdown]
# ### Optimized parameters

# %%
# k = number of topics, alpha(doc) higher alpha means more different topics per document
# beta(topic) higher beta means more words per topic
ldaModel = LDA.train(rdd, k=12, docConcentration=1.8, topicConcentration=3.5, seed=10)

# print the top x terms for each topic
pTop(ldaModel, 10)
# Out:
# ['electron', 'microscopi', 'spectroscopi', 'electron microscopi', 'devic', 'forc', 'print', 'scan', 'transmiss electron', 'polici']
# ['data', 'problem', 'optim', 'statist', 'program', 'linear', 'exam', 'skill', 'evalu', 'teach']
# ['circuit', 'analog', 'convert', 'rf', 'diffract', 'amplifi', 'nois', 'tem', 'transistor', 'mos']
# ['cell', 'chemic', 'chemistri', 'reaction', 'organ', 'molecular', 'structur', 'kinet', 'note', 'biolog']
# ['optic', 'control', 'signal', 'applic', 'communic', 'laser', 'sensor', 'principl', 'activ', 'practic']
# ['energi', 'heat', 'power', 'transfer', 'thermodynam', 'reactor', 'convers', 'mass', 'main', 'principl']
# ['biolog', 'research', 'structur', 'discuss', 'report', 'scientif', 'paper', 'week', 'semest', 'evalu']
# ['equat', 'theori', 'comput', 'function', 'physic', 'flow', 'mechan', 'numer', 'stochast', 'algorithm']
# ['imag', 'magnet', 'speech', 'recognit', 'applic', 'code', 'plasma', 'digit', 'techniqu', 'magnet materi']
# ['quantum', 'parallel', 'algorithm', 'memori', 'interact', 'cmos', 'comput', 'theori', 'field', 'transistor']
# ['develop', 'assess', 'manag', 'studi', 'technolog', 'architectur', 'case', 'class', 'engin', 'risk']
# ['verif', 'hardwar', 'brain', 'univers', 'languag', 'vhdl', 'mixedsign', 'evolut', 'lens', 'day']

# %% [markdown]
# After some testing we found values for alpha and beta that produce twelve relatively meaningful topics. Labels for those topics are :
# 1. Imagery
# 2. Data
# 3. Electronics
# 4. Biology and chemistry
# 5. Optics
# 6. Thermodynamics
# 7. Research, scientific methodology
# 8. Maths
# 9. Image and speech processing
# 10. Computing
# 11. Management
# 12. Hardware and metabolism
#
# The first eleven are all meaningful and coherent, they do not seem to contain out of topic words and do not overlap, but the twelfth topic looks like a mixup between computer hardware and biology.

# %%
topicLabels = dict(zip(range(12), ['Imagery','Data','Electronics','Bio/Chem','Optics','Thermodynamics','Research',
                                  'Math','Image/Speech processing','Computing','Management','Hardware/Brain?']))

# %%
tm = ldaModel.topicsMatrix()

# %% [markdown]
# These next cells will compute a score for each topic/course pair and display a list of the top topics for every course.

# %%
# Compute a score for each topic/course pair
# The score is the sum of the bag of words' terms multiplied by their weight in the model's topic matrix
# normalized by the number of words
def computeTopicScores(topicsMatrix, bagOfWords):
    topicScores = np.zeros(topicsMatrix.shape[1])
    wordCount = 0
    for i in range(topicsMatrix.shape[0]):
        occ = bagOfWords.get(terms[i], 0)
        wordCount += occ
        for j in range(topicsMatrix.shape[1]):
            topicScores[j] += occ * topicsMatrix[i][j]
    
    return topicScores / wordCount

# Create a list of courses with a sorted list of topics indices and scores
def associateTopicScores(topicsMatrix):
    res = list()
    for k,v in preprocessed.items():
        scores = computeTopicScores(topicsMatrix, v['description'])
        res.append((v['name'], sorted(list(zip(list(range(topicsMatrix.shape[1])), scores)), key=lambda x:x[1])))
        
    return res

# Print all the topics that have a score above the given threshold or the best topic if none satisfy the threshold
def printCourse(course, thresh = 10):
    tList = []
    for tup in course[1]:
        if tup[1] > thresh:
            tList.append(tup)
    if len(tList) > 0:
        print(course[0], "->", list(map(lambda x: topicLabels[x[0]], sorted(tList, key=lambda x:x[1], reverse=True))))
    else:
        print(course[0], "->", topicLabels[course[1][-1][0]])

# %%
courseToScores = associateTopicScores(tm)

# %%
print("List of courses with top topics for each of them \n")
for c in courseToScores:
    printCourse(c)
# Out:
# List of courses with top topics for each of them
#
# Composites technology -> ['Management', 'Data', 'Optics']
# Image Processing for Life Science -> ['Data', 'Image/Speech processing', 'Optics']
# Global business environment -> ['Management', 'Data']
# Electrochemical nano-bio-sensing and bio/CMOS interfaces -> Imagery
# Structural mechanics (for MT) -> ['Data', 'Research']
# Théorie et critique du projet MA2 (Boltshauser) -> ['Management', 'Research', 'Data']
# Advanced principles and applications of systems biology -> ['Data', 'Research', 'Optics', 'Math', 'Management']
# Mass spectrometry -> ['Math', 'Research', 'Data', 'Thermodynamics', 'Bio/Chem']
# Principles of digital communications -> ['Optics', 'Math']
# Hardware systems modeling I -> Math
# Quantitative systems modeling techniques -> ['Data', 'Research', 'Math', 'Management', 'Optics']
# Medical radiation physics -> ['Optics', 'Image/Speech processing', 'Math']
# Bio-nano-chip design -> ['Imagery', 'Bio/Chem']
# Principles of powder and densification processing -> ['Management']
# Fundamentals of solid-state materials -> ['Imagery', 'Optics', 'Math', 'Management', 'Bio/Chem', 'Research']
# Microeconomics -> ['Data', 'Math', 'Optics', 'Management']
# Polymer chemistry and macromolecular engineering -> ['Bio/Chem', 'Management', 'Research', 'Optics']
# Physical chemistry of polymeric materials -> ['Bio/Chem', 'Research', 'Math', 'Management']
# Fundamentals of neuroengineering -> ['Data', 'Research', 'Management', 'Optics']
# In Silico neuroscience -> ['Data', 'Math', 'Management', 'Research']
# Materials selection -> ['Management', 'Data', 'Research', 'Math']
# Optics laboratories I -> ['Optics', 'Data', 'Management', 'Math', 'Research']
# Fracture mechanics -> ['Math', 'Data', 'Research', 'Management', 'Thermodynamics']
# Air pollution and climate change
#  -> ['Data', 'Management']
# Philosophy of life sciences I -> ['Data', 'Management', 'Research']
# Lab methods : proteomics -> ['Data', 'Optics', 'Math', 'Research']
# Cementitious materials (advanced) -> ['Research', 'Management', 'Data', 'Optics']
# Material and energy flow analysis -> ['Data', 'Management']
# Linear algebra (english) -> ['Data', 'Optics', 'Math']
# Transport phenomena II -> ['Thermodynamics', 'Math', 'Management', 'Data']
# Printed systems and large area manufacturing -> ['Management', 'Optics', 'Imagery']
# Theoretical computer science -> ['Math', 'Data', 'Optics']
# Philosophy, epistemology and history of science I -> ['Data', 'Math', 'Management', 'Research', 'Optics']
# Reservoir mechanics for geo-energy and the environment -> ['Math', 'Management', 'Research', 'Data']
# Non linear analysis of structures -> ['Research', 'Math', 'Data']
# Investments -> ['Management', 'Math', 'Data']
# Engines and fuel cells -> ['Thermodynamics', 'Bio/Chem', 'Management', 'Data']
# Recycling of materials -> ['Data', 'Management', 'Research']
# Statistical signal and data processing through applications -> ['Optics', 'Data', 'Math']
# Analysis II (English) -> ['Math', 'Data']
# Technology & innovation strategy -> ['Management', 'Data', 'Research']
# Lab immersion I -> ['Data', 'Research', 'Management', 'Optics', 'Math']
# Internet analytics -> ['Data', 'Math', 'Optics']
# Supply chain management -> ['Management', 'Data', 'Optics']
# Particle-based methods -> ['Math', 'Data', 'Management']
# Statistical Sequence Processing -> ['Data', 'Optics']
# Solid state image sensing -> ['Optics', 'Data']
# Soft matter -> ['Bio/Chem', 'Research']
# Advanced regression -> ['Data', 'Math']
# Introduction to database systems -> ['Data', 'Management', 'Optics', 'Research']
# Hydraulic turbomachines -> ['Management']
# Design and analysis of experiments in materials science and engineering -> ['Data']
# Business design for IT services -> ['Management', 'Data']
# Some problems in the theory of simple groups -> ['Data', 'Management', 'Math', 'Research', 'Optics']
# Simulation and optimisation of industrial applications -> ['Management', 'Data', 'Optics', 'Math']
# Biomicroscopy II -> ['Optics']
# Modelling problem solving, computing and visualisation II -> ['Data', 'Management', 'Math', 'Research']
# Frontiers in Organic Synthesis. Part III Stereochemistry -> ['Bio/Chem', 'Research', 'Management']
# Photonic micro- and nanosystems -> ['Optics', 'Management']
# Safety of chemical processes -> ['Management', 'Data']
# Probabilities and statistics -> ['Data', 'Math']
# Practical - Fellay Lab -> ['Data', 'Bio/Chem']
# CCMX Winter School - Metal Science -> ['Management', 'Math', 'Optics', 'Data']
# Mobile robots -> ['Optics', 'Management', 'Data']
# Leading research in Chemical Engineering (a) -> ['Research', 'Bio/Chem', 'Management', 'Thermodynamics']
# Fluvial biogeosciences -> ['Research', 'Data', 'Management']
# Biochemistry II -> ['Research', 'Bio/Chem', 'Management']
# Micro-magnetic field sensors and actuators -> ['Optics', 'Image/Speech processing', 'Management', 'Research']
# Diffraction methods in structural biology -> ['Imagery', 'Research', 'Optics']
# Practical - Gönczy Lab -> ['Bio/Chem', 'Math']
# Principles and Practicals in X-Ray Scattering -> Imagery
# Frederic Joliot/Otto Hahn Summer School on nuclear reactors Physics, fuels and systems -> ['Thermodynamics', 'Optics']
# Computational finance -> ['Math', 'Data', 'Optics', 'Management']
# Applied stochastic processes -> ['Math', 'Data']
# Structure and evolution of galaxies (UNIGe) -> ['Research', 'Math', 'Bio/Chem']
# Numerical integration  of stochastic differential equations -> ['Math', 'Data']
# Immunology -> ['Research', 'Data', 'Management']
# Thin film fabrication processes -> ['Management', 'Data', 'Optics', 'Math', 'Research', 'Bio/Chem']
# Studio MA1 (Lütjens et Padmanabhan) -> ['Management', 'Research']
# Théorie et critique du projet MA1 (Huang) -> ['Management', 'Data']
# Biomedical signal processing -> ['Optics', 'Data']
# Current Topics in Chemical Biology 2 -> ['Research', 'Bio/Chem', 'Management']
# Physics and hydrology of snow -> ['Math', 'Optics', 'Bio/Chem']
# Nuclear magnetic resonance -> ['Bio/Chem', 'Optics', 'Image/Speech processing']
# Limestone-Calcined Clay - Cement : Characterisation methods -> Management
# Advanced materials for photovoltaics and lighting -> ['Management', 'Bio/Chem']
# Nanoelectronics -> ['Management', 'Optics', 'Math', 'Imagery']
# PhD Masterclass - The horizontal metropolis and other research questions -> ['Research', 'Management']
# Mapping urban history -> ['Management', 'Data']
# Topics in Autonomous Robotics -> ['Optics', 'Research']
# Speech processing -> ['Optics', 'Image/Speech processing']
# Mathematical models in supply chain management -> ['Management', 'Research', 'Data']
# Practical - Simanis Lab -> ['Research', 'Bio/Chem']
# Image communication -> ['Optics', 'Image/Speech processing', 'Management', 'Data']
# Plasma Diagnostics in Basic Plasma Physics Devices and Tokamaks: from Principles to Practice -> Data
# Nanophotonics and plasmonics -> ['Optics', 'Data', 'Math', 'Management']
# Computational photography -> ['Optics', 'Data', 'Math', 'Image/Speech processing', 'Management']
# Information literacy for chemists -> ['Research', 'Data', 'Bio/Chem', 'Management']
# Distributed algorithms -> ['Data', 'Math', 'Optics']
# Entrepreneurship laboratory (e-lab) -> ['Management', 'Data']
# Introduction to planetary sciences -> ['Data', 'Research', 'Optics', 'Management']
# Biomedical optics -> ['Optics', 'Research']
# Quality assurance and quality management systems -> ['Data', 'Management', 'Optics']
# Non-destructive evaluation methods -> ['Optics', 'Image/Speech processing', 'Data', 'Math']
# Concepts in ecological engineering -> ['Research', 'Management', 'Data']
# Molecular endocrinology -> ['Research', 'Management', 'Data', 'Math', 'Optics']
# Privacy Protection -> ['Data', 'Management', 'Optics', 'Research', 'Math']
# Synthesis, analysis and verification -> ['Data', 'Management', 'Math', 'Optics', 'Research']
# Chemical engineering lab & project -> ['Bio/Chem', 'Research', 'Data', 'Management', 'Optics']
# Mathematical modelling of DNA -> ['Math', 'Data', 'Optics', 'Research']
# Industry dynamics, models & trends -> ['Management', 'Data', 'Optics', 'Research']
# Optics II -> ['Optics']
# Multivariable control and coordination systems -> ['Optics', 'Data', 'Management', 'Math', 'Research']
# Science and technology of UV-induced polymerization -> ['Research', 'Optics', 'Data', 'Bio/Chem', 'Management']
# Lab methods : animal experimentation -> ['Research']
# Structure and reactivity -> ['Management', 'Bio/Chem']
# Macrofinance -> ['Data', 'Management', 'Math']
# Operations: economics & strategy -> ['Management', 'Data', 'Optics']
# Inorganic chemistry "Applications and spin-offs" -> ['Research', 'Bio/Chem', 'Management']
# Analytic algorithms -> ['Data', 'Math', 'Optics']
# Geomechanics -> ['Management']
# Database systems -> ['Data', 'Math']
# How people learn II -> ['Management', 'Data', 'Research']
# Biomolecular structure and mechanics -> ['Research', 'Math', 'Bio/Chem', 'Data', 'Management', 'Optics']
# Practical - De Palma Lab -> ['Bio/Chem']
# Distributed intelligent systems -> ['Data', 'Optics', 'Management']
# Research project in materials I -> ['Research', 'Data', 'Management', 'Optics', 'Math']
# Nutrition: from molecules to health -> ['Research', 'Management']
# Wood structures, properties and uses -> ['Management', 'Research', 'Math']
# Corporate governance -> ['Management', 'Optics', 'Data']
# Scientific literature analysis in Computational molecular biology -> ['Research', 'Data', 'Management']
# Mechanisms of cell motility -> ['Bio/Chem', 'Research']
# Specialisation project in materials -> ['Research', 'Data', 'Management', 'Optics', 'Math']
# Making structural logic -> ['Management', 'Research']
# Biotechnology lab (for CGC) -> ['Research', 'Bio/Chem']
# Bioprocesses and downstream processing -> ['Management', 'Data', 'Research', 'Optics']
# Algebraic curves and cryptography -> ['Data', 'Math']
# Image and video processing -> ['Optics', 'Image/Speech processing']
# Biochemical engineering -> ['Bio/Chem', 'Management', 'Data']
# Analog circuits for biochip -> ['Optics', 'Data']
# Advanced wireless communications: algorithms and architectures -> ['Optics']
# Numerical methods in biomechanics -> ['Math', 'Management', 'Optics', 'Data']
# Practical - Cole Lab -> ['Bio/Chem', 'Data']
# Functional Data Analysis -> ['Math', 'Data', 'Optics']
# TCP/IP networking -> ['Data', 'Optics', 'Math', 'Research']
# Introduction to particle accelerators -> ['Math', 'Data', 'Optics']
# Technology and Public Policy - (d) Technology policies for grand and global challenges -> ['Data']
# Technology and Public Policy - (b) Technology, policy and regulation -> ['Thermodynamics', 'Management', 'Optics', 'Data']
# Principles of computer systems -> ['Data', 'Optics', 'Math', 'Management']
# Physics and chemistry of the atmosphere -> ['Bio/Chem', 'Data', 'Thermodynamics', 'Management', 'Optics']
# Biomechanics of the musculoskeletal system -> ['Management', 'Math', 'Optics', 'Research']
# Studio BA4 (De Vylder & Taillieu) -> ['Management']
# Practical - Trono Lab -> ['Bio/Chem']
# Highlights in microtechnology -> ['Research']
# Transport phenomena I -> ['Math', 'Thermodynamics']
# International Finance -> ['Data']
# Chemical biology - tools and methods -> ['Research', 'Bio/Chem', 'Data']
# Experimental cognitive psychology I -> ['Data', 'Research', 'Management']
# Topics on Datacenter Design -> ['Math', 'Data', 'Research']
# Mechanical design principles -> ['Research', 'Math', 'Management', 'Data']
# Scanning and Analytical Transmission Electron Microscopy -> ['Imagery']
# Computational perception using multimodal sensors -> Math
# Supramolecular chemistry -> ['Bio/Chem', 'Research']
# Biological modeling of neural networks -> ['Math', 'Data', 'Optics', 'Research']
# Automatic speech processing -> ['Data', 'Optics', 'Image/Speech processing']
# Dielectric properties of materials -> ['Math', 'Optics', 'Research', 'Management', 'Bio/Chem']
# Using Mathematica to analyse and model experimental data -> Data
# Process development II -> ['Management', 'Research', 'Data', 'Optics']
# Large-area electronics: devices and materials -> ['Optics', 'Bio/Chem', 'Math', 'Imagery']
# Chemosensory receptors: Applications for biosensors and medical therapies -> ['Optics']
# Risk management -> ['Management', 'Data', 'Research', 'Optics']
# Distributed information systems -> ['Data', 'Management']
# Mathematical modelling of behavior -> ['Research', 'Data', 'Management']
# Empirical Asset Pricing -> ['Math', 'Research', 'Data', 'Management']
# Risk and energy -> ['Management', 'Thermodynamics', 'Data']
# Coordination chemistry and reactivity of f elements -> ['Bio/Chem', 'Optics', 'Math', 'Management', 'Research', 'Data']
# UE U : Cartography -> ['Data']
# Optional project in Systems engineering -> ['Management', 'Data', 'Thermodynamics', 'Optics', 'Research']
# Energy Regulation (2016) -> ['Thermodynamics', 'Optics', 'Management']
# Computational motor control -> ['Optics', 'Math', 'Data', 'Research']
# Data converter circuits and systems -> ['Data', 'Management', 'Electronics', 'Optics']
# Molecular and cellular biophysic I -> ['Research', 'Bio/Chem']
# Systems and architectures for signal processing -> ['Optics', 'Data', 'Management', 'Math']
# Tokamak Plasma Control -> ['Optics', 'Data']
# Training Rotation (EDMS) -> ['Research']
# Nanotechnology -> ['Math', 'Research', 'Management', 'Optics', 'Bio/Chem', 'Data']
# Metrology I -> ['Optics', 'Data', 'Management']
# Advanced algorithms -> ['Data', 'Math', 'Optics']
# Project in neuroprosthetics -> ['Data', 'Research', 'Management', 'Optics', 'Math']
# Electrochemistry for materials technology -> ['Thermodynamics', 'Management', 'Data', 'Optics', 'Bio/Chem']
# Quantum electrodynamics and quantum optics -> ['Math', 'Optics', 'Computing']
# Scientific literature analysis in molecular and cancer biology -> ['Research', 'Data', 'Management']
# Rings and modules -> ['Optics', 'Math', 'Research']
# Practical - Suter Lab -> ['Bio/Chem', 'Data', 'Research']
# Unsupervised and reinforcement learning in neural networks -> ['Data']
# Optics and technology of liquid crystal displays -> ['Optics', 'Management', 'Data']
# Hot Topics in Cancer Research -> ['Research', 'Bio/Chem']
# Lab in microelectronics -> ['Research', 'Management', 'Data', 'Electronics', 'Optics']
# Linear models -> ['Data', 'Math']
# Principles and applications of systems biology -> ['Data', 'Research', 'Math', 'Management', 'Optics']
# Statistical Physics for Communication and Computer Science -> ['Optics', 'Data', 'Thermodynamics', 'Math']
# Economics of innovation in the biomedical industry -> ['Data', 'Management', 'Math']
# Introduction to transport phenomena -> ['Math', 'Thermodynamics', 'Data']
# Magnetic and semiconducting nanostructures -> ['Imagery', 'Math', 'Image/Speech processing']
# Experimental Geomechanics -> ['Data', 'Optics', 'Management', 'Math', 'Image/Speech processing']
# Experimental cognitive psychology II -> ['Data', 'Management', 'Research', 'Optics']
# Photochemistry I -> ['Bio/Chem', 'Imagery']
# Stem cell biology and technology -> ['Bio/Chem', 'Research']
# Powder technology -> ['Management']
# Credit risk -> ['Management', 'Math', 'Research']
# Parabolic and hyperbolic PDE's -> ['Math']
# Powder Characterisation and Dispersion -> ['Data']
# IEEE Sensors Council Summer School on Nano-Bio-Sensing -> ['Imagery', 'Optics']
# Leading research in Chemical Engineering (b) -> ['Research', 'Bio/Chem', 'Management', 'Thermodynamics']
# Numerical methods in heat transfer -> ['Math', 'Data']
# Théorie et critique du projet MA1 (Gugger) -> ['Management']
# Test of VLSI systems -> ['Data', 'Optics', 'Management']
# Laser microprocessing -> ['Optics', 'Math']
# UE N : Art et architecture: constructing the view II -> ['Image/Speech processing', 'Management', 'Optics', 'Data']
# Empirical Corporate Finance -> ['Research', 'Management']
# IC design for robustness -> Optics
# Introduction to econometrics -> ['Data', 'Management', 'Optics']
# Radiation protection & radiation applications -> ['Optics', 'Thermodynamics', 'Math', 'Management', 'Data', 'Research']
# Semiconductor physics and fundamentals of electronic devices -> ['Optics', 'Imagery', 'Math', 'Management', 'Research', 'Data']
# Chemical engineering product design -> ['Management', 'Data', 'Bio/Chem', 'Research']
# Computer simulation of physical systems I -> ['Math', 'Data', 'Optics', 'Research']
# Chemical biology -> ['Research', 'Bio/Chem', 'Management', 'Data']
# Experimental design and data analysis with R -> ['Data']
# Introduction to natural language processing -> ['Data', 'Management', 'Optics', 'Math']
# Mobile networks -> ['Optics', 'Data']
# Philosophy, epistemology and history of science II -> ['Math', 'Data', 'Optics', 'Bio/Chem', 'Management']
# Optical communications -> ['Optics', 'Data']
# Low-voltage analog CMOS IC design -> ['Electronics']
# Nano CMOS Devices & Technologies for Tera-Bit Circuits and Systems -> ['Optics']
# Quantitative methods II -> ['Data', 'Management', 'Math', 'Research']
# Trends in Metabolism & Physiology -> ['Research']
# Media security -> ['Data', 'Optics']
# Markov chains and algorithmic applications -> ['Data', 'Math', 'Optics']
# Energy systems engineering -> ['Thermodynamics', 'Management']
# Surfaces and interfaces -> ['Thermodynamics', 'Math', 'Data']
# Lasers and applications in chemistry -> ['Optics', 'Data', 'Management', 'Math', 'Research']
# Working Group in Algebraic Groups, II -> ['Data', 'Math', 'Research', 'Management']
# Chemistry of food processes -> ['Bio/Chem', 'Management']
# Selected topics in advanced optics -> ['Optics', 'Management', 'Data']
# Product lifecycle management - concepts methods and tools -> ['Management', 'Data']
# Project in bioengineering and biosciences -> ['Data', 'Research', 'Management', 'Optics']
# Introduction to Algebraic geometry -> ['Data']
# Lab immersion academic (outside EPFL) A -> ['Research', 'Data', 'Management']
# Biomaterials (pour MX) -> ['Management', 'Research', 'Data']
# D. Thinking: real problems, human-focused solutions -> ['Management', 'Data']
# Financial big data -> ['Data', 'Management', 'Optics', 'Math', 'Research']
# Human language technology: applications to information access -> ['Data', 'Management', 'Research']
# Modeling and simulation of microsystems -> ['Math', 'Data', 'Optics']
# Synergism between Art of Total Synthesis and High Level Strategic Design (MOM) -> Management
# Topics in geometric analysis I -> ['Math']
# Scanning electron microscopy techniques (b) -> ['Imagery', 'Research', 'Optics', 'Image/Speech processing']
# Lab in acoustics -> ['Optics', 'Management', 'Data', 'Math', 'Research']
# Bioelectronics and implantable biomedical microelectronics -> ['Optics', 'Management', 'Data', 'Research']
# Introduction to operating systems -> ['Management', 'Data', 'Optics']
# Solar photovoltaics and energy systems -> ['Thermodynamics', 'Bio/Chem', 'Imagery', 'Optics']
# Nonlinear signal modeling and prediction -> ['Optics']
# Theoretical corporate finance -> ['Math', 'Data', 'Research', 'Management']
# Neurosciences II : cellular mechanisms of brain function -> ['Optics', 'Math', 'Data']
# Digital education & learning analytics -> ['Management', 'Data']
# Frontiers in Organic Synthesis. Part II Synthesis of carbo- and hetero-cycles -> ['Bio/Chem', 'Management', 'Research']
# Hardware systems modeling -> Optics
# Statistical thermodynamics -> ['Thermodynamics', 'Math', 'Data']
# Applied data analysis -> ['Data', 'Research', 'Optics', 'Management']
# Electron microscopy: advanced methods -> ['Imagery', 'Research', 'Management', 'Data', 'Optics']
# Modeling of emerging electron devices -> Optics
# Scientific literature analysis in cell and developmental biology -> ['Research', 'Management', 'Data', 'Bio/Chem']
# Numerical approximation of PDE's II -> ['Math', 'Data']
# Control systems   TP -> ['Optics', 'Math']
# Project in biomedical technologies -> ['Research', 'Data', 'Management', 'Optics']
# Practical - Hantschel Lab -> ['Research', 'Bio/Chem', 'Optics']
# Classical electrodynamics -> ['Math', 'Data', 'Optics']
# Pattern classification and machine learning -> ['Data', 'Math']
# Industrial electronics I -> ['Optics', 'Imagery', 'Thermodynamics']
# CCMX Advanced Course 'Advanced X-ray Diffraction Methods for Coatings: strain, defects and deformation analysis of thin films -> ['Thermodynamics']
# Molecular and cellular biophysic II -> ['Research', 'Bio/Chem']
# CCMX Advanced Course - Instrumented Nanoindentation -> ['Data', 'Optics', 'Math']
# Electronic properties of solids and superconductivity -> ['Optics', 'Math']
# Practical - Brisken Lab -> ['Management']
# Hydrogeophysics -> ['Optics', 'Management', 'Research', 'Data', 'Math']
# Sensorimotor neuroprosthetics -> ['Optics', 'Management']
# Advanced analysis I -> ['Math', 'Optics', 'Data']
# Nanofabrication with focused electron and ion beams -> ['Imagery', 'Optics']
# Computer simulation of physical systems II -> ['Math', 'Data', 'Optics']
# Fundamentals in Systems Engineering -> ['Management', 'Data', 'Research']
# Programming concepts in scientific computing -> ['Data', 'Management', 'Math', 'Research', 'Optics']
# Intelligent agents -> ['Data', 'Math']
# Lifecycle performance of product systems -> ['Management', 'Data', 'Research', 'Optics']
# Fluid mechanics for SV -> ['Math', 'Thermodynamics']
# Engineering internship credited with master project (master in Management of Technology and Entrepreneurship) -> ['Management', 'Research', 'Data', 'Optics']
# Active noise control -> ['Optics', 'Data']
# Reactive programming -> ['Data', 'Math', 'Research']
# Principles of intellectual property management -> ['Management', 'Data', 'Research']
# Optics laboratories II -> ['Optics', 'Data', 'Research', 'Management']
# UE L : Art and architecture: constructing the view I -> ['Image/Speech processing', 'Management', 'Optics', 'Data']
# Computer language processing -> ['Data', 'Optics', 'Math', 'Management']
# Photomedicine -> ['Optics', 'Research']
# Modelling and optimization of energy systems -> ['Thermodynamics', 'Data', 'Management', 'Math']
# 1st Workshop on Advances in CFD and MD modelling of Interface Dynamics in Capillary Two-Phase Flows -> ['Math']
# Early detection of innovation potential -> ['Management', 'Data', 'Research']
# Sanitary engineering in developing countries -> ['Management', 'Data']
# Experimental biochemistry and biophysics -> ['Research', 'Data', 'Optics', 'Management']
# Virtual reality -> ['Optics', 'Data', 'Research', 'Management']
# Recent Events in Energy-1 -> ['Research', 'Thermodynamics']
# History of globalization II -> Management
# Biomechanics of the cardiovascular system -> ['Math']
# Project in Electrical Energy Systems -> ['Data', 'Management', 'Research', 'Imagery', 'Optics']
# Turbulence -> ['Math', 'Management', 'Data']
# Chemical thermodynamics -> ['Bio/Chem', 'Thermodynamics', 'Math']
# Topics in geometric analysis II -> ['Math']
# Methods of Modelling and Simulation of Materials Science -> ['Math', 'Research', 'Data', 'Management', 'Bio/Chem']
# Nanobiotechnology and biophysics -> ['Research', 'Optics', 'Bio/Chem']
# Thermal power cycles and heat pump systems -> ['Thermodynamics', 'Management']
# Advanced information, computation, communication II -> ['Data', 'Optics', 'Math']
# Methods for rapid production and development -> ['Optics', 'Data', 'Management', 'Research']
# Software engineering -> ['Data', 'Management', 'Optics']
# How people learn I -> ['Management', 'Data', 'Research', 'Optics']
# Thermodynamics for materials science -> ['Bio/Chem', 'Math']
# Thermodynamics and energetics I -> ['Thermodynamics', 'Math']
# Applied corporate & industry analysis (MTE master only) -> ['Data', 'Research', 'Management']
# Nanoscale MOSFETs and beyond CMOS devices -> ['Thermodynamics', 'Management', 'Optics']
# Electrochemical Thermodynamics and Kinetics of Metals and Semiconductors for Energy Conversion -> ['Bio/Chem']
# Fundamentals of superresolution optical microscopy and Scanning Probe Microscopy -> ['Optics', 'Imagery']
# Understanding Statistics and Experimental Design -> ['Data', 'Math', 'Research', 'Optics']
# Scientific project design in translational neurosciences -> ['Management', 'Data', 'Research', 'Optics']
# Seminar series on advances in materials (spring) -> ['Research', 'Management', 'Data']
# Audio signal processing and virtual acoustics -> ['Optics']
# Slope stability -> Management
# Economics of Innovation and Technological Change -> ['Management', 'Research']
# Elliptic PDE's -> ['Math', 'Data']
# Computer-aided engineering -> ['Data', 'Management']
# Nuclear fusion and plasma physics -> ['Thermodynamics', 'Math', 'Management']
# Project in micro and nanoelectronics -> ['Data', 'Management', 'Research', 'Imagery', 'Optics']
# Environmental chemistry -> ['Bio/Chem', 'Management', 'Data']
# Power systems dynamics -> ['Optics', 'Management']
# Tribology -> ['Management', 'Data']
# Gödel and recursivity -> ['Math', 'Data']
# Technology policy and the energy transition -> ['Management', 'Data', 'Thermodynamics']
# X-Ray Analysis for thin films -> ['Math', 'Research', 'Optics', 'Management', 'Data', 'Bio/Chem']
# Fourier analysis and boundary value problems -> ['Data', 'Optics', 'Math']
# Organic chemistry -> ['Bio/Chem', 'Research', 'Management', 'Math']
# Density functional theory for chemistry students -> ['Math', 'Data', 'Optics']
# Advanced microwaves for wireless communications -> ['Optics', 'Electronics']
# Optimal decision making -> ['Data', 'Optics', 'Math', 'Management']
# Hardware systems modeling II -> Optics
# Introduction to Frustrated Magnetism -> ['Image/Speech processing']
# Quantum Information Theory and Computation -> ['Math', 'Data', 'Computing', 'Management', 'Optics']
# Investing: a Guide to Doing the Right Thing -> ['Management', 'Data']
# Biological chemistry II (for SV) -> ['Research', 'Thermodynamics', 'Bio/Chem', 'Management', 'Optics']
# Théorie et critique du projet MA2 (Geers) -> ['Management']
# Renewable energy and solar architecture in Davos -> ['Management', 'Thermodynamics', 'Research', 'Data']
# Lab immersion in industry B -> ['Research', 'Data', 'Management']
# Seminars in Physical Chemistry (2) -> ['Research', 'Bio/Chem', 'Management', 'Math', 'Optics']
# Multivariate statistics -> ['Data', 'Research', 'Math']
# Financial econometrics -> ['Data', 'Management', 'Math']
# Equilibrium-stage separation processes -> ['Math', 'Data']
# Electron Microscopy for Life Science -> ['Imagery', 'Optics', 'Research']
# Water resources engineering -> ['Data', 'Optics', 'Management', 'Math', 'Thermodynamics']
# IC design II -> ['Data', 'Management', 'Optics', 'Research']
# Space mission design and operations -> ['Math', 'Management', 'Data', 'Research', 'Optics']
# Model predictive control -> ['Optics', 'Data', 'Research', 'Math']
# Computer vision -> ['Image/Speech processing', 'Optics', 'Math']
# Photochemistry II -> ['Thermodynamics', 'Optics', 'Math', 'Imagery']
# Instability -> ['Math', 'Data', 'Research', 'Management', 'Optics']
# Transmission electron microscopy and diffraction (a) -> ['Imagery', 'Optics']
# Modern photovoltaic technologies -> ['Bio/Chem', 'Management']
# Sparse stochastic processes -> ['Math', 'Data', 'Optics']
# Cristallography and diffraction methods -> ['Optics', 'Data']
# Econometrics -> ['Data']
# Lab methods : histology -> ['Optics', 'Research', 'Data']
# Studio MA1 (Escher et GuneWardena) -> ['Management', 'Data', 'Research']
# Introduction to chemical engineering -> ['Data', 'Thermodynamics', 'Math', 'Management', 'Bio/Chem', 'Optics']
# Information technology and digital strategy -> ['Management', 'Data']
# Practical - Bucher Lab -> ['Data']
# Advanced quantum field theory -> ['Math', 'Data', 'Optics', 'Management']
# Working group in Topology I -> ['Data', 'Math', 'Management']
# Functional programming -> ['Data', 'Optics', 'Math', 'Research', 'Management']
# Neurotechnologies to treat neurodisorders: neuroprosthetics (EDNE) -> ['Research', 'Management']
# Lab methods : bioactive compounds screening -> ['Research', 'Data', 'Management', 'Bio/Chem', 'Optics']
# Advanced MEMS -> ['Optics', 'Management', 'Data']
# Théorie et critique du projet MA1 (Geers) -> ['Management']
# PLLs and clock & data recovery -> Optics
# Active Remote Sensing of the Atmosphere -> Optics
# Practical - Lemaitre Lab -> ['Bio/Chem']
# Integrated circuits technology -> ['Management', 'Optics']
# Applied probability & stochastic processes -> ['Data', 'Math', 'Optics']
# Negotiation techniques -> ['Management', 'Data', 'Research', 'Optics']
# Satellite communications  systems and networks -> ['Optics']
# Parallel and high-performance computing -> ['Data', 'Math', 'Management']
# Plasma physics III -> ['Image/Speech processing', 'Optics', 'Math']
# Energy conversion and renewable energy -> ['Thermodynamics', 'Optics']
# Image optics -> ['Optics', 'Image/Speech processing']
# Financial Econometrics (EDFI) -> ['Data', 'Management']
# Interdisciplinary / disciplinary project for chemical master -> ['Bio/Chem', 'Research', 'Management']
# Social media -> ['Data', 'Management', 'Math']
# Fixed income analysis -> ['Management', 'Math']
# Parallelism and concurrency -> ['Data', 'Math', 'Research']
# Optical fibers and fiber devices -> ['Optics']
# Surface and thin films processes -> ['Thermodynamics', 'Math', 'Optics']
# Optimization and simulation -> ['Data', 'Math', 'Research']
# Financial & managerial accounting -> ['Management', 'Data', 'Optics']
# Innovation management -> ['Management', 'Data', 'Research']
# Image analysis and pattern recognition -> ['Optics', 'Image/Speech processing', 'Data', 'Management']
# Stochastic calculus I -> ['Math', 'Data']
# Piezoelectric materials, properties and devices -> ['Optics', 'Math', 'Management']
# Limnology -> ['Data', 'Research', 'Math']
# Fundamentals of biosensors and electronic biochips -> ['Optics', 'Research']
# Signal processing for communications -> ['Optics', 'Data']
# Soft Microsystems Processing and Devices -> ['Imagery', 'Optics', 'Management']
# A Network Tour of Data Science -> ['Data', 'Management', 'Math', 'Research', 'Optics']
# Mass spectrometry, principles and applications -> ['Math', 'Thermodynamics']
# Development engineering -> ['Management', 'Research', 'Data']
# Assembly techniques -> ['Management', 'Math', 'Optics', 'Data']
# Nonlinear Optics -> ['Optics']
# Nonlinear Spectroscopy -> ['Optics', 'Math', 'Bio/Chem']
# Advanced analog and RF integrated circuits design II -> ['Electronics', 'Optics']
# RF MEMS for communications applications -> ['Optics', 'Management']
# Fundamentals of traffic operations and control -> ['Data', 'Management', 'Optics', 'Math', 'Research']
# Biophysics II -> ['Bio/Chem', 'Math']
# Quantum Field Theory Methods in Gravity and Cosmology -> ['Math', 'Management', 'Data', 'Research', 'Optics', 'Computing']
# Lasers: theory and modern applications -> ['Optics']
# Machine Learning for Engineers -> ['Data', 'Optics', 'Math']
# Energy storage in power systems: technologies, applications and future needs -> ['Thermodynamics']
# Properties of semiconductors and related nanostructures -> ['Optics', 'Math', 'Management']
# Seismic engineering -> ['Research', 'Math', 'Management']
# Théorie et critique du projet MA2 (Gugger) -> ['Management', 'Research', 'Data']
# Advanced lab in electrical engineering -> ['Data', 'Management', 'Optics', 'Math', 'Research']
# Concurrent algorithms -> ['Data', 'Math', 'Research']
# Water quality modeling -> ['Data', 'Bio/Chem', 'Management']
# Scientific literature analysis in Neuroscience -> ['Research', 'Data', 'Management']
# Information security and privacy -> ['Data', 'Optics', 'Management']
# Chemical engineering of heterogenous reactions -> ['Bio/Chem', 'Management', 'Data']
# Flexible bioelectronics -> ['Optics', 'Management', 'Research', 'Imagery', 'Math', 'Data']
# Eco-friendly production and process intensification -> ['Bio/Chem', 'Management', 'Thermodynamics', 'Data', 'Research']
# Dynamical system theory for engineers -> ['Data', 'Math', 'Optics']
# Introduction to magnetic materials in modern technologies -> ['Image/Speech processing', 'Optics', 'Management', 'Math', 'Research', 'Data']
# Empirical Methods in Corporate Finance -> ['Data']
# Cosmology: Dark and Luminous Matters  -> Math
# Pharmacology and pharmacokinetics -> ['Research', 'Management', 'Math']
# Algorithms -> ['Data', 'Math', 'Research']
# Probability theory -> ['Math', 'Data', 'Optics']
# Theoretical Microfluidics -> ['Math']
# Economics of innovation -> ['Management', 'Data', 'Research']
# Pharmacological chemistry -> ['Research', 'Bio/Chem', 'Management']
# High energy and space astrophysics (UNIGe) -> ['Thermodynamics', 'Management']
# Fundamentals in statistical pattern recognition -> ['Data']
# Advanced Topics in Cryptology -> ['Research', 'Management', 'Data', 'Math']
# Advanced cryptography -> ['Data', 'Optics', 'Management', 'Research', 'Math']
# Biostatistics -> ['Data', 'Math', 'Management', 'Optics']
# Digital 3D Geometry Processing -> ['Data', 'Math', 'Management', 'Optics']
# Introduction to digital signal processing using Matlab, applied to environmental sciences and civil engineering -> ['Optics', 'Data']
# Advanced diffusional separation processes -> ['Thermodynamics']
# Lab immersion academic (outside EPFL) B -> ['Research', 'Data', 'Management']
# Inorganic reactivity -> ['Bio/Chem', 'Research', 'Management', 'Math']
# Advanced satellite positioning -> ['Optics', 'Data', 'Research', 'Math']
# Lab in electrical energy systems -> ['Optics', 'Thermodynamics', 'Data']
# Optical waves propagation -> ['Optics', 'Image/Speech processing']
# Energy Autonomous Wireless Smart Systems -> ['Thermodynamics', 'Optics', 'Management', 'Data']
# Numerical methods for visual computing -> ['Data', 'Math', 'Optics', 'Management', 'Research']
# Power management -> ['Optics', 'Thermodynamics', 'Electronics']
# Environmental policy -> ['Management', 'Data', 'Research', 'Optics']
# Fate and behaviour of organic pollutants -> ['Bio/Chem', 'Optics', 'Data', 'Management']
# Landmark Papers in Cancer and Infection -> ['Management', 'Bio/Chem', 'Research', 'Data']
# Advanced analog and RF integrated circuits design I -> ['Optics', 'Electronics']
# Advanced control systems -> ['Optics', 'Data']
# 2D Layered Materials: Synthesis, Properties and Applications -> ['Imagery', 'Optics', 'Management']
# Game Theory -> ['Data']
# Linear system theory -> ['Optics', 'Data']
# Discrete mathematics -> ['Data', 'Management', 'Math', 'Research']
# Emerging Nanopatterning Methods -> Data
# Project in information technologies -> ['Data', 'Management', 'Research', 'Imagery', 'Optics']
# Graph theory -> ['Math', 'Data']
# Ceramics, structures and properties   TP -> ['Research', 'Management', 'Math']
# Strategic marketing & technology commercialization -> ['Management', 'Data', 'Research']
# Lab immersion in industry A -> ['Research', 'Data', 'Management']
# Topics in theoretical computer science -> ['Data', 'Math', 'Management', 'Optics', 'Research']
# Advanced Earthquake Engineering -> ['Research', 'Data', 'Management', 'Math']
# Scaling laws in micro- and nanosystems -> ['Math', 'Optics', 'Management']
# Materials and technology of microfabrication -> ['Management', 'Optics', 'Data', 'Research', 'Math', 'Thermodynamics']
# Business information systems -> ['Management', 'Data', 'Optics']
# History of globalization I -> ['Management', 'Research', 'Data']
# Operating systems implementation -> ['Data', 'Optics']
# Entrepreneurship -> ['Management', 'Data', 'Research', 'Optics']
# Computational methods in molecular quantum mechanics -> ['Math', 'Data', 'Research']
# High pressure in chemical kinetics and equilibria -> ['Bio/Chem', 'Math', 'Research']
# Materials Science -> ['Bio/Chem', 'Research', 'Management', 'Math']
# CCMX Winter School - Additive Manufacturing of Metals and the Material Science Behind It' -> Data
# Introduction to crystal growth by epitaxy -> ['Research', 'Bio/Chem', 'Math']
# Microstructuring of glass -> ['Optics', 'Math', 'Research', 'Bio/Chem']
# Advanced composites in engineering structures -> ['Research', 'Data', 'Management', 'Math', 'Optics']
# Ecotoxicology -> ['Management', 'Bio/Chem', 'Research', 'Data']
# New tools and research strategies in personalized medicine -> ['Research', 'Management', 'Data', 'Optics']
# Numerical methods for electromagnetics -> ['Math', 'Data', 'Research']
# Photomechanics for Engineers -> ['Optics']
# Introduction to scanning electron microscopy microanalysis techniques -> ['Imagery', 'Optics', 'Bio/Chem', 'Image/Speech processing']
# Fundamentals of VLSI design -> ['Data', 'Optics', 'Management', 'Electronics']
# Electric filters -> ['Optics', 'Management', 'Data', 'Research', 'Math']
# Introduction to multiprocessor architecture -> ['Management', 'Data', 'Math']
# Wireless Transceivers: Radio Architectures, System and Circuit Design -> ['Management', 'Optics']
# Information theory and coding -> ['Data', 'Optics', 'Math', 'Management']
# Cellular Signalling -> ['Research', 'Bio/Chem', 'Optics']
# Fracture of materials -> ['Research', 'Math', 'Management']
# Advances in Additive Manufacturing for Polymers in Bioengineering, Electronics and Material Science -> ['Management', 'Imagery', 'Data']
# Chemistry of small biological molecules -> ['Research', 'Bio/Chem', 'Optics']
# Théorie et critique du projet MA2 (Huang) -> ['Management', 'Data']
# Human computer interaction -> ['Data', 'Research']
# Scientific project design in integrative neurosciences -> ['Management', 'Research', 'Data']
# Organic electronic materials - synthesis, applications, properties -> ['Bio/Chem', 'Imagery']
# Sensor orientation -> ['Optics', 'Data']
# Imagery of territory -> ['Image/Speech processing', 'Optics', 'Data', 'Management']
# Scientific project design in drug discovery -> ['Management', 'Data', 'Research']
# Brain Bioenergetics: from behavior to pathology -> ['Research']
# Advanced information, computation, communication I -> ['Math', 'Data', 'Management']
# Wireless receivers: algorithms and architectures -> ['Optics']
# Biomimetic membrane systems and their applications -> ['Bio/Chem', 'Math', 'Research', 'Optics']
# Data Analysis for Science and Engineering -> ['Data', 'Research', 'Math', 'Management']
# Infection biology -> ['Research']
# Advanced digital communications -> ['Optics', 'Data', 'Management']
# Difficult Double Double Histories -> ['Management', 'Research', 'Data', 'Optics']
# Lab immersion III -> ['Data', 'Research', 'Management', 'Optics', 'Math']
# Practical - Lingner Lab -> ['Bio/Chem', 'Research']
# Reactor Technology -> ['Thermodynamics', 'Management']
# Advanced derivatives -> ['Math', 'Management']
# Geocomputation -> ['Data', 'Management', 'Research', 'Optics', 'Math']
# Summer School on Neurophysiology for Neural and Biomedical Engineering (2016) -> ['Management', 'Research', 'Data', 'Optics']
# Multivariate Extreme Value and Max-Stable Processes -> ['Math']
# Monthly IBI-EDBB Mini-symposia -> ['Research', 'Management']
# Numerical Methods for Physical Properties Evaluation -> ['Math']
# High Dimensional Approximation for PDEs with random parameters -> ['Math', 'Data']
# Energy geostructures -> ['Thermodynamics', 'Data']
# Data analysis and model classification -> ['Data', 'Optics', 'Management', 'Research', 'Math']
# Mechanical product design and development -> ['Management', 'Data', 'Optics', 'Math', 'Research']
# Energy planning: modeling and decision support systems -> ['Thermodynamics', 'Management', 'Data']
# Waterborne Pathogens -> ['Management', 'Math', 'Research']
# Mathematics for Financial Economics -> ['Data', 'Math']
# Cellular biology and biochemistry for engineers -> ['Research', 'Data', 'Management', 'Bio/Chem', 'Optics']
# Smart grids technologies -> ['Data', 'Optics', 'Management', 'Thermodynamics', 'Math']
# Transportation systems engineering -> ['Data', 'Management', 'Math', 'Optics', 'Research']
# Working group in Topology II -> ['Math', 'Data']
# Networks out of control -> ['Data', 'Math', 'Optics']
# Surface analysis -> ['Imagery', 'Bio/Chem', 'Optics', 'Math', 'Thermodynamics']
# Multi-body simulation -> ['Math', 'Management', 'Data', 'Research', 'Optics']
# Accounting for finance -> ['Data']
# Computer architecture -> ['Math', 'Data', 'Management']
# Laser Processing of Materials: From Optical Properties of Materials and Light-Matter Interaction to Applications -> ['Optics', 'Math']
# Real-time embedded systems -> ['Data', 'Management', 'Optics', 'Research']
# Robotics practicals -> ['Optics', 'Data']
# Practical - Naef Lab -> ['Research', 'Bio/Chem', 'Data', 'Optics', 'Management']
# Optional project in computer science -> ['Research', 'Management', 'Data']
# UE W: Reading construction -> ['Research', 'Management', 'Data']
# Advanced lab in electrical energy systems -> ['Data', 'Optics', 'Management']
# HF and VHF circuits and techniques II -> ['Optics', 'Data', 'Management', 'Research', 'Electronics']
# Interfaces in biology and nanoscience -> ['Research', 'Data', 'Bio/Chem', 'Management', 'Optics', 'Math']
# Practical - Constam Lab -> ['Bio/Chem', 'Optics']
# Dynamic Asset Pricing -> ['Math', 'Management']
# Microelectronics -> ['Optics']
# Hydrodynamics -> ['Math']
# Readings in Organization Economics -> ['Research', 'Management', 'Data']
# Optics III -> ['Optics']
# Gene transfer and recombinant protein expression in animal cells -> ['Bio/Chem', 'Research']
# CCMX Advanced Course - Atomic Force Microscopy (AFM): Theory and Practice -> ['Optics', 'Imagery']
# Wave propagation along transmission lines -> ['Math', 'Optics']
# CCMX Advanced Course - Combining Structural & Analytical Investigations of Matter at the Micro-, Nano and Atomic Scale- (2016) -> ['Imagery', 'Research', 'Optics']
# Propagation of acoustic waves -> ['Data', 'Math', 'Management', 'Optics', 'Research']
# Food biotechnology -> ['Management', 'Bio/Chem', 'Data']
# Derivatives -> ['Math', 'Data']
# Leading and managing in a global context -> ['Management', 'Data', 'Research']
# Technology ventures in IC -> ['Management', 'Data', 'Research', 'Optics']
# Advanced NMR and imaging -> ['Optics', 'Image/Speech processing', 'Data', 'Management']
# Seminars in Physical Chemistry (1) -> ['Research', 'Bio/Chem', 'Management', 'Math', 'Optics']
# Optional project in communication systems -> Research
# Effects of radiation on materials -> ['Imagery', 'Math', 'Management', 'Thermodynamics', 'Optics']
# Advanced compiler construction -> ['Data', 'Math']
# Circuits and systems II -> ['Optics', 'Data', 'Management']
# Cancer Biology I -> ['Research', 'Bio/Chem', 'Optics']
# Magnetic confinement -> ['Image/Speech processing']
# Cancer Biology II -> ['Research', 'Bio/Chem', 'Optics', 'Data']
# Creative Problem Solving in Science and Engineering -> ['Data', 'Math']
# Design of Ultra-low Power Wearable Wireless Systems -> ['Optics', 'Management', 'Data', 'Research']
# Metrology II -> ['Optics', 'Management', 'Data']
# Summer school on healthcare diagnostics -> ['Management', 'Data']
# Introduction to practical aspects of animal experimentation and animal facilities (Winter) (EDNE) -> ['Research', 'Optics', 'Bio/Chem']
# Quantitative methods in finance -> ['Data', 'Math']
# Numerical methods in chemistry -> ['Math', 'Data', 'Bio/Chem', 'Optics']
# General physics II -> ['Thermodynamics', 'Math', 'Optics', 'Research', 'Management', 'Image/Speech processing']
# Enterprise and service-oriented architecture -> ['Management', 'Data']
# Magnetic materials in modern technologies - from concepts to real devices -> ['Image/Speech processing', 'Management', 'Math', 'Optics', 'Data', 'Research']
# Electromagnetic compatibility -> ['Optics']
# Scaling in MEMS -> ['Math', 'Management']
# Part 4 : Research project in Area and Cultural Studies -> ['Management', 'Research', 'Data', 'Optics']
# Biomass conversion -> ['Thermodynamics', 'Management']
# Solid waste engineering -> ['Management', 'Data', 'Research']
# Haptic human robot interfaces -> ['Optics', 'Math']
# Statistical neurosciences -> ['Data', 'Management', 'Research']
# Student seminar: security protocols and applications -> ['Data', 'Optics', 'Research', 'Management']
# Fundamentals of biomedical imaging -> ['Image/Speech processing', 'Optics', 'Data', 'Research', 'Management']
# Information : strategy & economics -> ['Management', 'Data', 'Research']
# Personal interaction studio -> ['Data', 'Management', 'Math']
# Total synthesis of natural products -> ['Bio/Chem', 'Management', 'Research']
# Incompressible fluid mechanics -> ['Math']
# Solid state physics II -> ['Math']
# Fracture Mechanics and Fatigue of Structures -> ['Research', 'Math']
# HydroPower and Dams: Benefits and Concerns -> ['Data', 'Management', 'Thermodynamics']
# Cryptography and security -> ['Data', 'Math', 'Optics']
# Neurosciences I : molecular neuroscience and neurodegeneration -> ['Research', 'Bio/Chem', 'Data']
# Microbial diversity -> ['Research', 'Math']
# Neurosciences III : behavioral and cognitive neuroscience -> ['Math', 'Research']
# Seminar series on advances in materials (autumn) -> ['Research', 'Management', 'Data']
# Characterization Methods in Materials Science -> ['Imagery', 'Research', 'Optics', 'Math']
# Biomicroscopy I -> ['Optics']
# Computational physics III -> ['Math', 'Data', 'Optics']
# Lab in microwaves -> ['Research', 'Optics', 'Data', 'Management']
# Engineering geology for geo-energy -> Research
# Process development I -> ['Management', 'Thermodynamics', 'Data', 'Optics']
# New Concretes for Structures -> ['Math', 'Research', 'Bio/Chem']
# Signals, instruments, and systems -> ['Optics', 'Data', 'Management']
# Introduction to computer graphics -> ['Data', 'Optics', 'Management']
# Probabilistic Coupling -> ['Math', 'Data']
# Statistical theory -> ['Data', 'Math', 'Optics']
# Time series -> ['Data', 'Math', 'Optics']
# Photonic systems and technology -> ['Optics', 'Management']
# Advanced analysis II -> ['Optics', 'Math', 'Data']
# Plasma instabilities -> ['Math', 'Data', 'Optics', 'Bio/Chem']
# Audio engineering -> ['Optics']
# Studio BA5 (Fröhlich M. & A.) -> ['Management', 'Data', 'Research']
# Environmental transport phenomena -> ['Math', 'Data']
# Advanced machine learning -> ['Data', 'Research', 'Optics', 'Management', 'Math']
# Ultrafast phenomena -> ['Optics', 'Imagery', 'Math', 'Research']
# Transmission electron microscopy and diffraction (b) -> ['Imagery', 'Optics']
# Water and wastewater treatment -> ['Data', 'Management']
# Bioreactor modeling and simulation -> ['Data', 'Math', 'Optics', 'Management', 'Bio/Chem', 'Thermodynamics']
# Physical models for micro and nanosystems -> ['Math', 'Imagery', 'Optics']
# Reliability of MEMS (EDOC) -> ['Data', 'Optics']
# Grid and Converter Controls -> ['Optics', 'Thermodynamics']
# Light sources: optical fiber and waveguide lasers -> ['Optics']
# Integrated optics -> ['Optics', 'Data', 'Math']
# Snow Science Winter School -> ['Optics', 'Data', 'Research', 'Management', 'Math']
# Micro and nanostructuration of materials -> ['Data', 'Optics']
# Heat and mass transfer -> ['Thermodynamics', 'Math']
# Theory of computation -> ['Math', 'Data', 'Optics']
# General physics III -> ['Math', 'Optics', 'Management', 'Research']
# Methods of asymptotic analysis in mechanics -> ['Math']
# Environment chemical and biological technology -> ['Research', 'Data', 'Bio/Chem', 'Management']
# Evolutionary robotics -> ['Optics', 'Data', 'Math']
# Analysis and modelling of locomotion -> ['Optics']
# Advanced topics in electromagnetic compatibility -> ['Optics', 'Research', 'Management', 'Data']
# Fundamentals of Biometrics -> ['Data']
# Advanced computer architecture -> ['Management']
# Laboratory information management systems (LIMS) -> ['Management', 'Data', 'Research']
# Advanced topics in financial econometrics -> ['Data', 'Math', 'Management']
# Harmonic analysis -> ['Optics', 'Math']
# Fundamentals of biophotonics -> ['Optics', 'Data', 'Research', 'Management']
# Engineering of musculoskeletal system and rehabilitation -> ['Management']
# Corporate strategy -> ['Management', 'Data', 'Research']
# Introduction to the finite elements method -> ['Math', 'Data', 'Optics']
# Transient and dynamic analysis of electric power systems -> ['Optics', 'Math', 'Data']
# Information and Asset Pricing -> ['Data', 'Management']
# Embedded systems -> ['Management', 'Data', 'Optics', 'Research']
# Organic semiconductors -> ['Optics', 'Bio/Chem', 'Imagery', 'Math', 'Management']
# Combinatorial optimization -> ['Data', 'Math']
# Genomics and bioinformatics -> ['Research', 'Bio/Chem']
# Advances in Contact Mechanics -> ['Research', 'Management', 'Data']
# Crystallography of structural phase transformations -> ['Data', 'Management', 'Math']
# Advanced analog IC design -> ['Electronics']
# Computer networks -> ['Data', 'Optics', 'Math']
# Statistical mechanics -> ['Data', 'Math', 'Research', 'Management', 'Optics']
# Principles of finance -> ['Data', 'Management', 'Math', 'Research']
# Understanding modern Switzerland II -> ['Research', 'Management', 'Data']
# Introduction to nuclear engineering -> ['Thermodynamics', 'Optics', 'Math']
# Information Science in Engineering -> ['Math', 'Research', 'Data', 'Management', 'Optics', 'Bio/Chem']
# Applied molecular quantum chemistry -> ['Math', 'Bio/Chem', 'Imagery', 'Data', 'Thermodynamics', 'Management']
# Symmetry and Conservation in the Cell -> ['Bio/Chem', 'Math']
# Advanced metallurgy -> ['Management']
# Environmental Economics for Engineers -> ['Management', 'Data']
# Economics of innovation & management in energy -> ['Thermodynamics', 'Management']
# Understanding modern Switzerland I -> ['Research', 'Management', 'Data']
# Communication for Research Engineers -> ['Research', 'Data', 'Optics', 'Management']
# Power electronics -> ['Thermodynamics', 'Optics', 'Imagery', 'Management', 'Research', 'Math', 'Data']
# Current Topics in Chemical Biology 1 -> ['Research', 'Bio/Chem', 'Management']
# Applied mechanical design -> ['Data', 'Management', 'Math', 'Optics', 'Research']
# Optical Materials: Fundamental concepts and recent developments -> ['Optics', 'Management', 'Research', 'Math']
# Presentation skills -> ['Management', 'Data']
# 3D Electron Microscopy and FIB-Nanotomography -> ['Imagery', 'Optics']
# Scanning electron microscopy techniques (a) -> ['Imagery', 'Research', 'Optics', 'Image/Speech processing']
# BioMEMS -> ['Optics', 'Bio/Chem', 'Management', 'Research']
# Plasma physics II -> ['Image/Speech processing', 'Optics', 'Math']
# Lab methods : biosafety -> ['Management', 'Research', 'Optics', 'Data']
# Advanced probability and applications -> ['Math', 'Data']
# Sensors in medical instrumentation -> ['Optics']
# Thermodynamics of energy conversion and storage -> ['Thermodynamics', 'Management']
# Spacecraft avionics systems, architectures and processors -> ['Data', 'Optics', 'Math']
# General chemistry (English) -> ['Bio/Chem', 'Math', 'Thermodynamics', 'Research', 'Data']
# Games for Crowds and Networks -> ['Data', 'Math', 'Optics', 'Management']
# Numerical Analysis and Computational Mathematics -> ['Data', 'Math', 'Optics']
# Advanced Microscopy for Life Science -> ['Optics', 'Imagery']
# Théorie et critique du projet BA3 (De Vylder & Taillieu) -> ['Management']
# Quantum chemistry -> ['Math', 'Management', 'Bio/Chem', 'Computing']
# Machine learning programming -> ['Data', 'Research', 'Optics', 'Management']
# Practical - Meylan Lab -> ['Research', 'Optics']
# Brain-computer interaction -> ['Optics', 'Data']
# Academic Writing for Doctoral Students -> ['Research', 'Data', 'Management']
# Studio MA2 (Lütjens et Padmanabhan) -> ['Management', 'Research']
# Measuring systems laboratory work -> ['Optics', 'Research']
# Industrial electronics II -> ['Optics', 'Math', 'Imagery']
# Efficient Synthetic Routes Towards Bioactive Molecules -> ['Management']
# Atomistic and quantum simulations of materials -> ['Math', 'Research', 'Bio/Chem', 'Optics', 'Data', 'Management']
# Electronic spectroscopy -> ['Imagery', 'Management']
# Analysis III -> ['Optics', 'Math']
# Practical - Radtke Lab -> ['Bio/Chem', 'Math']
# Neuroscience for engineers -> ['Image/Speech processing', 'Optics']
# Mathematics of data: from theory to computation -> ['Data', 'Math']
# Inorganic chemistry "Techniques and methods" -> ['Research', 'Bio/Chem', 'Management', 'Optics']
# Fluid mechanics (for SIE) -> ['Math', 'Thermodynamics', 'Data']
# Bioinorganic chemistry -> ['Research', 'Management']
# Bioanalytics and analytical sensors -> ['Management', 'Data']
# Physics of photonic semiconductor devices -> ['Optics', 'Math']
# Project in Biotechnology -> ['Research', 'Management', 'Data']
# Digital Speech and Audio Coding -> ['Optics', 'Data']
# Foundations of software -> ['Data', 'Management', 'Optics']
# Current Topics in Distributed Systems -> ['Research', 'Management', 'Data']
# Industrial automation -> ['Optics', 'Data', 'Management', 'Research']
# Lab immersion II -> ['Data', 'Research', 'Management', 'Math', 'Optics']
# Project in molecular sciences -> ['Research', 'Data', 'Management', 'Math']
# Stellar evolution and nucleosynthesis (UNIGe) -> ['Math', 'Management']
# Data science for business -> ['Data', 'Management', 'Research', 'Optics']
# Asset Pricing -> ['Math', 'Data']
# Quantum optics and quantum information -> ['Math', 'Computing', 'Optics', 'Data']
# Analysis of ancient materials and their degradation -> ['Data', 'Optics', 'Research', 'Image/Speech processing', 'Management']
# Advanced steel design -> ['Research']
# Recent Events in Energy-2 -> ['Research', 'Thermodynamics', 'Management']
# Spatial statistics and analysis -> ['Data', 'Management']
# Process development project -> ['Management', 'Data', 'Research', 'Optics']
# Semester project in Bioengineering -> ['Data', 'Research', 'Management', 'Math', 'Optics']
# Applied wastewater engineering -> ['Data', 'Optics']
# Life cycle engineering of polymers -> ['Management', 'Data']
# Introduction to electronic structure methods -> ['Math', 'Data', 'Research', 'Optics']
# CCMX Summer School - Multiscale Modelling of Materials (2016) -> ['Management', 'Data', 'Optics', 'Research', 'Math']
# Introduction to nanomaterials -> ['Optics', 'Math', 'Management', 'Bio/Chem', 'Research', 'Data', 'Thermodynamics']
# CCMX Winter School Surface Science and Coatings -> ['Research', 'Optics', 'Data', 'Management', 'Math']
# Advanced electroanalytical chemistry I -> ['Imagery']
# Basic principles of drug action at the nervous system -> ['Research']
# Quantitative risk management -> ['Management', 'Data']
# Statistics for genomic data analysis -> ['Data', 'Research', 'Management']
# Advanced bioengineering methods laboratory -> ['Research', 'Data', 'Optics', 'Management']
# Scientific project design in translational oncology -> ['Bio/Chem', 'Research', 'Management']
# Optics I -> ['Optics', 'Math']
# Analysis I (English) -> ['Math', 'Data']
# Convex optimization and applications -> ['Data', 'Math', 'Optics']
# Venture capital -> ['Data', 'Management']
# Advanced energetics -> ['Thermodynamics', 'Management', 'Data']
# General physics I (English) -> ['Math', 'Thermodynamics', 'Management', 'Optics']
# Scientific literature analysis in Bioengineering -> ['Research', 'Management', 'Data', 'Optics']
# Biological chemistry III -> ['Research', 'Optics', 'Bio/Chem']
# Tissue engineering -> ['Research', 'Management', 'Bio/Chem', 'Optics', 'Data']
# Localization and Navigation Methods -> ['Optics', 'Math']
# Advanced biomedical imaging methods and instrumentation -> ['Image/Speech processing', 'Optics']
# Scientific project design in synthetic biology (iGEM) -> ['Research', 'Management', 'Data']
# Modelling, optimisation, design and analysis of integrated energy systems -> ['Thermodynamics', 'Data', 'Optics', 'Management']
# Discrete optimization -> ['Data', 'Math']
# HF and VHF circuits and techniques I -> ['Optics', 'Data', 'Management', 'Research', 'Electronics']
# Scientific project design in regenerative medicine and diagnostics -> ['Research', 'Management', 'Data']
# Neutronics -> ['Optics', 'Thermodynamics', 'Math', 'Management']
# Qualitative Research Methods -> ['Research', 'Data', 'Management']
# Numerical flow simulation -> ['Math', 'Data', 'Optics', 'Research', 'Management']
# Reactor Experiments -> ['Optics', 'Thermodynamics']
# Practical - Van der Goot Lab -> ['Bio/Chem', 'Research']
# Biomaterials -> ['Bio/Chem', 'Management', 'Research', 'Optics', 'Data']
# Optical detectors -> ['Optics']
# Introduction to cellular and molecular biotechnology -> ['Data', 'Management', 'Optics', 'Research']
# Optimal control -> ['Data', 'Optics', 'Math']
# Project in computer science II -> ['Management', 'Data', 'Research', 'Optics']
# Image processing I -> ['Optics', 'Image/Speech processing', 'Data']
# Biomineralization: from nature to application -> ['Research', 'Management', 'Data', 'Optics']
# Philosophy of life sciences II -> ['Data', 'Management', 'Research']
# Spacecraft design and system engineering -> ['Management', 'Data', 'Math', 'Research', 'Optics']
# CCMX Advanced Course - Inorganic Particle Synthesis by Precipitation: From Nanoparticles to Self-organised  Mesocrystals and from Theory to Practice -> ['Math']
# Lectures in Life Sciences -> ['Research', 'Data', 'Management']
# Introductory course about Spatial Statistics -> ['Data', 'Math']
# Mathematical methods for physicists -> ['Data', 'Math', 'Optics']
# Selected topics in mechanics of solids and structures -> ['Management', 'Research', 'Math', 'Bio/Chem', 'Data', 'Optics']
# Martingales in financial mathematics -> ['Math', 'Data', 'Management']
# Computational Social Media -> ['Data', 'Math']
# Analog circuits design I -> ['Optics', 'Electronics']
# Advanced numerical analysis -> ['Data', 'Math', 'Optics']
# Aerodynamics -> ['Math']
# Catalyst design for synthesis -> ['Bio/Chem']
# General physics (English) II -> ['Math', 'Bio/Chem', 'Thermodynamics', 'Optics', 'Management']
# Frontiers in Chemical Synthesis. Towards Sustainable Chemistry -> ['Bio/Chem', 'Management', 'Research']
# Science and Engineering Teaching and Learning -> ['Data', 'Management', 'Research']
# B2B - high-tech marketing -> ['Management', 'Data']
# Measuring systems -> ['Optics', 'Data']
# Working Group in Algebraic Groups, I -> ['Data', 'Math', 'Research', 'Management']
# Principles of microeconomics -> ['Data', 'Management', 'Math', 'Research']
# Software-defined radio: A hands-on course -> ['Optics']
# Cognitive psychology B -> ['Research', 'Management', 'Data']
# Modelling problem solving, computing and visualisation I -> ['Data', 'Math', 'Optics']
# Optimization Methods and Models -> ['Data', 'Math', 'Management', 'Optics']
# Nanocomputing: Devices, Circuits and Architectures -> ['Math', 'Management', 'Optics', 'Data']
# Two-phase flows and heat transfer -> ['Thermodynamics', 'Math']
# Theory of materials : from structures to properties -> ['Math', 'Optics', 'Management', 'Bio/Chem', 'Data']
# Technology and Public Policy - (a) Science, technology and society -> ['Management', 'Data']
# Computation of molecular properties -> ['Math', 'Imagery']
# Microbiology -> ['Research', 'Math', 'Bio/Chem']
# Analog circuits design II -> ['Data', 'Electronics', 'Management']
# MINTT: Management of Innovation and technology transfer (EDOC) -> ['Management', 'Data', 'Research']
# Advanced multiprocessor architecture -> ['Management', 'Data', 'Research', 'Math']
# Single cell genomics -> ['Bio/Chem', 'Research']
# Advanced electroanalytical chemistry (II session) -> ['Imagery']
# Computational linear algebra -> ['Data', 'Math', 'Optics']
# Additive Combinatorics -> ['Research', 'Management', 'Optics']
# Production management -> ['Management', 'Data', 'Optics', 'Research', 'Math']
# Packing and covering -> ['Math', 'Data']
# Research project in materials II -> ['Research', 'Data', 'Management', 'Optics', 'Math']
# Molecular quantum dynamics -> ['Math']
# System Identification -> ['Data', 'Optics', 'Research']
# Stochastic calculus II -> ['Math', 'Data']
# Biophysics I -> ['Research', 'Management', 'Bio/Chem', 'Data', 'Math', 'Optics']
# CCMX Winter School - Nanoparticles: From Fundamentals to Applications in Life Sciences -> ['Research', 'Data', 'Optics', 'Bio/Chem', 'Management', 'Math']
# Basic principles of drug action at the cardiovascular system -> ['Research', 'Bio/Chem']
# Commutative algebra -> ['Data', 'Optics']
# Sustainability assessment -> ['Management', 'Data', 'Research']
# Chemical kinetics -> ['Bio/Chem', 'Math', 'Data']
# Decision-aid methodologies in transportation -> ['Data', 'Management', 'Research', 'Optics', 'Math']
# Introduction to environmental engineering -> ['Data', 'Management', 'Bio/Chem', 'Research', 'Math']
# Entrepreneurship & new venture strategy (a) -> ['Management', 'Data', 'Research']
# Renewable energy (for ME) -> ['Thermodynamics', 'Management', 'Optics', 'Data']
# Physical and computational organic chemistry -> ['Bio/Chem', 'Math', 'Research', 'Data', 'Management']
# Signal processing for functional brain imaging -> ['Data', 'Optics', 'Image/Speech processing']
# Design technologies for integrated systems -> ['Data', 'Optics', 'Math', 'Management']
# Structural stability -> ['Research', 'Math', 'Data']
# Translational Robotics for Clinical Rehabilitation -> ['Management', 'Optics', 'Data']
# Microwaves -> ['Optics', 'Data', 'Math']
# Convexity -> ['Data', 'Math']
# Introduction to finance (IF master and minor only) -> ['Management', 'Data', 'Research']
# Practical - Blokesch Lab -> ['Research', 'Bio/Chem', 'Optics']
# Scientific programming for Engineers -> ['Data', 'Math', 'Optics', 'Research']

# %% [markdown]
# ## Exercise 4.11: Wikipedia structure

# %%
rdd_wiki = sc.textFile("/ix/wikipedia-for-schools.txt").map(json.loads) # load the wikipedia data

# %%
# First we need to transform the data into the correct format for LDA

# Aggregate the rdd to get a set of all words
def seq(a,b):
    for el in b['tokens']:
        a.add(el)
    return a
def comb(a,b):
    return a.union(b)
wikiTerms = rdd_wiki.aggregate(set(), seq, comb)

# %%
# Sorted list of all words
wikiTermsList = sorted(list(wikiTerms))
# Mappings from words to their alphabet index
wikiTermsDict = dict(zip(wikiTermsList, range(len(wikiTerms))))

# %%
# Filters for the data

# Checks if given word is a number
def is_number(word):
    try:
        float(word)
        return True
    except ValueError:
        return False

    
# If the word passes the filters and should be in the dataset, returns True, False otherwise
def filter_word(word):
    # Words of len 1
    if len(word) < 2:
        return False
    # Months, directions
    rem_words = set(['january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november'
                ,'december', 'north', 'south', 'east', 'west'])
    if word.lower() in rem_words:
        return False
    
    # Removing words consisting of a punctuation sign
    if word in string.punctuation:
        return False
    # Removing numbers
    if is_number(word):
        return False
    return True

# %%
# Create a bag of words from an rdd entry
def createBOW(termList):
    resDict = {}
    for term in termList['tokens']:
        if (filter_word(term)):
            resDict[term] = resDict.get(term, 0) + 1
    return resDict

# Create a sparse term vector from a bag of words
def createSparseTermVector(bow):
    values = []
    indices = []
    for k,v in sorted(bow.items(), key=lambda x:x[0]):
        values.append(v)
        indices.append(wikiTermsDict[k])
    return Vectors.sparse(len(values), indices, values)

def mapFunc(el):
    return [el['page_id'], createSparseTermVector(createBOW(el))]

vectorsRDD = rdd_wiki.map(mapFunc).persist()

# %%
# Print the top 10 words for each topic from the lda model's topic description
def topWords(ldaTopicDesc, wordList):
    for topic in ldaTopicDesc:
        termList = []
        for i in range(10):
            termList.append(wordList[topic[0][i]])
            
        print(termList)

# %% [markdown]
# We had two ideas of hyperparameters for the wikipedia dataset. The goal of the first one is to find more precise topics for instance a country or different kinds of art and to this end it uses balanced values of alpha (3.4) and beta (3.5) while the second one uses a high value of alpha (10) and a low value of beta (1.91) with the aim of finding very broad topics like history, sports or science. We chose a higher value of k for the first idea (20) than for the second (10).

# %%
# Train the model and print the top words for each topic

wiki_ldaModel = LDA.train(vectorsRDD, k=20, docConcentration=3.4, topicConcentration=3.5, seed=10)
topDesc = wiki_ldaModel.describeTopics()
topWords(topDesc, wikiTermsList)
# Out:
# ['war', 'government', 'army', 'battle', 'empire', 'military', 'republic', 'king', 'forces', 'city']
# ['time', 'universe', 'theory', 'years', 'matter', 'number', 'made', 'work', 'series', 'big']
# ['river', 'world', 'century', 'population', 'german', 'state', 'area', 'soviet', 'people', 'part']
# ['light', 'form', 'glass', 'called', 'system', 'number', 'made', 'time', 'high', 'standard']
# ['blood', 'disease', 'cells', 'cell', 'common', 'process', 'windows', 'treatment', 'system', 'cancer']
# ['united', 'england', 'war', 'world', 'american', 'city', 'president', 'british', 'government', 'won']
# ['species', 'water', 'oil', 'plants', 'acid', 'found', 'food', 'form', 'plant', 'birds']
# ['game', 'time', 'work', 'system', 'theory', 'life', 'called', 'law', 'number', 'set']
# ['number', 'numbers', 'theory', 'function', 'set', 'mathematics', 'real', 'space', 'called', 'time']
# ['energy', 'nuclear', 'gas', 'number', 'reaction', 'chemical', 'water', 'element', 'form', 'temperature']
# ['music', 'album', 'time', 'band', 'years', 'song', 'songs', 'rock', 'made', 'called']
# ['time', 'world', 'english', 'years', 'ford', 'early', 'century', 'made', 'states', 'american']
# ['government', 'united', 'city', 'states', 'war', 'world', 'state', 'national', 'economic', 'years']
# ['states', 'american', 'united', 'people', 'world', 'english', 'century', 'years', 'countries', 'state']
# ['american', 'city', 'british', 'calendar', 'united', 'london', 'actor', 'film', 'john', 'english']
# ['black', 'music', 'time', 'years', 'early', 'work', 'made', 'called', 'century', 'tea']
# ['open', 'large', 'species', 'years', 'world', 'early', 'number', 'including', 'population', 'called']
# ['aircraft', 'series', 'test', 'time', 'pope', 'italy', 'rome', 'ships', 'australia', 'day']
# ['church', 'century', 'god', 'roman', 'christian', 'catholic', 'religious', 'great', 'people', 'jesus']
# ['earth', 'solar', 'sun', 'km', 'surface', 'hurricane', 'star', 'stars', 'storm', 'planet']

# %% [markdown]
# The idea behind the first set of parameters was to find a good balance bewteen alpha and beta to find a lot of meaningful topics. Its parameters values were inspired by the results of the epfl courses topic extraction. We raised alpha because we estimated that wikipedia articles would probably contain more topics than epfl courses and thought about lowering beta to prevent the many words of the articles from polluting the topics but decided against it because we thought that the higher number of meaningful words would balance it.
#
# It worked well for some topics and less well for others. We can see that several topics seem to be related to war and governments in general (1, 6, 13, 18) and a few others seem linked to history and countries (12, 14). Some of the topics on the other hand are very precise and not corrupted by weird outliers like topic 11 that is clearly about music and topic 20 that talks about planets, stars and space in general.
#
# Overall the results are not very good and too many topics are nonsensical or not distinguishable enough to be interpreted in a meanigful way.

# %%
# Train the model and print the top words for each topic

wiki_ldaModel = LDA.train(vectorsRDD, k=10, docConcentration=10.0, topicConcentration=1.91, seed=10)
topDesc = wiki_ldaModel.describeTopics()
topWords(topDesc, wikiTermsList)
# Out:
# ['time', 'states', 'hurricane', 'storm', 'people', 'island', 'tropical', 'system', 'number', 'united']
# ['water', 'energy', 'form', 'chemical', 'acid', 'called', 'number', 'temperature', 'process', 'high']
# ['music', 'american', 'film', 'time', 'played', 'years', 'player', 'play', 'year', 'world']
# ['king', 'english', 'century', 'church', 'england', 'calendar', 'war', 'great', 'empire', 'god']
# ['government', 'war', 'united', 'states', 'world', 'british', 'union', 'africa', 'country', 'economic']
# ['chinese', 'china', 'language', 'century', 'population', 'islands', 'world', 'river', 'republic', 'number']
# ['species', 'found', 'years', 'early', 'time', 'birds', 'made', 'large', 'family', 'genus']
# ['time', 'earth', 'sun', 'years', 'star', 'stars', 'mass', 'solar', 'system', 'planet']
# ['war', 'american', 'city', 'united', 'president', 'british', 'states', 'army', 'john', 'time']
# ['city', 'area', 'time', 'set', 'theory', 'number', 'centre', 'lake', 'large', 'called']

# %% [markdown]
# The idea behind the second set of parameters was to find all of the topics that were mentioned in the documents (high alpha) but only consider the most relevant words of each documents (low beta). We hoped that this would result in very general topics.
#
# The results are quite good with three topics that look similar (4, 5 and 9) although they are not exactly the same. Topic 7 looks weird as well and does not include a lot of meaningful words that could give us a good idea of what its subject is.
#
# Labels for the produced topics could be:
# 1. Tropical weather
# 2. Chemistry
# 3. Entertainment
# 4. War (older, american independance)
# 5. War (newer, ww2)
# 6. China
# 7. Species classification
# 8. Space
# 9. War
# 10. Urban environment
#
# Overall these results are quite promising and we think that the second idea is the better one to interpret this dataset.
