# %% [markdown]
# # Text 3: Latent Dirichlet allocation
# **Internet Analytics - Lab 4**
#
# ---
#
# **Group:** *O*
#
# **Names:**
#
# * *Argelaguet Franquelo, Pau*
# * *du Bois de Dunilac, Vivien*
#
# ---
#
# #### Instructions
#
# *This is a template for part 3 of the lab. Clearly write your answers, comments and interpretations in Markodown cells. Don't forget that you can add $\LaTeX$ equations in these cells. Feel free to add or remove any cell.*
#
# *Please properly comment your code. Code readability will be considered for grading. To avoid long cells of codes in the notebook, you can also embed long python functions and classes in a separate module. Don’t forget to hand in your module if that is the case. In multiple exercises, you are required to come up with your own method to solve various problems. Be creative and clearly motivate and explain your methods. Creativity and clarity will be considered for grading.*

# %%
from pyspark.mllib.clustering import LDA, LDAModel
from pyspark.mllib.linalg import Vectors

import json
import pickle
import numpy as np
import string
import collections
import operator
import math

from functools import reduce
from scipy.sparse import csr_matrix
from utils import load_json, load_pkl, save_pkl

# %%
courses = load_json('data/courses.txt')
preprocessed = load_pkl('data/preprocess.pckl')
terms = load_pkl('data/terms.pckl')

# %%
mat = load_pkl('data/mat.pckl')
doc = load_pkl('data/documents.pckl')
stopwords = load_pkl('data/stopwords.pkl')

# %% [markdown]
# ## Exercise 4.8: Topics extraction

# %%
print(list(list(preprocessed.items())[0][1]['description'].items()))
# Out:
# [('adapt', 2), ('adapt composit', 2), ('applic', 2), ('biocomposit', 2), ('composit', 12), ('composit applic', 2), ('cost', 2), ('develop', 2), ('nanocomposit', 2), ('perform', 2), ('polym', 2), ('product', 3), ('team', 2)]

# %%
def createTermVector(bagOfWord):
    countList = []
    for term in terms:
        countList.append(bagOfWord.get(term, 0))
    return Vectors.dense(countList)

# %%
vectorList = []
counter = 1
for it in list(preprocessed.items()):
    vectorList.append([counter, createTermVector(it[1]['description'])])
    counter += 1
rdd = sc.parallelize(vectorList)

# %%
def pTop(ldaModel, nWords=10):
    for topic in ldaModel.describeTopics():
        termList = []
        for i in range(nWords):
            termList.append(terms[topic[0][i]])
        print(termList)

# %% [markdown]
# ### Variying ALPHA

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=1.01)
pTop(ldaModel)
# Out:
# ['heat', 'communic', 'chemic', 'electron', 'applic', 'reaction', 'algorithm', 'linear', 'comput', 'flow']
# ['energi', 'report', 'skill', 'evalu', 'data', 'plan', 'convers', 'comput', 'week', 'technolog']
# ['physic', 'equat', 'problem', 'mass', 'properti', 'structur', 'group', 'applic', 'solv', 'mechan']
# ['energi', 'paper', 'engin', 'discuss', 'industri', 'busi', 'cell', 'assess', 'team', 'technolog']
# ['problem', 'program', 'comput', 'optim', 'numer', 'research', 'linear', 'algorithm', 'plan', 'signal']
# ['data', 'network', 'robot', 'control', 'algorithm', 'magnet', 'water', 'assess', 'exam', 'architectur']
# ['electron', 'stochast', 'financi', 'control', 'architectur', 'applic', 'function', 'comput', 'linear', 'theori']
# ['simul', 'studi', 'case', 'risk', 'data', 'manag', 'assess', 'case studi', 'mechan', 'activ']
# ['biolog', 'chemic', 'organ', 'structur', 'chemistri', 'develop', 'reaction', 'scientif', 'evalu', 'molecular']
# ['optic', 'microscopi', 'electron', 'mechan', 'quantum', 'spectroscopi', 'laser', 'applic', 'principl', 'imag']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=3.0)
pTop(ldaModel)
# Out:
# ['report', 'flow', 'linear', 'problem', 'skill', 'numer', 'data', 'scientif', 'optim', 'experiment']
# ['electron', 'quantum', 'theori', 'cell', 'microscopi', 'applic', 'magnet', 'structur', 'introduct', 'risk']
# ['circuit', 'architectur', 'devic', 'field', 'sensor', 'activ', 'signal', 'robot', 'integr', 'techniqu']
# ['optic', 'biolog', 'paper', 'laser', 'discuss', 'chemic', 'protein', 'physic', 'chemistri', 'interact']
# ['case', 'studi', 'manag', 'cell', 'power', 'applic', 'case studi', 'engin', 'group', 'wast']
# ['energi', 'engin', 'thermodynam', 'numer', 'physic', 'dure', 'convers', 'environment', 'comput', 'technolog']
# ['control', 'mechan', 'structur', 'properti', 'function', 'fundament', 'fractur', 'measur', 'problem', 'statist']
# ['organ', 'structur', 'engin', 'machin', 'network', 'properti', 'transport', 'physic', 'program', 'metal']
# ['data', 'develop', 'week', 'innov', 'research', 'technolog', 'plan', 'assess', 'evalu', 'differ']
# ['imag', 'stochast', 'theori', 'probabl', 'introduct', 'time', 'optim', 'equat', 'risk', 'differenti']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=5.0)
pTop(ldaModel)
# Out:
# ['statist', 'program', 'data', 'linear', 'optim', 'problem', 'algorithm', 'theori', 'comput', 'function']
# ['control', 'engin', 'circuit', 'robot', 'filter', 'oper', 'week', 'power', 'imag', 'integr']
# ['paper', 'electron', 'control', 'field', 'data', 'water', 'discuss', 'solid', 'energi', 'devic']
# ['report', 'skill', 'laser', 'research', 'quantum', 'evalu', 'laboratori', 'data', 'activ', 'organ']
# ['simul', 'market', 'price', 'flow', 'scientif', 'architectur', 'develop', 'research', 'theori', 'physic']
# ['optic', 'energi', 'fourier', 'risk', 'solv', 'algebra', 'imag', 'physic', 'problem', 'measur']
# ['mechan', 'magnet', 'applic', 'structur', 'properti', 'physic', 'organ', 'metal', 'communic', 'electron']
# ['stochast', 'numer', 'reactor', 'architectur', 'develop', 'visual', 'final', 'imag', 'assess', 'urban']
# ['biolog', 'cell', 'protein', 'signal', 'structur', 'molecular', 'optic', 'dynam', 'applic', 'note']
# ['studi', 'case', 'chemic', 'assess', 'group', 'case studi', 'reaction', 'class', 'product', 'evalu']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=7.5)
pTop(ldaModel)
# Out:
# ['electron', 'sensor', 'techniqu', 'applic', 'product', 'industri', 'communic', 'devic', 'principl', 'technolog']
# ['linear', 'statist', 'probabl', 'introduct', 'stochast', 'price', 'financi', 'imag', 'measur', 'market']
# ['paper', 'teach', 'scienc', 'space', 'theori', 'architectur', 'comput', 'research', 'group', 'scale']
# ['biolog', 'field', 'engin', 'structur', 'problem', 'assess', 'physic', 'research', 'skill', 'energi']
# ['optic', 'structur', 'mechan', 'quantum', 'laser', 'molecular', 'protein', 'function', 'statist', 'applic']
# ['energi', 'control', 'optim', 'program', 'data', 'risk', 'network', 'engin', 'communic', 'power']
# ['case', 'imag', 'studi', 'integr', 'function', 'group', 'activ', 'topic', 'fourier', 'circuit']
# ['chemic', 'flow', 'reaction', 'equat', 'chemistri', 'magnet', 'heat', 'physic', 'thermodynam', 'transfer']
# ['report', 'data', 'experiment', 'week', 'skill', 'scientif', 'laboratori', 'robot', 'written', 'stabil']
# ['develop', 'semest', 'innov', 'architectur', 'numer', 'cell', 'week', 'dure', 'comput', 'evalu']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=10.0)
pTop(ldaModel)
# Out:
# ['optic', 'laser', 'reaction', 'studi', 'theori', 'microscopi', 'problem', 'reactor', 'evalu', 'measur']
# ['data', 'imag', 'program', 'comput', 'statist', 'algorithm', 'signal', 'final', 'practic', 'visual']
# ['electron', 'communic', 'simul', 'robot', 'energi', 'flow', 'equat', 'introduct', 'circuit', 'price']
# ['biolog', 'protein', 'comput', 'molecular', 'interact', 'quantum', 'architectur', 'function', 'dynam', 'theori']
# ['numer', 'engin', 'magnet', 'teach', 'equat', 'mathemat', 'probabl', 'biolog', 'practic', 'properti']
# ['paper', 'semest', 'discuss', 'product', 'assess', 'environment', 'econom', 'research', 'innov', 'studi']
# ['report', 'evalu', 'develop', 'research', 'scientif', 'data', 'problem', 'experiment', 'optim', 'skill']
# ['cell', 'control', 'chemic', 'energi', 'metal', 'thermodynam', 'mechan', 'organ', 'electron', 'convers']
# ['structur', 'energi', 'mechan', 'manag', 'control', 'group', 'risk', 'inform', 'assess', 'dynam']
# ['physic', 'field', 'devic', 'differ', 'industri', 'activ', 'group', 'plan', 'sensor', 'provid']

# %% [markdown]
# ### Variying BETA

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=1.01, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['structur', 'mechan', 'comput', 'quantum', 'numer', 'cell', 'dynam', 'simul', 'applic', 'solv']
# ['control', 'protein', 'biolog', 'imag', 'research', 'network', 'develop', 'activ', 'chemic', 'studi']
# ['report', 'problem', 'evalu', 'plan', 'data', 'skill', 'optim', 'scientif', 'assess', 'studi']
# ['flow', 'physic', 'practic', 'teach', 'skill', 'theori', 'test', 'equat', 'product', 'technolog']
# ['electron', 'devic', 'imag', 'microscopi', 'structur', 'techniqu', 'properti', 'chemistri', 'integr', 'organ']
# ['risk', 'manag', 'magnet', 'market', 'differ', 'financi', 'case', 'price', 'assess', 'introduct']
# ['engin', 'paper', 'field', 'biolog', 'discuss', 'reaction', 'communic', 'chemic', 'activ', 'circuit']
# ['energi', 'mass', 'industri', 'thermodynam', 'heat', 'environment', 'evalu', 'water', 'chemic', 'convers']
# ['statist', 'signal', 'linear', 'probabl', 'stochast', 'theori', 'data', 'robot', 'time', 'control']
# ['optic', 'data', 'cell', 'algorithm', 'laser', 'note', 'function', 'program', 'applic', 'structur']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=3.0, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['cell', 'biolog', 'applic', 'organ', 'chemic', 'physic', 'signal', 'function', 'reaction', 'activ']
# ['problem', 'numer', 'comput', 'linear', 'theori', 'optim', 'algorithm', 'program', 'statist', 'equat']
# ['optic', 'microscopi', 'electron', 'applic', 'imag', 'physic', 'principl', 'equat', 'control', 'theori']
# ['energi', 'heat', 'convers', 'thermodynam', 'architectur', 'magnet', 'transfer', 'physic', 'case', 'technolog']
# ['network', 'technolog', 'applic', 'theori', 'control', 'activ', 'communic', 'techniqu', 'imag', 'develop']
# ['data', 'report', 'research', 'evalu', 'scientif', 'skill', 'plan', 'assess', 'experiment', 'problem']
# ['structur', 'week', 'class', 'engin', 'control', 'assess', 'group', 'activ', 'develop', 'evalu']
# ['laser', 'quantum', 'physic', 'mechan', 'biolog', 'architectur', 'chemic', 'electron', 'engin', 'principl']
# ['electron', 'applic', 'theori', 'mechan', 'signal', 'structur', 'techniqu', 'introduct', 'devic', 'properti']
# ['imag', 'applic', 'physic', 'mechan', 'engin', 'properti', 'theori', 'techniqu', 'activ', 'biolog']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=5.0, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['data', 'problem', 'assess', 'activ', 'control', 'optic', 'evalu', 'comput', 'energi', 'applic']
# ['electron', 'energi', 'imag', 'applic', 'structur', 'physic', 'biolog', 'control', 'activ', 'mechan']
# ['problem', 'comput', 'data', 'assess', 'applic', 'evalu', 'activ', 'theori', 'structur', 'optim']
# ['biolog', 'structur', 'physic', 'mechan', 'applic', 'chemic', 'energi', 'assess', 'cell', 'engin']
# ['energi', 'applic', 'structur', 'data', 'optic', 'electron', 'theori', 'assess', 'problem', 'physic']
# ['structur', 'optic', 'problem', 'applic', 'electron', 'data', 'biolog', 'physic', 'theori', 'activ']
# ['data', 'engin', 'problem', 'structur', 'activ', 'theori', 'assess', 'applic', 'evalu', 'comput']
# ['electron', 'optic', 'energi', 'applic', 'structur', 'physic', 'mechan', 'control', 'theori', 'properti']
# ['structur', 'optic', 'problem', 'applic', 'comput', 'theori', 'biolog', 'physic', 'mechan', 'activ']
# ['report', 'data', 'evalu', 'research', 'assess', 'problem', 'technolog', 'skill', 'activ', 'engin']

# %%
ldaModel = LDA.train(rdd, k=10, topicConcentration=7.0, docConcentration=6.0)
pTop(ldaModel)
# Out:
# ['structur', 'electron', 'applic', 'data', 'problem', 'physic', 'mechan', 'energi', 'assess', 'activ']
# ['energi', 'data', 'problem', 'assess', 'structur', 'applic', 'evalu', 'activ', 'comput', 'theori']
# ['data', 'energi', 'evalu', 'assess', 'problem', 'activ', 'report', 'applic', 'structur', 'comput']
# ['optic', 'applic', 'problem', 'energi', 'activ', 'electron', 'assess', 'theori', 'structur', 'comput']
# ['data', 'optic', 'structur', 'applic', 'problem', 'theori', 'assess', 'activ', 'comput', 'evalu']
# ['structur', 'applic', 'problem', 'theori', 'assess', 'data', 'activ', 'comput', 'evalu', 'physic']
# ['problem', 'structur', 'applic', 'comput', 'theori', 'data', 'assess', 'activ', 'physic', 'mechan']
# ['structur', 'data', 'problem', 'assess', 'applic', 'engin', 'activ', 'evalu', 'theori', 'comput']
# ['data', 'applic', 'structur', 'problem', 'assess', 'engin', 'energi', 'activ', 'evalu', 'comput']
# ['assess', 'structur', 'evalu', 'problem', 'applic', 'data', 'activ', 'engin', 'theori', 'research']

# %% [markdown]
# ### Optimized parameters

# %%
# k = number of topics, alpha(doc) higher alpha means more different topics per document
# beta(topic) higher beta means more words per topic
ldaModel = LDA.train(rdd, k=20, docConcentration=2.51, topicConcentration=1.61, seed=10)

# print the top x terms for each topic
pTop(ldaModel, 10)
# Out:
# ['cell', 'properti', 'mechan', 'applic', 'magnet', 'structur', 'physic', 'function', 'molecular', 'part']
# ['stabil', 'measur', 'water', 'treatment', 'snow', 'physic', 'wastewat', 'atmospher', 'field', 'control']
# ['structur', 'manag', 'risk', 'case', 'assess', 'reactor', 'mechan', 'class', 'week', 'case studi']
# ['chemistri', 'reaction', 'equat', 'organ', 'chemic', 'differenti', 'synthesi', 'engin', 'stochast', 'food']
# ['data', 'secur', 'network', 'statist', 'seri', 'time', 'hour', 'time seri', 'practic', 'regress']
# ['report', 'control', 'data', 'skill', 'plan', 'evalu', 'optim', 'scientif', 'experiment', 'research']
# ['linear', 'signal', 'statist', 'communic', 'probabl', 'code', 'theori', 'signal process', 'filter', 'algorithm']
# ['busi', 'innov', 'group', 'problem', 'class', 'inform', 'market', 'set', 'theori', 'rate']
# ['optic', 'numer', 'principl', 'laser', 'physic', 'applic', 'sensor', 'comput', 'transfer', 'heat']
# ['research', 'network', 'social', 'data', 'understand', 'brain', 'function', 'neuron', 'studi', 'media']
# ['languag', 'program', 'problem', 'compil', 'function', 'machin', 'transport', 'optim', 'semest', 'cours student']
# ['cancer', 'privaci', 'scienc', 'comput', 'teach', 'inform', 'technolog', 'effect', 'tumor', 'protect']
# ['quantum', 'circuit', 'devic', 'integr', 'theori', 'electron', 'applic', 'print', 'mechan', 'function']
# ['space', 'metal', 'qualiti', 'alloy', 'powder', 'phase', 'physic', 'engin', 'import', 'la']
# ['energi', 'thermodynam', 'test', 'convers', 'price', 'main', 'financ', 'financi', 'energi convers', 'effici']
# ['architectur', 'program', 'algorithm', 'engin', 'machin', 'studio', 'urban', 'tool', 'industri', 'complex']
# ['biolog', 'chemic', 'paper', 'protein', 'discuss', 'molecular', 'mass', 'engin', 'product', 'critic']
# ['electron', 'imag', 'microscopi', 'sampl', 'techniqu', 'diffract', 'transmiss', 'electron microscopi', 'tem', 'applic']
# ['power', 'comput', 'flow', 'simul', 'control', 'fluid', 'convert', 'grid', 'dynam', 'electr']
# ['develop', 'technolog', 'group', 'oral', 'studi', 'engin', 'polici', 'content', 'manag', 'wast']

# %%
topicLabels = dict(zip(range(20), ['Cellular biology', 'Environment', 'Risk management', 'Chemistry', 'Data applications', 'Lab environment',
              'Signal processing', 'Business', 'Physics', 'Machine learning', 'Computer language processing',
              'Cancer', 'Micro/Nano-electronics', 'Materials', 'Thermodynamics', 'Architecture/Design',
              'Biology', 'Imagery', 'Electricity/Power', 'Applied science']))

# %%
def extractTopics(ldaModel, nWords=10):
    topicList = []
    for topic in ldaModel.describeTopics():
        termList = []
        for i in range(nWords):
            termList.append(terms[topic[0][i]])
        topicList.append(termList)
    return topicList

# %%
courseTopics = extractTopics(ldaModel, 25)
topicLabels = range(len(courseTopics))
#topicLabels = ['Imagery', 'Scientific methodology', 'Statistics', 'Biology/Chemistry', 'Signal/Image processing', 'Energy', 'Lab environment', 'Maths', 'Stochastic models', 'Programming', 'Business', 'Organization']

# %%
for course in preprocessed.items():
    topics = []
    for i in range(len(courseTopics)):
        count = 0
        t = courseTopics[i]
        for word in course[1]['description']:
            if word in t:
                count += 1
        if count > 4:
            topics.append(topicLabels[i])
    print(course[1]['name'], topics)
# Out:
# Composites technology []
# Image Processing for Life Science []
# Global business environment [2, 7, 19]
# Electrochemical nano-bio-sensing and bio/CMOS interfaces []
# Structural mechanics (for MT) []
# Théorie et critique du projet MA2 (Boltshauser) [5, 19]
# Advanced principles and applications of systems biology []
# Mass spectrometry [16]
# Principles of digital communications [6]
# Hardware systems modeling I []
# Quantitative systems modeling techniques []
# Medical radiation physics [8]
# Bio-nano-chip design []
# Principles of powder and densification processing [13]
# Fundamentals of solid-state materials []
# Microeconomics [7]
# Polymer chemistry and macromolecular engineering []
# Physical chemistry of polymeric materials []
# Fundamentals of neuroengineering []
# In Silico neuroscience []
# Materials selection [2, 7]
# Optics laboratories I [5, 8, 9, 11, 19]
# Fracture mechanics []
# Air pollution and climate change
#  []
# Philosophy of life sciences I [2, 5, 7, 9, 10, 11, 19]
# Lab methods : proteomics [4]
# Cementitious materials (advanced) [16]
# Material and energy flow analysis []
# Linear algebra (english) []
# Transport phenomena II []
# Printed systems and large area manufacturing [2, 7, 8, 12, 16]
# Theoretical computer science [6]
# Philosophy, epistemology and history of science I [11]
# Reservoir mechanics for geo-energy and the environment [0]
# Non linear analysis of structures []
# Investments [7, 14]
# Engines and fuel cells [8, 14]
# Recycling of materials [19]
# Statistical signal and data processing through applications [6]
# Analysis II (English) []
# Technology & innovation strategy [2, 5, 7, 11, 19]
# Lab immersion I [5, 11, 19]
# Internet analytics [4, 6, 9, 10, 15]
# Supply chain management [2, 7, 11, 19]
# Particle-based methods [18, 19]
# Statistical Sequence Processing [6]
# Solid state image sensing [3, 8, 11, 12]
# Soft matter []
# Advanced regression [4, 6]
# Introduction to database systems [2, 5, 10]
# Hydraulic turbomachines []
# Design and analysis of experiments in materials science and engineering []
# Business design for IT services [7]
# Some problems in the theory of simple groups []
# Simulation and optimisation of industrial applications [2, 7]
# Biomicroscopy II [8, 17]
# Modelling problem solving, computing and visualisation II [11]
# Frontiers in Organic Synthesis. Part III Stereochemistry [3]
# Photonic micro- and nanosystems [8, 12]
# Safety of chemical processes [2, 7]
# Probabilities and statistics [4]
# Practical - Fellay Lab []
# CCMX Winter School - Metal Science [13]
# Mobile robots []
# Leading research in Chemical Engineering (a) [3]
# Fluvial biogeosciences [1, 5, 9, 10, 11]
# Biochemistry II []
# Micro-magnetic field sensors and actuators []
# Diffraction methods in structural biology [17]
# Practical - Gönczy Lab []
# Principles and Practicals in X-Ray Scattering []
# Frederic Joliot/Otto Hahn Summer School on nuclear reactors Physics, fuels and systems []
# Computational finance [14]
# Applied stochastic processes []
# Structure and evolution of galaxies (UNIGe) []
# Numerical integration  of stochastic differential equations [3]
# Immunology [5, 11, 19]
# Thin film fabrication processes []
# Studio MA1 (Lütjens et Padmanabhan) []
# Théorie et critique du projet MA1 (Huang) [5, 7, 11, 15, 19]
# Biomedical signal processing [6]
# Current Topics in Chemical Biology 2 []
# Physics and hydrology of snow [1]
# Nuclear magnetic resonance []
# Limestone-Calcined Clay - Cement : Characterisation methods []
# Advanced materials for photovoltaics and lighting [0, 12]
# Nanoelectronics [12]
# PhD Masterclass - The horizontal metropolis and other research questions []
# Mapping urban history [7]
# Topics in Autonomous Robotics []
# Speech processing [6]
# Mathematical models in supply chain management [2, 15, 16]
# Practical - Simanis Lab []
# Image communication []
# Plasma Diagnostics in Basic Plasma Physics Devices and Tokamaks: from Principles to Practice []
# Nanophotonics and plasmonics []
# Computational photography [8, 11, 18, 19]
# Information literacy for chemists []
# Distributed algorithms []
# Entrepreneurship laboratory (e-lab) [7]
# Introduction to planetary sciences [4, 5]
# Biomedical optics [8]
# Quality assurance and quality management systems [13]
# Non-destructive evaluation methods []
# Concepts in ecological engineering [5]
# Molecular endocrinology [19]
# Privacy Protection [4, 7, 9, 11]
# Synthesis, analysis and verification [0, 4, 5, 9, 10, 11, 18]
# Chemical engineering lab & project [5]
# Mathematical modelling of DNA []
# Industry dynamics, models & trends [19]
# Optics II []
# Multivariable control and coordination systems []
# Science and technology of UV-induced polymerization []
# Lab methods : animal experimentation []
# Structure and reactivity []
# Macrofinance [4, 5, 7, 14, 19]
# Operations: economics & strategy [2, 5]
# Inorganic chemistry "Applications and spin-offs" [3]
# Analytic algorithms [6, 10]
# Geomechanics []
# Database systems []
# How people learn II [5, 9, 19]
# Biomolecular structure and mechanics [0, 5, 11, 16]
# Practical - De Palma Lab []
# Distributed intelligent systems [5]
# Research project in materials I [5]
# Nutrition: from molecules to health []
# Wood structures, properties and uses [0]
# Corporate governance [19]
# Scientific literature analysis in Computational molecular biology [7, 11, 16, 19]
# Mechanisms of cell motility []
# Specialisation project in materials [5]
# Making structural logic [2]
# Biotechnology lab (for CGC) []
# Bioprocesses and downstream processing [0, 3, 16]
# Algebraic curves and cryptography [7]
# Image and video processing [4, 6]
# Biochemical engineering [0, 3, 16]
# Analog circuits for biochip []
# Advanced wireless communications: algorithms and architectures []
# Numerical methods in biomechanics [19]
# Practical - Cole Lab []
# Functional Data Analysis []
# TCP/IP networking [5, 9, 18]
# Introduction to particle accelerators []
# Technology and Public Policy - (d) Technology policies for grand and global challenges []
# Technology and Public Policy - (b) Technology, policy and regulation [19]
# Principles of computer systems [9, 10, 15]
# Physics and chemistry of the atmosphere [5, 11]
# Biomechanics of the musculoskeletal system [19]
# Studio BA4 (De Vylder & Taillieu) []
# Practical - Trono Lab []
# Highlights in microtechnology []
# Transport phenomena I [3, 8]
# International Finance []
# Chemical biology - tools and methods [16]
# Experimental cognitive psychology I [2, 5, 7, 9, 10, 11, 19]
# Topics on Datacenter Design []
# Mechanical design principles []
# Scanning and Analytical Transmission Electron Microscopy [17]
# Computational perception using multimodal sensors []
# Supramolecular chemistry []
# Biological modeling of neural networks [3, 4, 9, 11]
# Automatic speech processing [0, 6]
# Dielectric properties of materials [0, 12]
# Using Mathematica to analyse and model experimental data []
# Process development II []
# Large-area electronics: devices and materials [0, 8, 12, 13, 17]
# Chemosensory receptors: Applications for biosensors and medical therapies []
# Risk management [2]
# Distributed information systems []
# Mathematical modelling of behavior []
# Empirical Asset Pricing []
# Risk and energy [2, 5, 7, 15, 19]
# Coordination chemistry and reactivity of f elements [3]
# UE U : Cartography [4, 7, 15]
# Optional project in Systems engineering [5, 15]
# Energy Regulation (2016) []
# Computational motor control [18]
# Data converter circuits and systems [12]
# Molecular and cellular biophysic I [0, 16]
# Systems and architectures for signal processing [2, 5, 6, 7, 11, 15]
# Tokamak Plasma Control []
# Training Rotation (EDMS) []
# Nanotechnology [0]
# Metrology I []
# Advanced algorithms [4, 6]
# Project in neuroprosthetics [5]
# Electrochemistry for materials technology []
# Quantum electrodynamics and quantum optics [8]
# Scientific literature analysis in molecular and cancer biology [7, 11, 16, 19]
# Rings and modules []
# Practical - Suter Lab []
# Unsupervised and reinforcement learning in neural networks [4, 6]
# Optics and technology of liquid crystal displays []
# Hot Topics in Cancer Research [16]
# Lab in microelectronics []
# Linear models []
# Principles and applications of systems biology [9, 11, 16, 19]
# Statistical Physics for Communication and Computer Science []
# Economics of innovation in the biomedical industry [4, 5, 7]
# Introduction to transport phenomena []
# Magnetic and semiconducting nanostructures []
# Experimental Geomechanics []
# Experimental cognitive psychology II [5]
# Photochemistry I [8]
# Stem cell biology and technology [0]
# Powder technology [13]
# Credit risk []
# Parabolic and hyperbolic PDE's []
# Powder Characterisation and Dispersion []
# IEEE Sensors Council Summer School on Nano-Bio-Sensing [12]
# Leading research in Chemical Engineering (b) [3]
# Numerical methods in heat transfer [4, 5, 8, 9, 10, 11, 15, 18, 19]
# Théorie et critique du projet MA1 (Gugger) []
# Test of VLSI systems []
# Laser microprocessing [8]
# UE N : Art et architecture: constructing the view II [5, 19]
# Empirical Corporate Finance []
# IC design for robustness []
# Introduction to econometrics []
# Radiation protection & radiation applications []
# Semiconductor physics and fundamentals of electronic devices [11, 12]
# Chemical engineering product design [16]
# Computer simulation of physical systems I [0]
# Chemical biology [16]
# Experimental design and data analysis with R [4, 6]
# Introduction to natural language processing []
# Mobile networks []
# Philosophy, epistemology and history of science II []
# Optical communications []
# Low-voltage analog CMOS IC design []
# Nano CMOS Devices & Technologies for Tera-Bit Circuits and Systems [12]
# Quantitative methods II []
# Trends in Metabolism & Physiology [10]
# Media security [4]
# Markov chains and algorithmic applications [6]
# Energy systems engineering [14]
# Surfaces and interfaces []
# Lasers and applications in chemistry [5, 8, 9, 10, 19]
# Working Group in Algebraic Groups, II []
# Chemistry of food processes [3, 5]
# Selected topics in advanced optics [5, 8]
# Product lifecycle management - concepts methods and tools [7]
# Project in bioengineering and biosciences [2, 5, 10, 11, 19]
# Introduction to Algebraic geometry []
# Lab immersion academic (outside EPFL) A [5, 9, 10, 11, 19]
# Biomaterials (pour MX) []
# D. Thinking: real problems, human-focused solutions []
# Financial big data [2, 4, 5, 7, 9, 10, 15, 19]
# Human language technology: applications to information access [5]
# Modeling and simulation of microsystems [0]
# Synergism between Art of Total Synthesis and High Level Strategic Design (MOM) []
# Topics in geometric analysis I []
# Scanning electron microscopy techniques (b) [17]
# Lab in acoustics []
# Bioelectronics and implantable biomedical microelectronics [5, 12]
# Introduction to operating systems []
# Solar photovoltaics and energy systems []
# Nonlinear signal modeling and prediction []
# Theoretical corporate finance []
# Neurosciences II : cellular mechanisms of brain function [0, 9]
# Digital education & learning analytics []
# Frontiers in Organic Synthesis. Part II Synthesis of carbo- and hetero-cycles [3]
# Hardware systems modeling []
# Statistical thermodynamics [12]
# Applied data analysis [4, 5, 7, 9, 10, 11, 15, 18]
# Electron microscopy: advanced methods [17]
# Modeling of emerging electron devices []
# Scientific literature analysis in cell and developmental biology [3, 5, 16, 19]
# Numerical approximation of PDE's II []
# Control systems   TP [5]
# Project in biomedical technologies []
# Practical - Hantschel Lab []
# Classical electrodynamics [8]
# Pattern classification and machine learning [4, 5, 6, 10, 15]
# Industrial electronics I [18]
# CCMX Advanced Course 'Advanced X-ray Diffraction Methods for Coatings: strain, defects and deformation analysis of thin films []
# Molecular and cellular biophysic II [16]
# CCMX Advanced Course - Instrumented Nanoindentation [17]
# Electronic properties of solids and superconductivity []
# Practical - Brisken Lab []
# Hydrogeophysics []
# Sensorimotor neuroprosthetics []
# Advanced analysis I []
# Nanofabrication with focused electron and ion beams []
# Computer simulation of physical systems II [8]
# Fundamentals in Systems Engineering [2, 3, 5, 7, 10, 13, 15, 16, 19]
# Programming concepts in scientific computing [5, 10]
# Intelligent agents []
# Lifecycle performance of product systems [5, 7, 19]
# Fluid mechanics for SV []
# Engineering internship credited with master project (master in Management of Technology and Entrepreneurship) []
# Active noise control []
# Reactive programming []
# Principles of intellectual property management [19]
# Optics laboratories II [5, 8]
# UE L : Art and architecture: constructing the view I []
# Computer language processing [10]
# Photomedicine [8, 16]
# Modelling and optimization of energy systems [5, 7, 8, 14, 15]
# 1st Workshop on Advances in CFD and MD modelling of Interface Dynamics in Capillary Two-Phase Flows [18]
# Early detection of innovation potential [2, 3, 5, 7, 19]
# Sanitary engineering in developing countries [19]
# Experimental biochemistry and biophysics [5, 11, 16]
# Virtual reality [11]
# Recent Events in Energy-1 [16]
# History of globalization II []
# Biomechanics of the cardiovascular system []
# Project in Electrical Energy Systems []
# Turbulence [3]
# Chemical thermodynamics [14]
# Topics in geometric analysis II []
# Methods of Modelling and Simulation of Materials Science []
# Nanobiotechnology and biophysics [16, 17]
# Thermal power cycles and heat pump systems [14]
# Advanced information, computation, communication II []
# Methods for rapid production and development []
# Software engineering [5, 9, 15, 19]
# How people learn I [5, 9, 19]
# Thermodynamics for materials science []
# Thermodynamics and energetics I [14]
# Applied corporate & industry analysis (MTE master only) [5]
# Nanoscale MOSFETs and beyond CMOS devices [12]
# Electrochemical Thermodynamics and Kinetics of Metals and Semiconductors for Energy Conversion []
# Fundamentals of superresolution optical microscopy and Scanning Probe Microscopy [17]
# Understanding Statistics and Experimental Design []
# Scientific project design in translational neurosciences [5, 7, 10, 19]
# Seminar series on advances in materials (spring) []
# Audio signal processing and virtual acoustics [6]
# Slope stability [1]
# Economics of Innovation and Technological Change []
# Elliptic PDE's []
# Computer-aided engineering []
# Nuclear fusion and plasma physics []
# Project in micro and nanoelectronics []
# Environmental chemistry [3]
# Power systems dynamics [18]
# Tribology [0, 11]
# Gödel and recursivity [10]
# Technology policy and the energy transition [7, 11, 19]
# X-Ray Analysis for thin films []
# Fourier analysis and boundary value problems []
# Organic chemistry [3]
# Density functional theory for chemistry students []
# Advanced microwaves for wireless communications []
# Optimal decision making [4, 5, 10]
# Hardware systems modeling II []
# Introduction to Frustrated Magnetism []
# Quantum Information Theory and Computation []
# Investing: a Guide to Doing the Right Thing [2, 7, 14]
# Biological chemistry II (for SV) []
# Théorie et critique du projet MA2 (Geers) [5]
# Renewable energy and solar architecture in Davos []
# Lab immersion in industry B [5, 9, 10, 11, 16, 19]
# Seminars in Physical Chemistry (2) []
# Multivariate statistics []
# Financial econometrics [4, 7, 10, 14, 19]
# Equilibrium-stage separation processes []
# Electron Microscopy for Life Science [0, 17]
# Water resources engineering []
# IC design II []
# Space mission design and operations []
# Model predictive control [5]
# Computer vision []
# Photochemistry II [8, 12, 17]
# Instability []
# Transmission electron microscopy and diffraction (a) [17]
# Modern photovoltaic technologies []
# Sparse stochastic processes [3, 6]
# Cristallography and diffraction methods []
# Econometrics [4]
# Lab methods : histology []
# Studio MA1 (Escher et GuneWardena) []
# Introduction to chemical engineering []
# Information technology and digital strategy [7]
# Practical - Bucher Lab []
# Advanced quantum field theory []
# Working group in Topology I []
# Functional programming []
# Neurotechnologies to treat neurodisorders: neuroprosthetics (EDNE) []
# Lab methods : bioactive compounds screening [3, 5, 16, 19]
# Advanced MEMS [12]
# Théorie et critique du projet MA1 (Geers) [5]
# PLLs and clock & data recovery []
# Active Remote Sensing of the Atmosphere []
# Practical - Lemaitre Lab []
# Integrated circuits technology []
# Applied probability & stochastic processes [5, 10]
# Negotiation techniques [5, 7, 11, 19]
# Satellite communications  systems and networks []
# Parallel and high-performance computing []
# Plasma physics III []
# Energy conversion and renewable energy [14]
# Image optics [8, 17]
# Financial Econometrics (EDFI) []
# Interdisciplinary / disciplinary project for chemical master []
# Social media [9]
# Fixed income analysis []
# Parallelism and concurrency []
# Optical fibers and fiber devices []
# Surface and thin films processes []
# Optimization and simulation []
# Financial & managerial accounting []
# Innovation management [2, 5, 7, 11, 19]
# Image analysis and pattern recognition []
# Stochastic calculus I [3]
# Piezoelectric materials, properties and devices []
# Limnology [13]
# Fundamentals of biosensors and electronic biochips []
# Signal processing for communications [6]
# Soft Microsystems Processing and Devices [0, 12, 17]
# A Network Tour of Data Science [4, 9, 11]
# Mass spectrometry, principles and applications []
# Development engineering [7, 9, 19]
# Assembly techniques [0, 2]
# Nonlinear Optics []
# Nonlinear Spectroscopy []
# Advanced analog and RF integrated circuits design II []
# RF MEMS for communications applications [12]
# Fundamentals of traffic operations and control [5, 7, 10, 11, 15]
# Biophysics II []
# Quantum Field Theory Methods in Gravity and Cosmology []
# Lasers: theory and modern applications [8]
# Machine Learning for Engineers []
# Energy storage in power systems: technologies, applications and future needs []
# Properties of semiconductors and related nanostructures []
# Seismic engineering []
# Théorie et critique du projet MA2 (Gugger) []
# Advanced lab in electrical engineering []
# Concurrent algorithms []
# Water quality modeling [3, 7, 11]
# Scientific literature analysis in Neuroscience [7, 11, 16, 19]
# Information security and privacy [4]
# Chemical engineering of heterogenous reactions [3, 5, 7]
# Flexible bioelectronics [12]
# Eco-friendly production and process intensification [3, 8, 13, 16]
# Dynamical system theory for engineers []
# Introduction to magnetic materials in modern technologies [0, 11, 12]
# Empirical Methods in Corporate Finance []
# Cosmology: Dark and Luminous Matters  []
# Pharmacology and pharmacokinetics []
# Algorithms [10]
# Probability theory []
# Theoretical Microfluidics []
# Economics of innovation [2, 7, 19]
# Pharmacological chemistry [16]
# High energy and space astrophysics (UNIGe) []
# Fundamentals in statistical pattern recognition [4, 6]
# Advanced Topics in Cryptology [19]
# Advanced cryptography [4, 5, 7]
# Biostatistics [6]
# Digital 3D Geometry Processing []
# Introduction to digital signal processing using Matlab, applied to environmental sciences and civil engineering []
# Advanced diffusional separation processes []
# Lab immersion academic (outside EPFL) B [5, 9, 10, 11, 19]
# Inorganic reactivity [3]
# Advanced satellite positioning [6]
# Lab in electrical energy systems [18]
# Optical waves propagation []
# Energy Autonomous Wireless Smart Systems [17, 18]
# Numerical methods for visual computing [2, 5, 6, 8, 10, 13, 15, 18, 19]
# Power management []
# Environmental policy [7, 11]
# Fate and behaviour of organic pollutants [3]
# Landmark Papers in Cancer and Infection []
# Advanced analog and RF integrated circuits design I [12]
# Advanced control systems [5]
# 2D Layered Materials: Synthesis, Properties and Applications [0, 1, 2, 9, 12, 17]
# Game Theory []
# Linear system theory []
# Discrete mathematics []
# Emerging Nanopatterning Methods []
# Project in information technologies []
# Graph theory []
# Ceramics, structures and properties   TP [0]
# Strategic marketing & technology commercialization [2, 5, 7, 9, 11, 19]
# Lab immersion in industry A [5, 9, 10, 11, 16, 19]
# Topics in theoretical computer science []
# Advanced Earthquake Engineering []
# Scaling laws in micro- and nanosystems [12]
# Materials and technology of microfabrication []
# Business information systems []
# History of globalization I [2, 5, 7, 13, 19]
# Operating systems implementation []
# Entrepreneurship [7, 11, 19]
# Computational methods in molecular quantum mechanics [0, 10, 12, 19]
# High pressure in chemical kinetics and equilibria []
# Materials Science [0, 13]
# CCMX Winter School - Additive Manufacturing of Metals and the Material Science Behind It' [13]
# Introduction to crystal growth by epitaxy []
# Microstructuring of glass []
# Advanced composites in engineering structures [5]
# Ecotoxicology []
# New tools and research strategies in personalized medicine [5, 11]
# Numerical methods for electromagnetics [8]
# Photomechanics for Engineers []
# Introduction to scanning electron microscopy microanalysis techniques [17]
# Fundamentals of VLSI design []
# Electric filters [5]
# Introduction to multiprocessor architecture []
# Wireless Transceivers: Radio Architectures, System and Circuit Design []
# Information theory and coding [6]
# Cellular Signalling [16]
# Fracture of materials [2]
# Advances in Additive Manufacturing for Polymers in Bioengineering, Electronics and Material Science []
# Chemistry of small biological molecules []
# Théorie et critique du projet MA2 (Huang) [5, 11, 15, 19]
# Human computer interaction []
# Scientific project design in integrative neurosciences []
# Organic electronic materials - synthesis, applications, properties [0, 3]
# Sensor orientation [5, 6]
# Imagery of territory []
# Scientific project design in drug discovery [5, 7, 11, 19]
# Brain Bioenergetics: from behavior to pathology []
# Advanced information, computation, communication I [4, 6, 7, 10, 15]
# Wireless receivers: algorithms and architectures []
# Biomimetic membrane systems and their applications [16]
# Data Analysis for Science and Engineering [4, 5, 19]
# Infection biology []
# Advanced digital communications [4, 6, 7, 11]
# Difficult Double Double Histories []
# Lab immersion III [5, 11, 19]
# Practical - Lingner Lab []
# Reactor Technology []
# Advanced derivatives []
# Geocomputation [5, 9, 10, 11, 19]
# Summer School on Neurophysiology for Neural and Biomedical Engineering (2016) []
# Multivariate Extreme Value and Max-Stable Processes []
# Monthly IBI-EDBB Mini-symposia []
# Numerical Methods for Physical Properties Evaluation []
# High Dimensional Approximation for PDEs with random parameters []
# Energy geostructures []
# Data analysis and model classification []
# Mechanical product design and development [12, 19]
# Energy planning: modeling and decision support systems [2, 7]
# Waterborne Pathogens []
# Mathematics for Financial Economics []
# Cellular biology and biochemistry for engineers [0, 3, 10, 11, 13, 15, 16, 19]
# Smart grids technologies [5, 18, 19]
# Transportation systems engineering [10]
# Working group in Topology II []
# Networks out of control [4]
# Surface analysis [17]
# Multi-body simulation [0]
# Accounting for finance []
# Computer architecture []
# Laser Processing of Materials: From Optical Properties of Materials and Light-Matter Interaction to Applications [8]
# Real-time embedded systems [4, 5, 14, 19]
# Robotics practicals [5]
# Practical - Naef Lab []
# Optional project in computer science []
# UE W: Reading construction []
# Advanced lab in electrical energy systems [5, 10, 11, 19]
# HF and VHF circuits and techniques II []
# Interfaces in biology and nanoscience []
# Practical - Constam Lab []
# Dynamic Asset Pricing []
# Microelectronics [12]
# Hydrodynamics []
# Readings in Organization Economics [19]
# Optics III []
# Gene transfer and recombinant protein expression in animal cells []
# CCMX Advanced Course - Atomic Force Microscopy (AFM): Theory and Practice [17]
# Wave propagation along transmission lines []
# CCMX Advanced Course - Combining Structural & Analytical Investigations of Matter at the Micro-, Nano and Atomic Scale- (2016) [17]
# Propagation of acoustic waves [5, 8, 11, 19]
# Food biotechnology []
# Derivatives [3, 4, 7, 14]
# Leading and managing in a global context [2, 5, 11, 19]
# Technology ventures in IC []
# Advanced NMR and imaging []
# Seminars in Physical Chemistry (1) []
# Optional project in communication systems []
# Effects of radiation on materials []
# Advanced compiler construction [10]
# Circuits and systems II [0, 6, 7]
# Cancer Biology I []
# Magnetic confinement []
# Cancer Biology II [11]
# Creative Problem Solving in Science and Engineering []
# Design of Ultra-low Power Wearable Wireless Systems [1, 3, 5, 6, 9, 10, 11, 12, 14, 18, 19]
# Metrology II []
# Summer school on healthcare diagnostics [11]
# Introduction to practical aspects of animal experimentation and animal facilities (Winter) (EDNE) []
# Quantitative methods in finance [4, 6, 7, 10, 13, 14]
# Numerical methods in chemistry [3, 8]
# General physics II []
# Enterprise and service-oriented architecture []
# Magnetic materials in modern technologies - from concepts to real devices [0, 10, 12]
# Electromagnetic compatibility []
# Scaling in MEMS []
# Part 4 : Research project in Area and Cultural Studies []
# Biomass conversion []
# Solid waste engineering [2, 3, 5, 7, 8, 9, 10, 11, 19]
# Haptic human robot interfaces []
# Statistical neurosciences []
# Student seminar: security protocols and applications [4]
# Fundamentals of biomedical imaging []
# Information : strategy & economics [7]
# Personal interaction studio [7, 15]
# Total synthesis of natural products []
# Incompressible fluid mechanics []
# Solid state physics II [0, 12]
# Fracture Mechanics and Fatigue of Structures []
# HydroPower and Dams: Benefits and Concerns []
# Cryptography and security [4, 6, 7]
# Neurosciences I : molecular neuroscience and neurodegeneration []
# Microbial diversity []
# Neurosciences III : behavioral and cognitive neuroscience []
# Seminar series on advances in materials (autumn) []
# Characterization Methods in Materials Science [17]
# Biomicroscopy I [8, 17]
# Computational physics III [8]
# Lab in microwaves []
# Engineering geology for geo-energy []
# Process development I []
# New Concretes for Structures []
# Signals, instruments, and systems [6, 18]
# Introduction to computer graphics [8]
# Probabilistic Coupling [6]
# Statistical theory []
# Time series [4, 6]
# Photonic systems and technology [8]
# Advanced analysis II []
# Plasma instabilities []
# Audio engineering []
# Studio BA5 (Fröhlich M. & A.) [15]
# Environmental transport phenomena []
# Advanced machine learning [6]
# Ultrafast phenomena [8]
# Transmission electron microscopy and diffraction (b) [17]
# Water and wastewater treatment [1, 3]
# Bioreactor modeling and simulation [8]
# Physical models for micro and nanosystems []
# Reliability of MEMS (EDOC) []
# Grid and Converter Controls [18]
# Light sources: optical fiber and waveguide lasers []
# Integrated optics [8]
# Snow Science Winter School [1]
# Micro and nanostructuration of materials []
# Heat and mass transfer [8]
# Theory of computation []
# General physics III []
# Methods of asymptotic analysis in mechanics []
# Environment chemical and biological technology [16]
# Evolutionary robotics []
# Analysis and modelling of locomotion [1]
# Advanced topics in electromagnetic compatibility []
# Fundamentals of Biometrics []
# Advanced computer architecture []
# Laboratory information management systems (LIMS) []
# Advanced topics in financial econometrics [7, 14]
# Harmonic analysis []
# Fundamentals of biophotonics [0, 8, 11]
# Engineering of musculoskeletal system and rehabilitation []
# Corporate strategy [2, 7, 11, 19]
# Introduction to the finite elements method [8]
# Transient and dynamic analysis of electric power systems []
# Information and Asset Pricing []
# Embedded systems []
# Organic semiconductors [0]
# Combinatorial optimization []
# Genomics and bioinformatics []
# Advances in Contact Mechanics []
# Crystallography of structural phase transformations [0, 13]
# Advanced analog IC design []
# Computer networks [4]
# Statistical mechanics [4]
# Principles of finance [2]
# Understanding modern Switzerland II []
# Introduction to nuclear engineering []
# Information Science in Engineering []
# Applied molecular quantum chemistry []
# Symmetry and Conservation in the Cell [0]
# Advanced metallurgy [13]
# Environmental Economics for Engineers []
# Economics of innovation & management in energy [19]
# Understanding modern Switzerland I [5]
# Communication for Research Engineers [10]
# Power electronics []
# Current Topics in Chemical Biology 1 [16]
# Applied mechanical design [19]
# Optical Materials: Fundamental concepts and recent developments []
# Presentation skills [11]
# 3D Electron Microscopy and FIB-Nanotomography [17]
# Scanning electron microscopy techniques (a) [17]
# BioMEMS []
# Plasma physics II []
# Lab methods : biosafety []
# Advanced probability and applications []
# Sensors in medical instrumentation [8, 12, 18]
# Thermodynamics of energy conversion and storage []
# Spacecraft avionics systems, architectures and processors [9]
# General chemistry (English) [0, 3, 8, 16]
# Games for Crowds and Networks []
# Numerical Analysis and Computational Mathematics [5, 6, 8]
# Advanced Microscopy for Life Science []
# Théorie et critique du projet BA3 (De Vylder & Taillieu) []
# Quantum chemistry []
# Machine learning programming [5, 15]
# Practical - Meylan Lab [11, 16]
# Brain-computer interaction []
# Academic Writing for Doctoral Students []
# Studio MA2 (Lütjens et Padmanabhan) []
# Measuring systems laboratory work []
# Industrial electronics II []
# Efficient Synthetic Routes Towards Bioactive Molecules []
# Atomistic and quantum simulations of materials [0]
# Electronic spectroscopy []
# Analysis III []
# Practical - Radtke Lab []
# Neuroscience for engineers []
# Mathematics of data: from theory to computation [4, 6, 10, 15]
# Inorganic chemistry "Techniques and methods" [3]
# Fluid mechanics (for SIE) []
# Bioinorganic chemistry []
# Bioanalytics and analytical sensors []
# Physics of photonic semiconductor devices [8]
# Project in Biotechnology []
# Digital Speech and Audio Coding [6]
# Foundations of software []
# Current Topics in Distributed Systems []
# Industrial automation []
# Lab immersion II [5, 11]
# Project in molecular sciences [5]
# Stellar evolution and nucleosynthesis (UNIGe) []
# Data science for business [2, 4, 5, 7, 10, 11, 15, 19]
# Asset Pricing []
# Quantum optics and quantum information []
# Analysis of ancient materials and their degradation []
# Advanced steel design [2]
# Recent Events in Energy-2 [10]
# Spatial statistics and analysis []
# Process development project []
# Semester project in Bioengineering [5, 11]
# Applied wastewater engineering [1, 13]
# Life cycle engineering of polymers [2, 7, 19]
# Introduction to electronic structure methods [0, 12]
# CCMX Summer School - Multiscale Modelling of Materials (2016) [0]
# Introduction to nanomaterials []
# CCMX Winter School Surface Science and Coatings []
# Advanced electroanalytical chemistry I []
# Basic principles of drug action at the nervous system []
# Quantitative risk management []
# Statistics for genomic data analysis [5]
# Advanced bioengineering methods laboratory [5]
# Scientific project design in translational oncology []
# Optics I []
# Analysis I (English) []
# Convex optimization and applications []
# Venture capital [4, 7]
# Advanced energetics [2, 7, 14]
# General physics I (English) []
# Scientific literature analysis in Bioengineering [3, 5, 9, 10, 11, 16, 19]
# Biological chemistry III [16]
# Tissue engineering [0]
# Localization and Navigation Methods [8]
# Advanced biomedical imaging methods and instrumentation []
# Scientific project design in synthetic biology (iGEM) []
# Modelling, optimisation, design and analysis of integrated energy systems [14]
# Discrete optimization [10]
# HF and VHF circuits and techniques I []
# Scientific project design in regenerative medicine and diagnostics []
# Neutronics []
# Qualitative Research Methods []
# Numerical flow simulation [0, 5, 8, 18]
# Reactor Experiments []
# Practical - Van der Goot Lab []
# Biomaterials [0, 7, 9, 16, 19]
# Optical detectors [8, 12]
# Introduction to cellular and molecular biotechnology []
# Optimal control []
# Project in computer science II []
# Image processing I [6, 17]
# Biomineralization: from nature to application [5, 16]
# Philosophy of life sciences II [5, 9, 11, 19]
# Spacecraft design and system engineering []
# CCMX Advanced Course - Inorganic Particle Synthesis by Precipitation: From Nanoparticles to Self-organised  Mesocrystals and from Theory to Practice []
# Lectures in Life Sciences []
# Introductory course about Spatial Statistics []
# Mathematical methods for physicists []
# Selected topics in mechanics of solids and structures [2]
# Martingales in financial mathematics [14]
# Computational Social Media [9, 11]
# Analog circuits design I []
# Advanced numerical analysis [8, 15]
# Aerodynamics []
# Catalyst design for synthesis [3]
# General physics (English) II []
# Frontiers in Chemical Synthesis. Towards Sustainable Chemistry [3]
# Science and Engineering Teaching and Learning [4, 5, 7, 9, 10, 11, 19]
# B2B - high-tech marketing [2, 7, 19]
# Measuring systems []
# Working Group in Algebraic Groups, I []
# Principles of microeconomics [3, 5, 7, 10, 19]
# Software-defined radio: A hands-on course []
# Cognitive psychology B [5, 10, 11, 16, 19]
# Modelling problem solving, computing and visualisation I []
# Optimization Methods and Models [10, 15]
# Nanocomputing: Devices, Circuits and Architectures [12]
# Two-phase flows and heat transfer [8, 18]
# Theory of materials : from structures to properties []
# Technology and Public Policy - (a) Science, technology and society [19]
# Computation of molecular properties []
# Microbiology [0]
# Analog circuits design II []
# MINTT: Management of Innovation and technology transfer (EDOC) [2, 5, 7, 10, 11, 19]
# Advanced multiprocessor architecture []
# Single cell genomics []
# Advanced electroanalytical chemistry (II session) []
# Computational linear algebra [8]
# Additive Combinatorics []
# Production management [5, 19]
# Packing and covering []
# Research project in materials II [5]
# Molecular quantum dynamics [12]
# System Identification [5]
# Stochastic calculus II [3, 4]
# Biophysics I []
# CCMX Winter School - Nanoparticles: From Fundamentals to Applications in Life Sciences []
# Basic principles of drug action at the cardiovascular system []
# Commutative algebra []
# Sustainability assessment [2, 5, 7, 10, 11, 19]
# Chemical kinetics [3]
# Decision-aid methodologies in transportation [5, 10]
# Introduction to environmental engineering [1]
# Entrepreneurship & new venture strategy (a) [2, 7]
# Renewable energy (for ME) [14]
# Physical and computational organic chemistry [3]
# Signal processing for functional brain imaging [6]
# Design technologies for integrated systems [10, 15]
# Structural stability [2]
# Translational Robotics for Clinical Rehabilitation [11]
# Microwaves []
# Convexity []
# Introduction to finance (IF master and minor only) [2, 7]
# Practical - Blokesch Lab []
# Scientific programming for Engineers []

# %%
tm = ldaModel.topicsMatrix()

# %%
# Compute a score for each topic/course pair
# The score is the sum of the bag of words' terms multiplied by their weight in the model's topic matrix
# normalized by the number of words
def computeTopicScores(topicsMatrix, bagOfWords):
    topicScores = np.zeros(topicsMatrix.shape[1])
    wordCount = 0
    for i in range(topicsMatrix.shape[0]):
        occ = bagOfWords.get(terms[i], 0)
        wordCount += occ
        for j in range(topicsMatrix.shape[1]):
            topicScores[j] += occ * topicsMatrix[i][j]
    
    return topicScores / wordCount

def associateTopicScores(topicsMatrix):
    res = list()
    for k,v in preprocessed.items():
        scores = computeTopicScores(topicsMatrix, v['description'])
        res.append((v['name'], sorted(list(zip(list(range(topicsMatrix.shape[1])), scores)), key=lambda x:x[1])))
        
    return res

def printCourse(course, thresh = 10):
    tList = []
    for tup in course[1]:
        if tup[1] > thresh:
            tList.append(tup)
    if len(tList) > 0:
        print(course[0], "->", list(map(lambda x: topicLabels[x[0]], sorted(tList, key=lambda x:x[1], reverse=True))))
    else:
        print(course[0], "->", topicLabels[course[1][-1][0]])

# %%
courseToScores = associateTopicScores(tm)

# %%
for c in courseToScores:
    printCourse(c)
# Out:
# Composites technology -> ['Cellular biology', 'Applied science']
# Image Processing for Life Science -> ['Imagery', 'Lab environment']
# Global business environment -> ['Business', 'Risk management']
# Electrochemical nano-bio-sensing and bio/CMOS interfaces -> Imagery
# Structural mechanics (for MT) -> ['Risk management']
# Théorie et critique du projet MA2 (Boltshauser) -> ['Lab environment', 'Applied science']
# Advanced principles and applications of systems biology -> ['Biology', 'Physics', 'Machine learning', 'Lab environment', 'Cellular biology']
# Mass spectrometry -> ['Biology', 'Risk management']
# Principles of digital communications -> ['Signal processing']
# Hardware systems modeling I -> Thermodynamics
# Quantitative systems modeling techniques -> ['Lab environment', 'Business', 'Architecture/Design', 'Physics', 'Applied science']
# Medical radiation physics -> ['Imagery', 'Physics']
# Bio-nano-chip design -> ['Imagery']
# Principles of powder and densification processing -> Applied science
# Fundamentals of solid-state materials -> ['Imagery', 'Cellular biology', 'Physics', 'Micro/Nano-electronics', 'Risk management']
# Microeconomics -> ['Business', 'Lab environment', 'Physics', 'Signal processing', 'Micro/Nano-electronics', 'Applied science']
# Polymer chemistry and macromolecular engineering -> ['Chemistry', 'Lab environment', 'Risk management', 'Cellular biology']
# Physical chemistry of polymeric materials -> ['Chemistry', 'Risk management']
# Fundamentals of neuroengineering -> ['Lab environment', 'Machine learning', 'Chemistry', 'Biology', 'Applied science']
# In Silico neuroscience -> ['Lab environment']
# Materials selection -> ['Risk management', 'Applied science', 'Business', 'Lab environment', 'Cellular biology']
# Optics laboratories I -> ['Physics', 'Lab environment']
# Fracture mechanics -> ['Risk management', 'Cellular biology', 'Lab environment']
# Air pollution and climate change
#  -> ['Lab environment']
# Philosophy of life sciences I -> ['Lab environment']
# Lab methods : proteomics -> Biology
# Cementitious materials (advanced) -> ['Biology', 'Risk management', 'Lab environment', 'Applied science']
# Material and energy flow analysis -> ['Lab environment', 'Applied science']
# Linear algebra (english) -> ['Signal processing']
# Transport phenomena II -> ['Physics', 'Chemistry', 'Electricity/Power', 'Applied science', 'Thermodynamics', 'Architecture/Design']
# Printed systems and large area manufacturing -> ['Micro/Nano-electronics', 'Imagery']
# Theoretical computer science -> ['Signal processing', 'Micro/Nano-electronics', 'Physics', 'Architecture/Design', 'Electricity/Power']
# Philosophy, epistemology and history of science I -> ['Lab environment']
# Reservoir mechanics for geo-energy and the environment -> ['Physics', 'Risk management']
# Non linear analysis of structures -> ['Risk management', 'Physics', 'Cellular biology']
# Investments -> ['Thermodynamics', 'Risk management']
# Engines and fuel cells -> ['Thermodynamics', 'Physics', 'Cellular biology']
# Recycling of materials -> ['Applied science', 'Lab environment']
# Statistical signal and data processing through applications -> ['Signal processing']
# Analysis II (English) -> ['Chemistry']
# Technology & innovation strategy -> ['Lab environment', 'Risk management', 'Applied science', 'Business']
# Lab immersion I -> ['Lab environment']
# Internet analytics -> ['Lab environment']
# Supply chain management -> ['Risk management', 'Applied science', 'Lab environment', 'Business']
# Particle-based methods -> ['Physics']
# Statistical Sequence Processing -> ['Signal processing']
# Solid state image sensing -> ['Physics', 'Imagery', 'Lab environment']
# Soft matter -> ['Cellular biology', 'Risk management']
# Advanced regression -> ['Signal processing', 'Lab environment', 'Data applications']
# Introduction to database systems -> ['Lab environment', 'Risk management', 'Data applications']
# Hydraulic turbomachines -> ['Risk management']
# Design and analysis of experiments in materials science and engineering -> ['Signal processing']
# Business design for IT services -> ['Business', 'Applied science']
# Some problems in the theory of simple groups -> ['Lab environment', 'Applied science', 'Business', 'Physics', 'Risk management', 'Architecture/Design']
# Simulation and optimisation of industrial applications -> ['Risk management', 'Lab environment', 'Electricity/Power']
# Biomicroscopy II -> ['Physics', 'Imagery']
# Modelling problem solving, computing and visualisation II -> ['Lab environment', 'Risk management', 'Applied science', 'Cellular biology']
# Frontiers in Organic Synthesis. Part III Stereochemistry -> ['Chemistry']
# Photonic micro- and nanosystems -> ['Physics']
# Safety of chemical processes -> ['Risk management']
# Probabilities and statistics -> ['Signal processing']
# Practical - Fellay Lab -> ['Lab environment', 'Data applications']
# CCMX Winter School - Metal Science -> ['Cellular biology']
# Mobile robots -> ['Lab environment']
# Leading research in Chemical Engineering (a) -> ['Biology', 'Chemistry']
# Fluvial biogeosciences -> ['Lab environment']
# Biochemistry II -> ['Biology', 'Chemistry']
# Micro-magnetic field sensors and actuators -> ['Cellular biology', 'Physics', 'Micro/Nano-electronics']
# Diffraction methods in structural biology -> ['Imagery']
# Practical - Gönczy Lab -> ['Cellular biology']
# Principles and Practicals in X-Ray Scattering -> Imagery
# Frederic Joliot/Otto Hahn Summer School on nuclear reactors Physics, fuels and systems -> ['Thermodynamics', 'Lab environment']
# Computational finance -> ['Physics', 'Lab environment', 'Signal processing', 'Thermodynamics']
# Applied stochastic processes -> Signal processing
# Structure and evolution of galaxies (UNIGe) -> ['Risk management', 'Cellular biology']
# Numerical integration  of stochastic differential equations -> ['Chemistry', 'Physics']
# Immunology -> ['Lab environment', 'Applied science', 'Cellular biology']
# Thin film fabrication processes -> ['Lab environment', 'Biology']
# Studio MA1 (Lütjens et Padmanabhan) -> ['Lab environment', 'Architecture/Design', 'Risk management']
# Théorie et critique du projet MA1 (Huang) -> ['Architecture/Design', 'Lab environment']
# Biomedical signal processing -> ['Signal processing']
# Current Topics in Chemical Biology 2 -> ['Biology', 'Chemistry', 'Lab environment']
# Physics and hydrology of snow -> ['Environment', 'Physics']
# Nuclear magnetic resonance -> ['Cellular biology', 'Chemistry']
# Limestone-Calcined Clay - Cement : Characterisation methods -> Materials
# Advanced materials for photovoltaics and lighting -> ['Cellular biology']
# Nanoelectronics -> ['Micro/Nano-electronics', 'Imagery']
# PhD Masterclass - The horizontal metropolis and other research questions -> ['Lab environment']
# Mapping urban history -> ['Risk management', 'Lab environment', 'Applied science', 'Business']
# Topics in Autonomous Robotics -> ['Lab environment']
# Speech processing -> ['Signal processing']
# Mathematical models in supply chain management -> ['Risk management', 'Biology', 'Lab environment']
# Practical - Simanis Lab -> ['Biology', 'Cellular biology']
# Image communication -> ['Imagery', 'Signal processing', 'Lab environment']
# Plasma Diagnostics in Basic Plasma Physics Devices and Tokamaks: from Principles to Practice -> Cancer
# Nanophotonics and plasmonics -> ['Physics']
# Computational photography -> ['Physics', 'Imagery', 'Lab environment', 'Signal processing']
# Information literacy for chemists -> ['Lab environment', 'Biology', 'Chemistry', 'Risk management']
# Distributed algorithms -> ['Architecture/Design', 'Physics', 'Signal processing']
# Entrepreneurship laboratory (e-lab) -> ['Risk management', 'Lab environment']
# Introduction to planetary sciences -> ['Lab environment']
# Biomedical optics -> ['Physics', 'Biology']
# Quality assurance and quality management systems -> ['Lab environment']
# Non-destructive evaluation methods -> ['Physics', 'Imagery', 'Cellular biology']
# Concepts in ecological engineering -> ['Lab environment']
# Molecular endocrinology -> ['Lab environment', 'Applied science', 'Risk management', 'Cellular biology', 'Biology', 'Machine learning', 'Physics']
# Privacy Protection -> ['Lab environment', 'Data applications']
# Synthesis, analysis and verification -> ['Lab environment', 'Architecture/Design']
# Chemical engineering lab & project -> ['Lab environment', 'Chemistry', 'Risk management']
# Mathematical modelling of DNA -> ['Physics', 'Signal processing', 'Electricity/Power']
# Industry dynamics, models & trends -> ['Lab environment', 'Applied science', 'Architecture/Design']
# Optics II -> ['Physics']
# Multivariable control and coordination systems -> ['Lab environment', 'Risk management']
# Science and technology of UV-induced polymerization -> ['Biology', 'Chemistry', 'Lab environment', 'Cellular biology']
# Lab methods : animal experimentation -> ['Lab environment', 'Biology']
# Structure and reactivity -> ['Chemistry', 'Lab environment']
# Macrofinance -> ['Lab environment', 'Business']
# Operations: economics & strategy -> ['Risk management', 'Lab environment', 'Applied science']
# Inorganic chemistry "Applications and spin-offs" -> ['Chemistry', 'Biology']
# Analytic algorithms -> ['Signal processing', 'Lab environment', 'Architecture/Design', 'Cellular biology', 'Physics']
# Geomechanics -> Cellular biology
# Database systems -> ['Lab environment', 'Data applications', 'Machine learning', 'Architecture/Design']
# How people learn II -> ['Lab environment', 'Machine learning']
# Biomolecular structure and mechanics -> ['Risk management', 'Biology', 'Lab environment', 'Cellular biology']
# Practical - De Palma Lab -> ['Cellular biology']
# Distributed intelligent systems -> ['Lab environment']
# Research project in materials I -> ['Lab environment', 'Risk management']
# Nutrition: from molecules to health -> Lab environment
# Wood structures, properties and uses -> ['Cellular biology', 'Risk management', 'Applied science']
# Corporate governance -> ['Risk management', 'Lab environment']
# Scientific literature analysis in Computational molecular biology -> ['Biology', 'Lab environment', 'Applied science']
# Mechanisms of cell motility -> ['Cellular biology']
# Specialisation project in materials -> ['Lab environment', 'Risk management']
# Making structural logic -> ['Risk management', 'Lab environment']
# Biotechnology lab (for CGC) -> ['Lab environment', 'Cellular biology', 'Biology']
# Bioprocesses and downstream processing -> ['Biology']
# Algebraic curves and cryptography -> ['Lab environment', 'Business']
# Image and video processing -> ['Signal processing', 'Imagery', 'Lab environment']
# Biochemical engineering -> ['Cellular biology', 'Biology']
# Analog circuits for biochip -> ['Micro/Nano-electronics', 'Electricity/Power']
# Advanced wireless communications: algorithms and architectures -> ['Signal processing']
# Numerical methods in biomechanics -> ['Physics']
# Practical - Cole Lab -> Cellular biology
# Functional Data Analysis -> ['Signal processing', 'Micro/Nano-electronics', 'Data applications']
# TCP/IP networking -> ['Lab environment']
# Introduction to particle accelerators -> ['Signal processing', 'Cellular biology', 'Physics']
# Technology and Public Policy - (d) Technology policies for grand and global challenges -> ['Applied science']
# Technology and Public Policy - (b) Technology, policy and regulation -> ['Applied science']
# Principles of computer systems -> ['Lab environment', 'Physics']
# Physics and chemistry of the atmosphere -> ['Lab environment', 'Chemistry']
# Biomechanics of the musculoskeletal system -> ['Cellular biology', 'Applied science']
# Studio BA4 (De Vylder & Taillieu) -> ['Architecture/Design']
# Practical - Trono Lab -> Cellular biology
# Highlights in microtechnology -> ['Lab environment']
# Transport phenomena I -> ['Chemistry', 'Physics']
# International Finance -> ['Thermodynamics']
# Chemical biology - tools and methods -> ['Biology', 'Chemistry', 'Lab environment']
# Experimental cognitive psychology I -> ['Lab environment']
# Topics on Datacenter Design -> ['Electricity/Power', 'Physics', 'Lab environment']
# Mechanical design principles -> ['Lab environment', 'Cellular biology', 'Risk management']
# Scanning and Analytical Transmission Electron Microscopy -> ['Imagery']
# Computational perception using multimodal sensors -> ['Signal processing']
# Supramolecular chemistry -> ['Chemistry', 'Biology']
# Biological modeling of neural networks -> ['Signal processing', 'Biology']
# Automatic speech processing -> ['Signal processing']
# Dielectric properties of materials -> ['Cellular biology', 'Risk management', 'Physics', 'Imagery']
# Using Mathematica to analyse and model experimental data -> Electricity/Power
# Process development II -> ['Applied science', 'Lab environment', 'Biology', 'Architecture/Design', 'Business']
# Large-area electronics: devices and materials -> ['Cellular biology', 'Physics', 'Imagery', 'Micro/Nano-electronics']
# Chemosensory receptors: Applications for biosensors and medical therapies -> Biology
# Risk management -> ['Risk management', 'Lab environment']
# Distributed information systems -> ['Lab environment', 'Data applications']
# Mathematical modelling of behavior -> ['Lab environment', 'Applied science', 'Risk management']
# Empirical Asset Pricing -> ['Biology', 'Chemistry']
# Risk and energy -> ['Risk management', 'Thermodynamics']
# Coordination chemistry and reactivity of f elements -> ['Chemistry', 'Cellular biology', 'Physics']
# UE U : Cartography -> ['Lab environment']
# Optional project in Systems engineering -> ['Lab environment', 'Architecture/Design', 'Biology', 'Applied science', 'Thermodynamics']
# Energy Regulation (2016) -> ['Thermodynamics']
# Computational motor control -> ['Lab environment', 'Physics']
# Data converter circuits and systems -> ['Lab environment', 'Micro/Nano-electronics', 'Data applications']
# Molecular and cellular biophysic I -> ['Biology', 'Risk management']
# Systems and architectures for signal processing -> ['Signal processing', 'Lab environment', 'Architecture/Design']
# Tokamak Plasma Control -> ['Lab environment']
# Training Rotation (EDMS) -> ['Lab environment']
# Nanotechnology -> ['Cellular biology', 'Risk management', 'Micro/Nano-electronics', 'Physics']
# Metrology I -> ['Lab environment', 'Signal processing', 'Physics']
# Advanced algorithms -> ['Signal processing', 'Lab environment', 'Architecture/Design', 'Cellular biology']
# Project in neuroprosthetics -> ['Lab environment', 'Risk management', 'Applied science']
# Electrochemistry for materials technology -> ['Thermodynamics', 'Risk management', 'Applied science', 'Lab environment']
# Quantum electrodynamics and quantum optics -> ['Micro/Nano-electronics', 'Physics']
# Scientific literature analysis in molecular and cancer biology -> ['Biology', 'Lab environment', 'Applied science']
# Rings and modules -> ['Risk management']
# Practical - Suter Lab -> ['Cellular biology']
# Unsupervised and reinforcement learning in neural networks -> ['Signal processing']
# Optics and technology of liquid crystal displays -> ['Physics', 'Lab environment']
# Hot Topics in Cancer Research -> ['Biology', 'Lab environment', 'Cellular biology']
# Lab in microelectronics -> ['Lab environment', 'Micro/Nano-electronics', 'Risk management']
# Linear models -> ['Signal processing']
# Principles and applications of systems biology -> ['Biology', 'Lab environment']
# Statistical Physics for Communication and Computer Science -> ['Signal processing']
# Economics of innovation in the biomedical industry -> ['Business', 'Lab environment', 'Applied science']
# Introduction to transport phenomena -> ['Physics', 'Chemistry']
# Magnetic and semiconducting nanostructures -> ['Imagery', 'Cellular biology', 'Micro/Nano-electronics']
# Experimental Geomechanics -> ['Thermodynamics', 'Imagery', 'Cellular biology', 'Micro/Nano-electronics', 'Signal processing']
# Experimental cognitive psychology II -> ['Lab environment', 'Risk management']
# Photochemistry I -> ['Imagery', 'Micro/Nano-electronics']
# Stem cell biology and technology -> ['Cellular biology', 'Biology']
# Powder technology -> Lab environment
# Credit risk -> ['Risk management']
# Parabolic and hyperbolic PDE's -> Physics
# Powder Characterisation and Dispersion -> Lab environment
# IEEE Sensors Council Summer School on Nano-Bio-Sensing -> ['Imagery', 'Micro/Nano-electronics']
# Leading research in Chemical Engineering (b) -> ['Biology', 'Chemistry']
# Numerical methods in heat transfer -> ['Physics', 'Lab environment']
# Théorie et critique du projet MA1 (Gugger) -> ['Lab environment', 'Architecture/Design']
# Test of VLSI systems -> ['Thermodynamics', 'Lab environment']
# Laser microprocessing -> ['Physics']
# UE N : Art et architecture: constructing the view II -> ['Imagery', 'Lab environment']
# Empirical Corporate Finance -> ['Risk management', 'Lab environment']
# IC design for robustness -> ['Micro/Nano-electronics']
# Introduction to econometrics -> ['Lab environment', 'Data applications', 'Signal processing']
# Radiation protection & radiation applications -> ['Physics', 'Cellular biology', 'Thermodynamics']
# Semiconductor physics and fundamentals of electronic devices -> ['Micro/Nano-electronics', 'Imagery', 'Physics', 'Lab environment', 'Cellular biology']
# Chemical engineering product design -> ['Biology', 'Lab environment', 'Chemistry']
# Computer simulation of physical systems I -> ['Cellular biology', 'Lab environment', 'Signal processing', 'Physics', 'Micro/Nano-electronics', 'Architecture/Design']
# Chemical biology -> ['Biology', 'Chemistry']
# Experimental design and data analysis with R -> ['Signal processing', 'Lab environment']
# Introduction to natural language processing -> ['Lab environment', 'Applied science']
# Mobile networks -> ['Signal processing', 'Physics', 'Machine learning', 'Data applications']
# Philosophy, epistemology and history of science II -> ['Physics', 'Cellular biology', 'Environment']
# Optical communications -> ['Physics']
# Low-voltage analog CMOS IC design -> ['Micro/Nano-electronics']
# Nano CMOS Devices & Technologies for Tera-Bit Circuits and Systems -> ['Micro/Nano-electronics']
# Quantitative methods II -> ['Physics', 'Lab environment', 'Applied science', 'Chemistry']
# Trends in Metabolism & Physiology -> ['Lab environment']
# Media security -> ['Lab environment']
# Markov chains and algorithmic applications -> ['Signal processing']
# Energy systems engineering -> ['Thermodynamics', 'Risk management']
# Surfaces and interfaces -> ['Thermodynamics', 'Cellular biology']
# Lasers and applications in chemistry -> ['Physics', 'Lab environment', 'Cellular biology', 'Micro/Nano-electronics', 'Chemistry']
# Working Group in Algebraic Groups, II -> ['Risk management', 'Business', 'Signal processing']
# Chemistry of food processes -> ['Chemistry']
# Selected topics in advanced optics -> ['Physics', 'Lab environment']
# Product lifecycle management - concepts methods and tools -> ['Risk management', 'Applied science']
# Project in bioengineering and biosciences -> ['Lab environment', 'Applied science', 'Risk management']
# Introduction to Algebraic geometry -> ['Signal processing']
# Lab immersion academic (outside EPFL) A -> ['Lab environment']
# Biomaterials (pour MX) -> ['Biology']
# D. Thinking: real problems, human-focused solutions -> ['Lab environment', 'Risk management']
# Financial big data -> ['Lab environment', 'Data applications', 'Signal processing', 'Risk management']
# Human language technology: applications to information access -> ['Lab environment']
# Modeling and simulation of microsystems -> ['Cellular biology', 'Physics', 'Electricity/Power', 'Lab environment']
# Synergism between Art of Total Synthesis and High Level Strategic Design (MOM) -> Chemistry
# Topics in geometric analysis I -> Chemistry
# Scanning electron microscopy techniques (b) -> ['Imagery', 'Lab environment']
# Lab in acoustics -> ['Lab environment', 'Physics']
# Bioelectronics and implantable biomedical microelectronics -> ['Lab environment', 'Micro/Nano-electronics', 'Imagery']
# Introduction to operating systems -> ['Risk management']
# Solar photovoltaics and energy systems -> ['Thermodynamics', 'Cellular biology', 'Imagery', 'Micro/Nano-electronics']
# Nonlinear signal modeling and prediction -> ['Signal processing', 'Physics']
# Theoretical corporate finance -> ['Biology', 'Risk management']
# Neurosciences II : cellular mechanisms of brain function -> Machine learning
# Digital education & learning analytics -> ['Applied science', 'Lab environment']
# Frontiers in Organic Synthesis. Part II Synthesis of carbo- and hetero-cycles -> ['Chemistry']
# Hardware systems modeling -> Micro/Nano-electronics
# Statistical thermodynamics -> ['Thermodynamics']
# Applied data analysis -> ['Lab environment', 'Data applications']
# Electron microscopy: advanced methods -> ['Imagery', 'Lab environment']
# Modeling of emerging electron devices -> ['Micro/Nano-electronics']
# Scientific literature analysis in cell and developmental biology -> ['Lab environment', 'Cellular biology', 'Biology', 'Applied science']
# Numerical approximation of PDE's II -> ['Physics']
# Control systems   TP -> ['Lab environment']
# Project in biomedical technologies -> ['Lab environment']
# Practical - Hantschel Lab -> ['Biology']
# Classical electrodynamics -> ['Physics', 'Chemistry']
# Pattern classification and machine learning -> ['Signal processing', 'Lab environment']
# Industrial electronics I -> ['Electricity/Power', 'Imagery', 'Lab environment']
# CCMX Advanced Course 'Advanced X-ray Diffraction Methods for Coatings: strain, defects and deformation analysis of thin films -> ['Biology']
# Molecular and cellular biophysic II -> ['Biology']
# CCMX Advanced Course - Instrumented Nanoindentation -> ['Lab environment', 'Cellular biology']
# Electronic properties of solids and superconductivity -> ['Environment', 'Physics', 'Imagery', 'Thermodynamics']
# Practical - Brisken Lab -> ['Applied science']
# Hydrogeophysics -> ['Lab environment', 'Risk management', 'Signal processing']
# Sensorimotor neuroprosthetics -> ['Lab environment']
# Advanced analysis I -> ['Signal processing']
# Nanofabrication with focused electron and ion beams -> ['Imagery']
# Computer simulation of physical systems II -> ['Micro/Nano-electronics', 'Physics', 'Cellular biology', 'Chemistry', 'Lab environment']
# Fundamentals in Systems Engineering -> ['Architecture/Design']
# Programming concepts in scientific computing -> ['Lab environment', 'Architecture/Design', 'Signal processing', 'Physics', 'Risk management']
# Intelligent agents -> Architecture/Design
# Lifecycle performance of product systems -> ['Lab environment', 'Risk management', 'Applied science']
# Fluid mechanics for SV -> ['Electricity/Power', 'Physics']
# Engineering internship credited with master project (master in Management of Technology and Entrepreneurship) -> ['Lab environment', 'Applied science']
# Active noise control -> ['Lab environment']
# Reactive programming -> ['Architecture/Design', 'Lab environment', 'Risk management', 'Cellular biology']
# Principles of intellectual property management -> ['Lab environment', 'Risk management', 'Applied science', 'Business']
# Optics laboratories II -> ['Physics', 'Lab environment']
# UE L : Art and architecture: constructing the view I -> ['Imagery', 'Lab environment']
# Computer language processing -> ['Lab environment']
# Photomedicine -> ['Physics']
# Modelling and optimization of energy systems -> ['Thermodynamics', 'Lab environment', 'Physics', 'Risk management']
# 1st Workshop on Advances in CFD and MD modelling of Interface Dynamics in Capillary Two-Phase Flows -> ['Electricity/Power', 'Physics']
# Early detection of innovation potential -> ['Lab environment', 'Applied science']
# Sanitary engineering in developing countries -> ['Applied science', 'Risk management']
# Experimental biochemistry and biophysics -> ['Lab environment', 'Biology']
# Virtual reality -> ['Lab environment']
# Recent Events in Energy-1 -> ['Thermodynamics']
# History of globalization II -> Applied science
# Biomechanics of the cardiovascular system -> ['Cellular biology']
# Project in Electrical Energy Systems -> ['Lab environment', 'Imagery']
# Turbulence -> ['Chemistry']
# Chemical thermodynamics -> ['Chemistry', 'Thermodynamics']
# Topics in geometric analysis II -> Materials
# Methods of Modelling and Simulation of Materials Science -> ['Cellular biology', 'Risk management', 'Micro/Nano-electronics']
# Nanobiotechnology and biophysics -> ['Cellular biology', 'Imagery']
# Thermal power cycles and heat pump systems -> ['Thermodynamics']
# Advanced information, computation, communication II -> ['Signal processing']
# Methods for rapid production and development -> ['Physics', 'Lab environment']
# Software engineering -> ['Lab environment', 'Applied science']
# How people learn I -> ['Machine learning', 'Lab environment', 'Applied science']
# Thermodynamics for materials science -> ['Chemistry', 'Biology']
# Thermodynamics and energetics I -> ['Thermodynamics']
# Applied corporate & industry analysis (MTE master only) -> ['Lab environment']
# Nanoscale MOSFETs and beyond CMOS devices -> ['Thermodynamics', 'Micro/Nano-electronics']
# Electrochemical Thermodynamics and Kinetics of Metals and Semiconductors for Energy Conversion -> ['Cellular biology']
# Fundamentals of superresolution optical microscopy and Scanning Probe Microscopy -> ['Physics', 'Imagery']
# Understanding Statistics and Experimental Design -> ['Signal processing', 'Data applications', 'Lab environment']
# Scientific project design in translational neurosciences -> ['Lab environment', 'Applied science']
# Seminar series on advances in materials (spring) -> ['Lab environment', 'Machine learning', 'Chemistry']
# Audio signal processing and virtual acoustics -> ['Signal processing']
# Slope stability -> Environment
# Economics of Innovation and Technological Change -> ['Lab environment', 'Applied science']
# Elliptic PDE's -> ['Chemistry', 'Physics']
# Computer-aided engineering -> ['Lab environment']
# Nuclear fusion and plasma physics -> ['Physics', 'Cellular biology']
# Project in micro and nanoelectronics -> ['Lab environment', 'Imagery']
# Environmental chemistry -> ['Chemistry']
# Power systems dynamics -> Electricity/Power
# Tribology -> Risk management
# Gödel and recursivity -> Signal processing
# Technology policy and the energy transition -> ['Applied science', 'Lab environment', 'Thermodynamics']
# X-Ray Analysis for thin films -> ['Cellular biology', 'Risk management', 'Imagery']
# Fourier analysis and boundary value problems -> ['Physics', 'Cellular biology', 'Signal processing', 'Lab environment']
# Organic chemistry -> ['Chemistry', 'Risk management', 'Cellular biology', 'Biology']
# Density functional theory for chemistry students -> ['Micro/Nano-electronics', 'Signal processing', 'Cellular biology']
# Advanced microwaves for wireless communications -> ['Micro/Nano-electronics']
# Optimal decision making -> ['Lab environment', 'Signal processing', 'Risk management', 'Physics', 'Cellular biology']
# Hardware systems modeling II -> Imagery
# Introduction to Frustrated Magnetism -> ['Cellular biology']
# Quantum Information Theory and Computation -> ['Micro/Nano-electronics', 'Signal processing']
# Investing: a Guide to Doing the Right Thing -> ['Risk management']
# Biological chemistry II (for SV) -> ['Thermodynamics', 'Chemistry', 'Biology']
# Théorie et critique du projet MA2 (Geers) -> ['Lab environment']
# Renewable energy and solar architecture in Davos -> ['Thermodynamics', 'Applied science', 'Lab environment', 'Risk management']
# Lab immersion in industry B -> ['Lab environment']
# Seminars in Physical Chemistry (2) -> ['Chemistry', 'Lab environment']
# Multivariate statistics -> ['Lab environment', 'Data applications', 'Signal processing']
# Financial econometrics -> Risk management
# Equilibrium-stage separation processes -> Biology
# Electron Microscopy for Life Science -> ['Imagery', 'Biology']
# Water resources engineering -> ['Lab environment']
# IC design II -> ['Lab environment', 'Micro/Nano-electronics']
# Space mission design and operations -> ['Materials', 'Lab environment', 'Risk management', 'Architecture/Design']
# Model predictive control -> ['Lab environment', 'Signal processing']
# Computer vision -> ['Imagery', 'Physics']
# Photochemistry II -> ['Physics', 'Thermodynamics', 'Imagery']
# Instability -> ['Lab environment', 'Physics']
# Transmission electron microscopy and diffraction (a) -> ['Imagery']
# Modern photovoltaic technologies -> ['Cellular biology']
# Sparse stochastic processes -> ['Signal processing']
# Cristallography and diffraction methods -> ['Imagery']
# Econometrics -> ['Signal processing', 'Lab environment']
# Lab methods : histology -> ['Imagery']
# Studio MA1 (Escher et GuneWardena) -> ['Lab environment', 'Risk management', 'Applied science']
# Introduction to chemical engineering -> ['Thermodynamics', 'Chemistry', 'Biology', 'Physics']
# Information technology and digital strategy -> ['Business', 'Lab environment']
# Practical - Bucher Lab -> ['Lab environment', 'Data applications']
# Advanced quantum field theory -> ['Micro/Nano-electronics']
# Working group in Topology I -> ['Signal processing', 'Business', 'Applied science', 'Micro/Nano-electronics']
# Functional programming -> ['Lab environment', 'Architecture/Design', 'Physics', 'Cellular biology', 'Computer language processing']
# Neurotechnologies to treat neurodisorders: neuroprosthetics (EDNE) -> ['Lab environment']
# Lab methods : bioactive compounds screening -> ['Lab environment', 'Biology', 'Cellular biology']
# Advanced MEMS -> ['Physics', 'Micro/Nano-electronics', 'Lab environment']
# Théorie et critique du projet MA1 (Geers) -> ['Lab environment']
# PLLs and clock & data recovery -> Micro/Nano-electronics
# Active Remote Sensing of the Atmosphere -> Environment
# Practical - Lemaitre Lab -> Cellular biology
# Integrated circuits technology -> ['Micro/Nano-electronics', 'Applied science', 'Lab environment']
# Applied probability & stochastic processes -> ['Lab environment', 'Signal processing']
# Negotiation techniques -> ['Lab environment']
# Satellite communications  systems and networks -> ['Lab environment']
# Parallel and high-performance computing -> ['Lab environment', 'Architecture/Design']
# Plasma physics III -> ['Cellular biology', 'Micro/Nano-electronics', 'Physics']
# Energy conversion and renewable energy -> ['Thermodynamics', 'Physics']
# Image optics -> ['Physics', 'Imagery']
# Financial Econometrics (EDFI) -> ['Thermodynamics', 'Business', 'Risk management']
# Interdisciplinary / disciplinary project for chemical master -> ['Lab environment', 'Cellular biology', 'Chemistry']
# Social media -> ['Lab environment', 'Machine learning']
# Fixed income analysis -> ['Business', 'Risk management']
# Parallelism and concurrency -> ['Lab environment', 'Architecture/Design', 'Data applications', 'Cellular biology', 'Risk management']
# Optical fibers and fiber devices -> ['Physics']
# Surface and thin films processes -> ['Thermodynamics']
# Optimization and simulation -> ['Lab environment', 'Signal processing', 'Electricity/Power', 'Cellular biology']
# Financial & managerial accounting -> ['Risk management']
# Innovation management -> ['Business', 'Risk management', 'Lab environment', 'Applied science']
# Image analysis and pattern recognition -> ['Imagery', 'Signal processing', 'Physics', 'Lab environment']
# Stochastic calculus I -> ['Signal processing']
# Piezoelectric materials, properties and devices -> Cellular biology
# Limnology -> Lab environment
# Fundamentals of biosensors and electronic biochips -> ['Physics']
# Signal processing for communications -> ['Signal processing']
# Soft Microsystems Processing and Devices -> ['Micro/Nano-electronics', 'Imagery']
# A Network Tour of Data Science -> ['Lab environment', 'Data applications', 'Signal processing', 'Machine learning']
# Mass spectrometry, principles and applications -> ['Biology']
# Development engineering -> ['Applied science', 'Lab environment']
# Assembly techniques -> ['Cellular biology', 'Risk management']
# Nonlinear Optics -> ['Physics']
# Nonlinear Spectroscopy -> ['Physics', 'Cellular biology']
# Advanced analog and RF integrated circuits design II -> ['Micro/Nano-electronics']
# RF MEMS for communications applications -> ['Micro/Nano-electronics']
# Fundamentals of traffic operations and control -> ['Lab environment', 'Architecture/Design', 'Applied science', 'Risk management']
# Biophysics II -> ['Cellular biology']
# Quantum Field Theory Methods in Gravity and Cosmology -> ['Micro/Nano-electronics', 'Cellular biology', 'Signal processing', 'Business']
# Lasers: theory and modern applications -> ['Physics']
# Machine Learning for Engineers -> ['Signal processing']
# Energy storage in power systems: technologies, applications and future needs -> ['Thermodynamics', 'Electricity/Power', 'Risk management']
# Properties of semiconductors and related nanostructures -> ['Cellular biology', 'Physics']
# Seismic engineering -> ['Risk management', 'Cellular biology']
# Théorie et critique du projet MA2 (Gugger) -> ['Lab environment', 'Applied science']
# Advanced lab in electrical engineering -> ['Lab environment', 'Physics', 'Cellular biology', 'Applied science']
# Concurrent algorithms -> ['Risk management', 'Architecture/Design', 'Lab environment', 'Cellular biology', 'Data applications', 'Signal processing']
# Water quality modeling -> ['Chemistry', 'Lab environment']
# Scientific literature analysis in Neuroscience -> ['Biology', 'Lab environment', 'Applied science']
# Information security and privacy -> ['Lab environment', 'Data applications']
# Chemical engineering of heterogenous reactions -> ['Chemistry', 'Lab environment', 'Risk management']
# Flexible bioelectronics -> ['Micro/Nano-electronics', 'Imagery', 'Physics', 'Lab environment', 'Cellular biology']
# Eco-friendly production and process intensification -> ['Chemistry', 'Biology', 'Risk management']
# Dynamical system theory for engineers -> ['Signal processing']
# Introduction to magnetic materials in modern technologies -> ['Cellular biology', 'Risk management']
# Empirical Methods in Corporate Finance -> ['Lab environment', 'Data applications']
# Cosmology: Dark and Luminous Matters  -> Chemistry
# Pharmacology and pharmacokinetics -> ['Applied science']
# Algorithms -> ['Risk management', 'Lab environment', 'Cellular biology', 'Architecture/Design', 'Data applications', 'Signal processing']
# Probability theory -> ['Signal processing', 'Micro/Nano-electronics']
# Theoretical Microfluidics -> ['Chemistry', 'Physics']
# Economics of innovation -> ['Business', 'Applied science', 'Lab environment', 'Risk management']
# Pharmacological chemistry -> ['Biology', 'Chemistry', 'Lab environment']
# High energy and space astrophysics (UNIGe) -> ['Thermodynamics']
# Fundamentals in statistical pattern recognition -> ['Signal processing']
# Advanced Topics in Cryptology -> ['Lab environment', 'Biology', 'Applied science']
# Advanced cryptography -> ['Lab environment', 'Business']
# Biostatistics -> ['Signal processing', 'Data applications', 'Lab environment']
# Digital 3D Geometry Processing -> Architecture/Design
# Introduction to digital signal processing using Matlab, applied to environmental sciences and civil engineering -> ['Signal processing', 'Lab environment', 'Physics']
# Advanced diffusional separation processes -> ['Physics']
# Lab immersion academic (outside EPFL) B -> ['Lab environment']
# Inorganic reactivity -> ['Chemistry', 'Biology', 'Lab environment']
# Advanced satellite positioning -> ['Signal processing']
# Lab in electrical energy systems -> ['Lab environment', 'Electricity/Power']
# Optical waves propagation -> ['Physics', 'Imagery']
# Energy Autonomous Wireless Smart Systems -> ['Thermodynamics', 'Imagery', 'Risk management', 'Physics']
# Numerical methods for visual computing -> ['Physics', 'Lab environment']
# Power management -> ['Electricity/Power', 'Lab environment', 'Micro/Nano-electronics']
# Environmental policy -> ['Lab environment', 'Risk management', 'Business', 'Applied science']
# Fate and behaviour of organic pollutants -> ['Chemistry', 'Lab environment']
# Landmark Papers in Cancer and Infection -> ['Cellular biology', 'Applied science', 'Biology', 'Lab environment']
# Advanced analog and RF integrated circuits design I -> ['Micro/Nano-electronics', 'Signal processing']
# Advanced control systems -> ['Lab environment']
# 2D Layered Materials: Synthesis, Properties and Applications -> ['Imagery']
# Game Theory -> Business
# Linear system theory -> ['Signal processing', 'Lab environment']
# Discrete mathematics -> ['Signal processing', 'Risk management', 'Business']
# Emerging Nanopatterning Methods -> Imagery
# Project in information technologies -> ['Lab environment', 'Imagery']
# Graph theory -> ['Signal processing', 'Micro/Nano-electronics', 'Business']
# Ceramics, structures and properties   TP -> ['Cellular biology', 'Risk management', 'Lab environment']
# Strategic marketing & technology commercialization -> ['Risk management', 'Business', 'Lab environment', 'Applied science']
# Lab immersion in industry A -> ['Lab environment']
# Topics in theoretical computer science -> ['Lab environment', 'Signal processing', 'Architecture/Design', 'Physics', 'Applied science']
# Advanced Earthquake Engineering -> ['Risk management', 'Lab environment', 'Cellular biology']
# Scaling laws in micro- and nanosystems -> ['Micro/Nano-electronics', 'Physics', 'Cellular biology']
# Materials and technology of microfabrication -> ['Applied science', 'Lab environment', 'Cellular biology', 'Micro/Nano-electronics', 'Physics', 'Imagery']
# Business information systems -> ['Business', 'Risk management', 'Applied science', 'Lab environment']
# History of globalization I -> ['Lab environment', 'Applied science']
# Operating systems implementation -> ['Architecture/Design']
# Entrepreneurship -> ['Lab environment', 'Applied science', 'Business', 'Risk management']
# Computational methods in molecular quantum mechanics -> ['Micro/Nano-electronics', 'Lab environment']
# High pressure in chemical kinetics and equilibria -> ['Biology', 'Chemistry']
# Materials Science -> ['Cellular biology', 'Risk management', 'Chemistry']
# CCMX Winter School - Additive Manufacturing of Metals and the Material Science Behind It' -> Physics
# Introduction to crystal growth by epitaxy -> ['Biology', 'Lab environment', 'Risk management']
# Microstructuring of glass -> ['Cellular biology', 'Risk management', 'Physics']
# Advanced composites in engineering structures -> ['Lab environment', 'Risk management', 'Cellular biology', 'Business']
# Ecotoxicology -> ['Biology', 'Chemistry', 'Risk management', 'Lab environment']
# New tools and research strategies in personalized medicine -> ['Lab environment', 'Applied science']
# Numerical methods for electromagnetics -> ['Lab environment', 'Physics']
# Photomechanics for Engineers -> ['Physics']
# Introduction to scanning electron microscopy microanalysis techniques -> ['Imagery', 'Biology']
# Fundamentals of VLSI design -> ['Lab environment', 'Micro/Nano-electronics']
# Electric filters -> ['Lab environment', 'Micro/Nano-electronics', 'Physics', 'Risk management', 'Signal processing']
# Introduction to multiprocessor architecture -> ['Lab environment']
# Wireless Transceivers: Radio Architectures, System and Circuit Design -> Architecture/Design
# Information theory and coding -> ['Signal processing', 'Lab environment', 'Physics']
# Cellular Signalling -> ['Cellular biology', 'Biology', 'Signal processing', 'Lab environment']
# Fracture of materials -> ['Risk management', 'Cellular biology']
# Advances in Additive Manufacturing for Polymers in Bioengineering, Electronics and Material Science -> ['Imagery']
# Chemistry of small biological molecules -> ['Biology', 'Imagery']
# Théorie et critique du projet MA2 (Huang) -> ['Architecture/Design', 'Lab environment']
# Human computer interaction -> ['Lab environment']
# Scientific project design in integrative neurosciences -> ['Lab environment']
# Organic electronic materials - synthesis, applications, properties -> ['Chemistry', 'Imagery', 'Cellular biology']
# Sensor orientation -> ['Lab environment', 'Signal processing']
# Imagery of territory -> ['Imagery', 'Lab environment']
# Scientific project design in drug discovery -> ['Lab environment', 'Applied science']
# Brain Bioenergetics: from behavior to pathology -> Machine learning
# Advanced information, computation, communication I -> ['Signal processing']
# Wireless receivers: algorithms and architectures -> ['Signal processing']
# Biomimetic membrane systems and their applications -> ['Cellular biology']
# Data Analysis for Science and Engineering -> ['Lab environment', 'Signal processing', 'Data applications']
# Infection biology -> ['Biology', 'Cellular biology']
# Advanced digital communications -> ['Signal processing', 'Lab environment']
# Difficult Double Double Histories -> ['Lab environment', 'Applied science']
# Lab immersion III -> ['Lab environment']
# Practical - Lingner Lab -> ['Cellular biology', 'Biology']
# Reactor Technology -> ['Risk management', 'Physics']
# Advanced derivatives -> ['Risk management', 'Business']
# Geocomputation -> ['Lab environment']
# Summer School on Neurophysiology for Neural and Biomedical Engineering (2016) -> ['Lab environment']
# Multivariate Extreme Value and Max-Stable Processes -> Signal processing
# Monthly IBI-EDBB Mini-symposia -> ['Lab environment']
# Numerical Methods for Physical Properties Evaluation -> ['Chemistry']
# High Dimensional Approximation for PDEs with random parameters -> Micro/Nano-electronics
# Energy geostructures -> ['Thermodynamics']
# Data analysis and model classification -> ['Cellular biology', 'Signal processing', 'Physics', 'Architecture/Design', 'Lab environment', 'Micro/Nano-electronics', 'Risk management', 'Imagery']
# Mechanical product design and development -> ['Lab environment', 'Applied science', 'Micro/Nano-electronics']
# Energy planning: modeling and decision support systems -> ['Thermodynamics', 'Risk management', 'Lab environment']
# Waterborne Pathogens -> ['Risk management', 'Cellular biology']
# Mathematics for Financial Economics -> ['Lab environment', 'Signal processing', 'Thermodynamics']
# Cellular biology and biochemistry for engineers -> ['Cellular biology', 'Biology', 'Lab environment', 'Applied science', 'Chemistry']
# Smart grids technologies -> ['Lab environment', 'Electricity/Power']
# Transportation systems engineering -> ['Lab environment', 'Risk management', 'Applied science', 'Physics']
# Working group in Topology II -> ['Signal processing', 'Micro/Nano-electronics', 'Business']
# Networks out of control -> ['Signal processing', 'Machine learning', 'Risk management']
# Surface analysis -> ['Imagery', 'Micro/Nano-electronics', 'Biology']
# Multi-body simulation -> ['Physics', 'Cellular biology', 'Risk management', 'Lab environment', 'Chemistry']
# Accounting for finance -> Thermodynamics
# Computer architecture -> ['Lab environment']
# Laser Processing of Materials: From Optical Properties of Materials and Light-Matter Interaction to Applications -> ['Physics', 'Cellular biology']
# Real-time embedded systems -> ['Lab environment']
# Robotics practicals -> ['Lab environment']
# Practical - Naef Lab -> ['Biology', 'Lab environment', 'Cellular biology']
# Optional project in computer science -> ['Lab environment', 'Risk management']
# UE W: Reading construction -> ['Lab environment', 'Applied science', 'Risk management', 'Architecture/Design']
# Advanced lab in electrical energy systems -> ['Lab environment']
# HF and VHF circuits and techniques II -> ['Lab environment', 'Micro/Nano-electronics']
# Interfaces in biology and nanoscience -> ['Biology', 'Lab environment', 'Cellular biology']
# Practical - Constam Lab -> ['Cellular biology', 'Signal processing', 'Imagery']
# Dynamic Asset Pricing -> ['Thermodynamics', 'Business']
# Microelectronics -> ['Micro/Nano-electronics']
# Hydrodynamics -> ['Chemistry', 'Physics']
# Readings in Organization Economics -> ['Lab environment', 'Applied science']
# Optics III -> ['Physics']
# Gene transfer and recombinant protein expression in animal cells -> ['Cellular biology', 'Biology']
# CCMX Advanced Course - Atomic Force Microscopy (AFM): Theory and Practice -> ['Imagery', 'Lab environment']
# Wave propagation along transmission lines -> Physics
# CCMX Advanced Course - Combining Structural & Analytical Investigations of Matter at the Micro-, Nano and Atomic Scale- (2016) -> ['Imagery']
# Propagation of acoustic waves -> ['Lab environment', 'Physics', 'Risk management', 'Applied science']
# Food biotechnology -> ['Chemistry', 'Lab environment']
# Derivatives -> Chemistry
# Leading and managing in a global context -> ['Lab environment', 'Risk management', 'Applied science']
# Technology ventures in IC -> ['Lab environment', 'Business', 'Risk management', 'Applied science']
# Advanced NMR and imaging -> ['Imagery', 'Physics', 'Cellular biology', 'Micro/Nano-electronics']
# Seminars in Physical Chemistry (1) -> ['Chemistry', 'Lab environment']
# Optional project in communication systems -> ['Lab environment']
# Effects of radiation on materials -> ['Imagery', 'Risk management', 'Cellular biology']
# Advanced compiler construction -> ['Lab environment']
# Circuits and systems II -> ['Signal processing', 'Lab environment']
# Cancer Biology I -> ['Cellular biology', 'Biology', 'Lab environment']
# Magnetic confinement -> ['Cellular biology']
# Cancer Biology II -> ['Lab environment', 'Cellular biology']
# Creative Problem Solving in Science and Engineering -> ['Lab environment', 'Physics', 'Applied science', 'Business']
# Design of Ultra-low Power Wearable Wireless Systems -> ['Lab environment', 'Signal processing']
# Metrology II -> ['Lab environment', 'Signal processing', 'Physics']
# Summer school on healthcare diagnostics -> ['Lab environment', 'Applied science']
# Introduction to practical aspects of animal experimentation and animal facilities (Winter) (EDNE) -> ['Biology', 'Lab environment', 'Cellular biology']
# Quantitative methods in finance -> Thermodynamics
# Numerical methods in chemistry -> ['Chemistry', 'Physics']
# General physics II -> ['Thermodynamics', 'Cellular biology', 'Physics']
# Enterprise and service-oriented architecture -> ['Lab environment', 'Business']
# Magnetic materials in modern technologies - from concepts to real devices -> ['Cellular biology', 'Micro/Nano-electronics']
# Electromagnetic compatibility -> ['Micro/Nano-electronics']
# Scaling in MEMS -> ['Micro/Nano-electronics']
# Part 4 : Research project in Area and Cultural Studies -> ['Lab environment', 'Applied science']
# Biomass conversion -> ['Thermodynamics']
# Solid waste engineering -> ['Applied science']
# Haptic human robot interfaces -> ['Lab environment']
# Statistical neurosciences -> ['Lab environment', 'Data applications', 'Signal processing']
# Student seminar: security protocols and applications -> ['Lab environment', 'Data applications']
# Fundamentals of biomedical imaging -> ['Imagery', 'Physics']
# Information : strategy & economics -> ['Business', 'Risk management', 'Lab environment', 'Applied science']
# Personal interaction studio -> ['Lab environment']
# Total synthesis of natural products -> ['Chemistry', 'Risk management']
# Incompressible fluid mechanics -> ['Chemistry', 'Physics', 'Electricity/Power']
# Solid state physics II -> ['Cellular biology', 'Micro/Nano-electronics']
# Fracture Mechanics and Fatigue of Structures -> ['Risk management', 'Cellular biology']
# HydroPower and Dams: Benefits and Concerns -> ['Thermodynamics']
# Cryptography and security -> ['Signal processing']
# Neurosciences I : molecular neuroscience and neurodegeneration -> ['Biology', 'Cellular biology']
# Microbial diversity -> ['Biology', 'Cellular biology']
# Neurosciences III : behavioral and cognitive neuroscience -> Cellular biology
# Seminar series on advances in materials (autumn) -> ['Lab environment', 'Machine learning', 'Chemistry']
# Characterization Methods in Materials Science -> ['Imagery', 'Cellular biology']
# Biomicroscopy I -> ['Physics', 'Imagery']
# Computational physics III -> ['Physics', 'Signal processing', 'Cellular biology']
# Lab in microwaves -> ['Lab environment']
# Engineering geology for geo-energy -> Risk management
# Process development I -> ['Thermodynamics', 'Applied science', 'Lab environment', 'Architecture/Design']
# New Concretes for Structures -> ['Risk management', 'Cellular biology']
# Signals, instruments, and systems -> ['Lab environment', 'Signal processing']
# Introduction to computer graphics -> Physics
# Probabilistic Coupling -> ['Signal processing']
# Statistical theory -> ['Signal processing']
# ...
# Reliability of MEMS (EDOC) -> ['Micro/Nano-electronics']
# Grid and Converter Controls -> ['Lab environment', 'Electricity/Power']
# Light sources: optical fiber and waveguide lasers -> ['Physics']
# Integrated optics -> ['Physics']
# Snow Science Winter School -> ['Lab environment', 'Environment']
# Micro and nanostructuration of materials -> ['Lab environment']
# Heat and mass transfer -> ['Physics']
# Theory of computation -> ['Physics', 'Lab environment', 'Electricity/Power', 'Signal processing', 'Architecture/Design', 'Micro/Nano-electronics']
# General physics III -> ['Physics', 'Chemistry', 'Cellular biology', 'Micro/Nano-electronics']
# Methods of asymptotic analysis in mechanics -> ['Electricity/Power', 'Physics']
# Environment chemical and biological technology -> ['Biology']
# Evolutionary robotics -> ['Lab environment']
# Analysis and modelling of locomotion -> ['Physics', 'Lab environment']
# Advanced topics in electromagnetic compatibility -> Imagery
# Fundamentals of Biometrics -> ['Lab environment', 'Signal processing']
# Advanced computer architecture -> Architecture/Design
# Laboratory information management systems (LIMS) -> ['Risk management', 'Applied science']
# Advanced topics in financial econometrics -> ['Business']
# Harmonic analysis -> ['Signal processing']
# Fundamentals of biophotonics -> ['Physics', 'Cellular biology', 'Lab environment', 'Biology']
# Engineering of musculoskeletal system and rehabilitation -> Lab environment
# Corporate strategy -> ['Risk management', 'Applied science', 'Business']
# Introduction to the finite elements method -> ['Physics', 'Lab environment', 'Chemistry', 'Cellular biology']
# Transient and dynamic analysis of electric power systems -> Lab environment
# Information and Asset Pricing -> ['Business']
# Embedded systems -> ['Lab environment']
# Organic semiconductors -> ['Physics', 'Imagery', 'Cellular biology', 'Micro/Nano-electronics', 'Chemistry']
# Combinatorial optimization -> ['Lab environment', 'Architecture/Design', 'Signal processing']
# Genomics and bioinformatics -> ['Biology']
# Advances in Contact Mechanics -> ['Risk management', 'Applied science', 'Biology', 'Business', 'Chemistry']
# Crystallography of structural phase transformations -> ['Cellular biology']
# Advanced analog IC design -> ['Micro/Nano-electronics']
# Computer networks -> ['Lab environment', 'Physics', 'Data applications']
# Statistical mechanics -> ['Signal processing', 'Lab environment', 'Risk management', 'Cellular biology', 'Physics']
# Principles of finance -> ['Risk management', 'Lab environment']
# Understanding modern Switzerland II -> ['Lab environment']
# Introduction to nuclear engineering -> ['Risk management', 'Physics', 'Cellular biology']
# Information Science in Engineering -> ['Lab environment', 'Cellular biology', 'Physics', 'Electricity/Power', 'Applied science', 'Architecture/Design', 'Risk management', 'Chemistry']
# Applied molecular quantum chemistry -> ['Imagery', 'Micro/Nano-electronics', 'Chemistry']
# Symmetry and Conservation in the Cell -> ['Cellular biology']
# Advanced metallurgy -> ['Materials']
# Environmental Economics for Engineers -> ['Risk management']
# Economics of innovation & management in energy -> ['Thermodynamics', 'Risk management', 'Applied science']
# Understanding modern Switzerland I -> ['Lab environment']
# Communication for Research Engineers -> ['Lab environment']
# Power electronics -> ['Imagery', 'Thermodynamics', 'Electricity/Power', 'Micro/Nano-electronics', 'Cellular biology', 'Physics', 'Risk management']
# Current Topics in Chemical Biology 1 -> ['Biology', 'Chemistry', 'Lab environment']
# Applied mechanical design -> ['Lab environment', 'Applied science', 'Risk management', 'Cellular biology', 'Business']
# Optical Materials: Fundamental concepts and recent developments -> ['Physics', 'Cellular biology']
# Presentation skills -> ['Lab environment']
# 3D Electron Microscopy and FIB-Nanotomography -> ['Imagery']
# Scanning electron microscopy techniques (a) -> ['Imagery', 'Lab environment']
# BioMEMS -> ['Cellular biology', 'Physics', 'Micro/Nano-electronics', 'Chemistry']
# Plasma physics II -> ['Micro/Nano-electronics', 'Physics']
# Lab methods : biosafety -> ['Risk management', 'Lab environment', 'Biology']
# Advanced probability and applications -> ['Signal processing']
# Sensors in medical instrumentation -> ['Physics', 'Imagery']
# Thermodynamics of energy conversion and storage -> ['Thermodynamics']
# Spacecraft avionics systems, architectures and processors -> ['Lab environment']
# General chemistry (English) -> ['Chemistry', 'Biology', 'Thermodynamics', 'Cellular biology']
# Games for Crowds and Networks -> ['Business', 'Signal processing', 'Machine learning', 'Lab environment']
# Numerical Analysis and Computational Mathematics -> ['Physics', 'Lab environment', 'Signal processing']
# Advanced Microscopy for Life Science -> ['Imagery']
# Théorie et critique du projet BA3 (De Vylder & Taillieu) -> Architecture/Design
# Quantum chemistry -> ['Micro/Nano-electronics', 'Cellular biology', 'Chemistry', 'Imagery', 'Risk management']
# Machine learning programming -> ['Lab environment', 'Architecture/Design']
# Practical - Meylan Lab -> Lab environment
# Brain-computer interaction -> ['Signal processing']
# Academic Writing for Doctoral Students -> ['Lab environment', 'Machine learning']
# Studio MA2 (Lütjens et Padmanabhan) -> ['Lab environment', 'Risk management', 'Architecture/Design', 'Applied science']
# Measuring systems laboratory work -> ['Lab environment', 'Physics']
# Industrial electronics II -> ['Lab environment', 'Electricity/Power', 'Imagery']
# Efficient Synthetic Routes Towards Bioactive Molecules -> Chemistry
# Atomistic and quantum simulations of materials -> ['Cellular biology', 'Micro/Nano-electronics', 'Risk management', 'Physics', 'Electricity/Power', 'Lab environment', 'Signal processing']
# Electronic spectroscopy -> ['Imagery', 'Micro/Nano-electronics']
# Analysis III -> ['Signal processing', 'Micro/Nano-electronics']
# Practical - Radtke Lab -> ['Chemistry']
# Neuroscience for engineers -> ['Imagery']
# Mathematics of data: from theory to computation -> ['Lab environment', 'Signal processing', 'Architecture/Design']
# Inorganic chemistry "Techniques and methods" -> ['Chemistry']
# Fluid mechanics (for SIE) -> ['Chemistry', 'Physics']
# Bioinorganic chemistry -> ['Biology']
# Bioanalytics and analytical sensors -> ['Lab environment', 'Applied science']
# Physics of photonic semiconductor devices -> ['Physics', 'Micro/Nano-electronics']
# Project in Biotechnology -> ['Lab environment', 'Machine learning']
# Digital Speech and Audio Coding -> ['Signal processing']
# Foundations of software -> ['Lab environment', 'Architecture/Design', 'Risk management']
# Current Topics in Distributed Systems -> ['Chemistry']
# Industrial automation -> ['Lab environment']
# Lab immersion II -> ['Lab environment', 'Data applications']
# Project in molecular sciences -> ['Lab environment', 'Risk management']
# Stellar evolution and nucleosynthesis (UNIGe) -> ['Cellular biology']
# Data science for business -> ['Lab environment', 'Data applications', 'Risk management', 'Business']
# Asset Pricing -> ['Business']
# Quantum optics and quantum information -> ['Micro/Nano-electronics', 'Physics']
# Analysis of ancient materials and their degradation -> ['Imagery', 'Lab environment']
# Advanced steel design -> ['Risk management']
# Recent Events in Energy-2 -> ['Lab environment', 'Thermodynamics']
# Spatial statistics and analysis -> ['Lab environment', 'Data applications']
# Process development project -> ['Lab environment', 'Applied science']
# Semester project in Bioengineering -> ['Lab environment', 'Data applications']
# Applied wastewater engineering -> ['Lab environment', 'Environment']
# Life cycle engineering of polymers -> ['Applied science', 'Risk management', 'Lab environment']
# Introduction to electronic structure methods -> ['Lab environment', 'Micro/Nano-electronics', 'Imagery', 'Risk management', 'Physics']
# CCMX Summer School - Multiscale Modelling of Materials (2016) -> ['Cellular biology', 'Lab environment', 'Biology', 'Physics']
# Introduction to nanomaterials -> ['Cellular biology', 'Physics', 'Biology', 'Lab environment', 'Chemistry', 'Applied science']
# CCMX Winter School Surface Science and Coatings -> ['Risk management', 'Physics', 'Cellular biology']
# Advanced electroanalytical chemistry I -> ['Micro/Nano-electronics']
# Basic principles of drug action at the nervous system -> ['Biology']
# Quantitative risk management -> ['Risk management']
# Statistics for genomic data analysis -> ['Lab environment', 'Data applications', 'Biology']
# Advanced bioengineering methods laboratory -> ['Lab environment', 'Machine learning']
# Scientific project design in translational oncology -> ['Cellular biology']
# Optics I -> ['Physics', 'Chemistry']
# Analysis I (English) -> Micro/Nano-electronics
# Convex optimization and applications -> ['Lab environment', 'Signal processing', 'Architecture/Design', 'Business', 'Physics']
# Venture capital -> ['Thermodynamics']
# Advanced energetics -> ['Thermodynamics', 'Risk management']
# General physics I (English) -> ['Thermodynamics', 'Cellular biology', 'Physics']
# Scientific literature analysis in Bioengineering -> ['Lab environment', 'Biology', 'Applied science']
# Biological chemistry III -> ['Biology', 'Risk management']
# Tissue engineering -> ['Cellular biology', 'Biology', 'Applied science']
# Localization and Navigation Methods -> ['Physics']
# Advanced biomedical imaging methods and instrumentation -> ['Imagery', 'Physics']
# Scientific project design in synthetic biology (iGEM) -> ['Biology', 'Lab environment']
# Modelling, optimisation, design and analysis of integrated energy systems -> ['Thermodynamics', 'Micro/Nano-electronics', 'Lab environment']
# Discrete optimization -> ['Signal processing', 'Lab environment', 'Architecture/Design']
# HF and VHF circuits and techniques I -> ['Lab environment', 'Micro/Nano-electronics']
# Scientific project design in regenerative medicine and diagnostics -> ['Lab environment', 'Applied science']
# Neutronics -> ['Risk management']
# Qualitative Research Methods -> ['Lab environment', 'Machine learning', 'Applied science', 'Data applications']
# Numerical flow simulation -> ['Physics', 'Lab environment', 'Electricity/Power']
# Reactor Experiments -> ['Lab environment']
# Practical - Van der Goot Lab -> ['Biology', 'Cellular biology']
# Biomaterials -> ['Cellular biology', 'Biology']
# Optical detectors -> ['Physics', 'Imagery']
# Introduction to cellular and molecular biotechnology -> Biology
# Optimal control -> ['Lab environment', 'Physics', 'Architecture/Design']
# Project in computer science II -> ['Lab environment', 'Risk management', 'Applied science', 'Biology', 'Business', 'Architecture/Design']
# Image processing I -> ['Imagery', 'Signal processing', 'Physics']
# Biomineralization: from nature to application -> ['Biology', 'Lab environment']
# Philosophy of life sciences II -> ['Lab environment', 'Business']
# Spacecraft design and system engineering -> ['Lab environment', 'Risk management', 'Architecture/Design', 'Cellular biology', 'Applied science', 'Materials']
# CCMX Advanced Course - Inorganic Particle Synthesis by Precipitation: From Nanoparticles to Self-organised  Mesocrystals and from Theory to Practice -> Risk management
# Lectures in Life Sciences -> ['Biology', 'Lab environment']
# Introductory course about Spatial Statistics -> ['Signal processing']
# Mathematical methods for physicists -> ['Signal processing', 'Physics', 'Chemistry', 'Lab environment']
# Selected topics in mechanics of solids and structures -> ['Risk management', 'Cellular biology', 'Applied science', 'Business']
# Martingales in financial mathematics -> ['Thermodynamics']
# Computational Social Media -> ['Machine learning']
# Analog circuits design I -> ['Micro/Nano-electronics', 'Risk management']
# Advanced numerical analysis -> ['Physics', 'Chemistry', 'Lab environment', 'Signal processing']
# Aerodynamics -> ['Physics', 'Electricity/Power']
# Catalyst design for synthesis -> ['Chemistry']
# General physics (English) II -> ['Physics', 'Cellular biology', 'Thermodynamics', 'Chemistry', 'Biology']
# Frontiers in Chemical Synthesis. Towards Sustainable Chemistry -> ['Chemistry']
# Science and Engineering Teaching and Learning -> ['Lab environment']
# B2B - high-tech marketing -> ['Risk management', 'Business', 'Lab environment']
# Measuring systems -> ['Lab environment', 'Physics']
# Working Group in Algebraic Groups, I -> ['Risk management', 'Business', 'Signal processing']
# Principles of microeconomics -> ['Lab environment', 'Business']
# Software-defined radio: A hands-on course -> ['Signal processing', 'Physics']
# Cognitive psychology B -> ['Lab environment']
# Modelling problem solving, computing and visualisation I -> ['Lab environment', 'Physics', 'Architecture/Design', 'Electricity/Power']
# Optimization Methods and Models -> ['Lab environment', 'Architecture/Design', 'Business', 'Signal processing', 'Applied science', 'Physics']
# Nanocomputing: Devices, Circuits and Architectures -> ['Micro/Nano-electronics', 'Lab environment', 'Physics']
# Two-phase flows and heat transfer -> ['Physics', 'Thermodynamics', 'Electricity/Power']
# Theory of materials : from structures to properties -> ['Cellular biology', 'Physics']
# Technology and Public Policy - (a) Science, technology and society -> ['Applied science']
# Computation of molecular properties -> ['Imagery', 'Micro/Nano-electronics']
# Microbiology -> ['Cellular biology']
# Analog circuits design II -> ['Micro/Nano-electronics', 'Lab environment']
# MINTT: Management of Innovation and technology transfer (EDOC) -> ['Lab environment', 'Applied science', 'Risk management']
# Advanced multiprocessor architecture -> ['Lab environment', 'Architecture/Design']
# Single cell genomics -> ['Cellular biology', 'Lab environment']
# Advanced electroanalytical chemistry (II session) -> ['Micro/Nano-electronics']
# Computational linear algebra -> ['Signal processing', 'Physics', 'Lab environment']
# Additive Combinatorics -> ['Imagery', 'Lab environment', 'Applied science', 'Physics', 'Environment', 'Biology']
# Production management -> ['Lab environment', 'Risk management', 'Applied science']
# Packing and covering -> ['Business']
# Research project in materials II -> ['Lab environment', 'Risk management']
# Molecular quantum dynamics -> ['Micro/Nano-electronics']
# System Identification -> ['Lab environment', 'Signal processing']
# Stochastic calculus II -> ['Chemistry']
# Biophysics I -> ['Biology', 'Cellular biology', 'Applied science']
# CCMX Winter School - Nanoparticles: From Fundamentals to Applications in Life Sciences -> ['Biology', 'Cellular biology', 'Physics']
# Basic principles of drug action at the cardiovascular system -> ['Biology']
# Commutative algebra -> ['Signal processing']
# Sustainability assessment -> ['Lab environment', 'Risk management', 'Applied science']
# Chemical kinetics -> ['Chemistry', 'Business']
# Decision-aid methodologies in transportation -> ['Lab environment', 'Applied science', 'Architecture/Design']
# Introduction to environmental engineering -> ['Chemistry', 'Biology', 'Applied science']
# Entrepreneurship & new venture strategy (a) -> ['Lab environment', 'Business', 'Risk management', 'Applied science']
# Renewable energy (for ME) -> ['Thermodynamics']
# Physical and computational organic chemistry -> ['Chemistry', 'Physics', 'Cellular biology', 'Imagery', 'Risk management', 'Biology']
# Signal processing for functional brain imaging -> ['Lab environment', 'Signal processing', 'Imagery']
# Design technologies for integrated systems -> ['Lab environment', 'Architecture/Design']
# Structural stability -> ['Risk management']
# Translational Robotics for Clinical Rehabilitation -> ['Lab environment', 'Applied science']
# Microwaves -> ['Micro/Nano-electronics']
# Convexity -> ['Lab environment']
# Introduction to finance (IF master and minor only) -> ['Risk management', 'Lab environment', 'Business']
# Practical - Blokesch Lab -> ['Biology']
# Scientific programming for Engineers -> ['Signal processing', 'Lab environment', 'Physics', 'Architecture/Design']

# %% [markdown]
# ## Exercise 4.9: Dirichlet hyperparameters

# %% [markdown]
# ## Exercise 4.10: EPFL's taught subjects

# %% [markdown]
# ## Exercise 4.11: Wikipedia structure

# %%
rdd = sc.textFile("/ix/wikipedia-for-schools.txt").map(json.loads)

# %%
def seq(a,b):
    for el in b['tokens']:
        a.add(el)
    return a
def comb(a,b):
    return a.union(b)
wikiTerms = rdd.aggregate(set(), seq, comb)

# %%
wikiTermsList = sorted(list(wikiTerms))
wikiTermsDict = dict(zip(wikiTermsList, range(len(wikiTerms))))

# %%
print(wikiTermsDict['king'])
# Out:
# 227108

# %%
elD = rdd.take(1)[0]

# %%
# Checks if given word is a number
def is_number(word):
    try:
        float(word)
        return True
    except ValueError:
        return False

    
# If the word passes the filters and should be in the dataset, returns True, False otherwise
def filter_word(word):
    # Words of len 1
    if len(word) < 2:
        return False
    # Removing words in stopwords
    #if word in stopwords:
        #return False
    # Removing words consisting of a punctuation sign
    if word in string.punctuation:
        return False
    # Removing numbers
    if is_number(word):
        return False
    return True

# %%
def createBOW(termList):
    resDict = {}
    for term in termList['tokens']:
        if (filter_word(term)):
            resDict[term] = resDict.get(term, 0) + 1
    return resDict

def createSparseTermVector(bow):
    values = []
    indices = []
    for k,v in sorted(bow.items(), key=lambda x:x[0]):
        values.append(v)
        indices.append(wikiTermsDict[k])
    return Vectors.sparse(len(values), indices, values)

def mapFunc(el):
    return [el['page_id'], createSparseTermVector(createBOW(el))]

vectorsRDD = rdd.map(mapFunc).persist()

# %%
wiki_ldaModel = LDA.train(vectorsRDD, k=30, docConcentration=2.01, topicConcentration=1.5)

# %%
topDesc = wiki_ldaModel.describeTopics()

# %%
def topWords(ldaTopicDesc, wordList):
    for topic in ldaTopicDesc:
        termList = []
        for i in range(10):
            termList.append(wordList[topic[0][i]])
            
        print(termList)

# %%
topWords(topDesc, wikiTermsList)
